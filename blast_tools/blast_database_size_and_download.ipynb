# %%
import ftplib
import os

def get_blastp_database_size(ftp_server, ftp_path):
    # Connect to the FTP server
    ftp = ftplib.FTP(ftp_server)
    ftp.login()
    ftp.cwd(ftp_path)

    # List files with detailed information
    entries = []
    try:
        ftp.retrlines('MLSD', entries.append)
    except ftplib.error_perm as e:
        print(f"Could not retrieve directory listing: {e}")
        ftp.quit()
        return

    total_size = 0
    file_sizes = {}

    for entry in entries:
        parts = entry.split(';')
        name_part = parts[-1].strip()
        size_part = [p for p in parts if p.startswith('size=')]
        
        if size_part and name_part.startswith('nr'):
            size = int(size_part[0].split('=')[1])
            total_size += size
            file_sizes[name_part] = size

    # Close the FTP connection
    ftp.quit()

    # Print the sizes
    for file, size in file_sizes.items():
        print(f'{file}: {size / (1024 ** 2):.2f} MB')
    print(f'Total size: {total_size / (1024 ** 3):.2f} GB')

# Parameters
ftp_server = 'ftp.ncbi.nlm.nih.gov'
ftp_path = '/blast/db/'

# Call the function to get the database size
get_blastp_database_size(ftp_server, ftp_path)

# Prompt user for download
download_prompt = input("Do you want to download the database files? (y/n): ").strip().lower()

if download_prompt == 'y':
    if not download_path:
        download_path = input("Enter the directory to save the files (default: './blast_db'): ").strip()
        download_path = download_path if download_path else './blast_db'

    os.makedirs(download_path, exist_ok=True)  # Create directory if it doesn't exist
    print(f"Downloading files to {download_path}...")

    for file in file_sizes.keys():
        local_file = os.path.join(download_path, file)
        print(f"Downloading {file} to {local_file}...")
        with open(local_file, 'wb') as f:
            ftp.retrbinary(f"RETR {file}", f.write)
        print(f"{file} downloaded successfully.")
else:
    print("Download skipped.")
# Out:
# nr.000.tar.gz: 36208.40 MB
# nr.000.tar.gz.md5: 0.00 MB
# nr.001.tar.gz: 2770.25 MB
# nr.001.tar.gz.md5: 0.00 MB
# nr.002.tar.gz: 2503.15 MB
# nr.002.tar.gz.md5: 0.00 MB
# nr.003.tar.gz: 2165.59 MB
# nr.003.tar.gz.md5: 0.00 MB
# nr.004.tar.gz: 2543.58 MB
# nr.004.tar.gz.md5: 0.00 MB
# nr.005.tar.gz: 2440.53 MB
# nr.005.tar.gz.md5: 0.00 MB
# nr.006.tar.gz: 2358.61 MB
# nr.006.tar.gz.md5: 0.00 MB
# nr.007.tar.gz: 2984.81 MB
# nr.007.tar.gz.md5: 0.00 MB
# nr.008.tar.gz: 30.56 MB
# nr.008.tar.gz.md5: 0.00 MB
# nr.009.tar.gz: 2550.57 MB
# nr.009.tar.gz.md5: 0.00 MB
# nr.010.tar.gz: 2985.39 MB
# nr.010.tar.gz.md5: 0.00 MB
# nr.011.tar.gz: 500.64 MB
# nr.011.tar.gz.md5: 0.00 MB
# nr.012.tar.gz: 2516.98 MB
# nr.012.tar.gz.md5: 0.00 MB
# nr.013.tar.gz: 2984.80 MB
# nr.013.tar.gz.md5: 0.00 MB
# nr.014.tar.gz: 428.30 MB
# nr.014.tar.gz.md5: 0.00 MB
# nr.015.tar.gz: 2589.09 MB
# nr.015.tar.gz.md5: 0.00 MB
# nr.016.tar.gz: 2713.99 MB
# nr.016.tar.gz.md5: 0.00 MB
# nr.017.tar.gz: 2984.50 MB
# nr.017.tar.gz.md5: 0.00 MB
# nr.018.tar.gz: 584.11 MB
# nr.018.tar.gz.md5: 0.00 MB
# nr.019.tar.gz: 2983.93 MB
# nr.019.tar.gz.md5: 0.00 MB
# nr.020.tar.gz: 91.55 MB
# nr.020.tar.gz.md5: 0.00 MB
# nr.021.tar.gz: 2812.46 MB
# nr.021.tar.gz.md5: 0.00 MB
# nr.022.tar.gz: 2984.48 MB
# nr.022.tar.gz.md5: 0.00 MB
# nr.023.tar.gz: 396.91 MB
# nr.023.tar.gz.md5: 0.00 MB
# nr.024.tar.gz: 2428.03 MB
# nr.024.tar.gz.md5: 0.00 MB
# nr.025.tar.gz: 2984.35 MB
# nr.025.tar.gz.md5: 0.00 MB
# nr.026.tar.gz: 242.89 MB
# nr.026.tar.gz.md5: 0.00 MB
# nr.027.tar.gz: 2984.59 MB
# nr.027.tar.gz.md5: 0.00 MB
# nr.028.tar.gz: 750.72 MB
# nr.028.tar.gz.md5: 0.00 MB
# nr.029.tar.gz: 2986.07 MB
# nr.029.tar.gz.md5: 0.00 MB
# nr.030.tar.gz: 433.04 MB
# nr.030.tar.gz.md5: 0.00 MB
# nr.031.tar.gz: 2034.78 MB
# nr.031.tar.gz.md5: 0.00 MB
# nr.032.tar.gz: 2985.97 MB
# nr.032.tar.gz.md5: 0.00 MB
# nr.033.tar.gz: 234.36 MB
# nr.033.tar.gz.md5: 0.00 MB
# nr.034.tar.gz: 2807.22 MB
# nr.034.tar.gz.md5: 0.00 MB
# nr.035.tar.gz: 2986.00 MB
# nr.035.tar.gz.md5: 0.00 MB
# nr.036.tar.gz: 371.77 MB
# nr.036.tar.gz.md5: 0.00 MB
# nr.037.tar.gz: 2733.77 MB
# nr.037.tar.gz.md5: 0.00 MB
# nr.038.tar.gz: 2374.28 MB
# nr.038.tar.gz.md5: 0.00 MB
# nr.039.tar.gz: 2373.20 MB
# nr.039.tar.gz.md5: 0.00 MB
# nr.040.tar.gz: 2390.30 MB
# nr.040.tar.gz.md5: 0.00 MB
# nr.041.tar.gz: 2593.11 MB
# nr.041.tar.gz.md5: 0.00 MB
# nr.042.tar.gz: 2963.20 MB
# nr.042.tar.gz.md5: 0.00 MB
# nr.043.tar.gz: 2985.41 MB
# nr.043.tar.gz.md5: 0.00 MB
# nr.044.tar.gz: 73.69 MB
# nr.044.tar.gz.md5: 0.00 MB
# nr.045.tar.gz: 2079.38 MB
# nr.045.tar.gz.md5: 0.00 MB
# nr.046.tar.gz: 2985.16 MB
# nr.046.tar.gz.md5: 0.00 MB
# nr-prot-metadata.json: 0.01 MB
# nr.047.tar.gz: 86.93 MB
# nr.047.tar.gz.md5: 0.00 MB
# nr.048.tar.gz: 2913.94 MB
# nr.048.tar.gz.md5: 0.00 MB
# nr.049.tar.gz: 2196.18 MB
# nr.049.tar.gz.md5: 0.00 MB
# nr.050.tar.gz: 2985.55 MB
# nr.050.tar.gz.md5: 0.00 MB
# nr.051.tar.gz: 41.77 MB
# nr.051.tar.gz.md5: 0.00 MB
# nr.052.tar.gz: 2985.62 MB
# nr.052.tar.gz.md5: 0.00 MB
# nr.053.tar.gz: 81.21 MB
# nr.053.tar.gz.md5: 0.00 MB
# nr.054.tar.gz: 2985.50 MB
# nr.054.tar.gz.md5: 0.00 MB
# nr.055.tar.gz: 159.05 MB
# nr.055.tar.gz.md5: 0.00 MB
# nr.056.tar.gz: 2122.88 MB
# nr.056.tar.gz.md5: 0.00 MB
# nr.057.tar.gz: 2690.49 MB
# nr.057.tar.gz.md5: 0.00 MB
# nr.058.tar.gz: 2985.23 MB
# nr.058.tar.gz.md5: 0.00 MB
# nr.059.tar.gz: 293.39 MB
# nr.059.tar.gz.md5: 0.00 MB
# nr.060.tar.gz: 2885.08 MB
# nr.060.tar.gz.md5: 0.00 MB
# nr.061.tar.gz: 2984.33 MB
# nr.061.tar.gz.md5: 0.00 MB
# nr.062.tar.gz: 68.32 MB
# nr.062.tar.gz.md5: 0.00 MB
# nr.063.tar.gz: 2904.87 MB
# nr.063.tar.gz.md5: 0.00 MB
# nr.064.tar.gz: 2733.44 MB
# nr.064.tar.gz.md5: 0.00 MB
# nr.065.tar.gz: 2826.52 MB
# nr.065.tar.gz.md5: 0.00 MB
# nr.066.tar.gz: 2985.05 MB
# nr.066.tar.gz.md5: 0.00 MB
# nr.067.tar.gz: 103.05 MB
# nr.067.tar.gz.md5: 0.00 MB
# nr.068.tar.gz: 2984.85 MB
# nr.068.tar.gz.md5: 0.00 MB
# nr.069.tar.gz: 102.53 MB
# nr.069.tar.gz.md5: 0.00 MB
# nr.070.tar.gz: 2887.37 MB
# nr.070.tar.gz.md5: 0.00 MB
# nr.071.tar.gz: 2404.06 MB
# nr.071.tar.gz.md5: 0.00 MB
# nr.072.tar.gz: 2966.25 MB
# nr.072.tar.gz.md5: 0.00 MB
# nr.073.tar.gz: 2985.30 MB
# nr.073.tar.gz.md5: 0.00 MB
# nr.074.tar.gz: 33.13 MB
# nr.074.tar.gz.md5: 0.00 MB
# nr.075.tar.gz: 2984.77 MB
# nr.075.tar.gz.md5: 0.00 MB
# nr.076.tar.gz: 571.41 MB
# nr.076.tar.gz.md5: 0.00 MB
# nr.077.tar.gz: 2578.12 MB
# nr.077.tar.gz.md5: 0.00 MB
# nr.078.tar.gz: 2507.39 MB
# nr.078.tar.gz.md5: 0.00 MB
# nr.079.tar.gz: 2688.71 MB
# nr.079.tar.gz.md5: 0.00 MB
# nr.080.tar.gz: 2984.56 MB
# nr.080.tar.gz.md5: 0.00 MB
# nr.081.tar.gz: 294.38 MB
# nr.081.tar.gz.md5: 0.00 MB
# nr.082.tar.gz: 2889.53 MB
# nr.082.tar.gz.md5: 0.00 MB
# nr.083.tar.gz: 2688.51 MB
# nr.083.tar.gz.md5: 0.00 MB
# nr.084.tar.gz: 2436.80 MB
# nr.084.tar.gz.md5: 0.00 MB
# nr.085.tar.gz: 2630.02 MB
# nr.085.tar.gz.md5: 0.00 MB
# nr.086.tar.gz: 2985.62 MB
# nr.086.tar.gz.md5: 0.00 MB
# nr.087.tar.gz: 203.48 MB
# nr.087.tar.gz.md5: 0.00 MB
# nr.088.tar.gz: 2985.19 MB
# nr.088.tar.gz.md5: 0.00 MB
# nr.089.tar.gz: 2.94 MB
# nr.089.tar.gz.md5: 0.00 MB
# nr.090.tar.gz: 2983.57 MB
# nr.090.tar.gz.md5: 0.00 MB
# nr.091.tar.gz: 76.02 MB
# nr.091.tar.gz.md5: 0.00 MB
# nr.092.tar.gz: 2983.63 MB
# nr.092.tar.gz.md5: 0.00 MB
# nr.093.tar.gz: 298.56 MB
# nr.093.tar.gz.md5: 0.00 MB
# nr.094.tar.gz: 2985.44 MB
# nr.094.tar.gz.md5: 0.00 MB
# nr.095.tar.gz: 394.75 MB
# nr.095.tar.gz.md5: 0.00 MB
# nr.096.tar.gz: 2315.46 MB
# nr.096.tar.gz.md5: 0.00 MB
# nr.097.tar.gz: 2984.88 MB
# nr.097.tar.gz.md5: 0.00 MB
# nr.098.tar.gz: 692.15 MB
# nr.098.tar.gz.md5: 0.00 MB
# nr.099.tar.gz: 2511.05 MB
# nr.099.tar.gz.md5: 0.00 MB
# nr.100.tar.gz: 2610.33 MB
# nr.100.tar.gz.md5: 0.00 MB
# nr.101.tar.gz: 2636.61 MB
# nr.101.tar.gz.md5: 0.00 MB
# nr.102.tar.gz: 1931.79 MB
# nr.102.tar.gz.md5: 0.00 MB
# nr.103.tar.gz: 2284.52 MB
# nr.103.tar.gz.md5: 0.00 MB
# nr.104.tar.gz: 2985.00 MB
# nr.104.tar.gz.md5: 0.00 MB
# nr.105.tar.gz: 99.70 MB
# nr.105.tar.gz.md5: 0.00 MB
# nr.106.tar.gz: 2973.65 MB
# nr.106.tar.gz.md5: 0.00 MB
# nr.107.tar.gz: 2509.88 MB
# nr.107.tar.gz.md5: 0.00 MB
# nr.108.tar.gz: 2773.98 MB
# nr.108.tar.gz.md5: 0.00 MB
# nr.109.tar.gz: 2783.30 MB
# nr.109.tar.gz.md5: 0.00 MB
# nr.110.tar.gz: 2823.34 MB
# nr.110.tar.gz.md5: 0.00 MB
# nr.111.tar.gz: 2469.51 MB
# nr.111.tar.gz.md5: 0.00 MB
# nr.112.tar.gz: 2920.04 MB
# nr.112.tar.gz.md5: 0.00 MB
# nr.113.tar.gz: 2421.83 MB
# nr.113.tar.gz.md5: 0.00 MB
# nr.114.tar.gz: 2984.77 MB
# nr.114.tar.gz.md5: 0.00 MB
# nr.115.tar.gz: 541.32 MB
# nr.115.tar.gz.md5: 0.00 MB
# nr.116.tar.gz: 977.26 MB
# nr.116.tar.gz.md5: 0.00 MB
# Total size: 268.22 GB
# Download skipped.
