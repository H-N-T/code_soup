# %%
data = [
    "D29K_I36K", "H30K_I36K", "T46K_E62K", "P80K_V83K", "T46K_S185K",
    "V13K_S185K", "E57K_S185K", "D14K_S185K", "H186K_E299K", "R276K_E299K",
    "R291K_E299K", "R296K_E299K", "R136K_A373K", "A212K_A373K", "N137K_A373K",
    "Q370K_A373K", "A42K_E65K", "R61K_E65K", "P80K_R86K", "T19K_H186K",
    "Q49K_H186K", "I36K_E233K", "N67K_G359K", "S132K_G389K", "E233K_G389K",
    "P106K_G389K", "A42K_S66K", "R61K_S66K", "R86K_V89K", "P80K_V89K",
    "D81K_V89K", "Q131K_D135K", "H30K_A192K", "A192K_N235K", "S229K_N235K",
    "E269K_L273K", "E233K_L273K", "P247K_L273K", "G359K_R360K", "E171K_R360K",
    "E62K_N67K", "S66K_N67K", "D135K_R136K", "P106K_R136K", "E62K_A212K",
    "R174K_A212K", "S229K_T237K", "T19K_R276K", "P247K_R276K", "E269K_R302K",
    "H186K_R302K", "P247K_R302K", "V248K_R302K", "T19K_T46K", "E62K_T70K",
    "E65K_T70K", "S66K_T70K", "N67K_T70K", "S132K_N137K", "P106K_N137K",
    "N114K_N137K", "E269K_R291K", "D29K_H30K", "T19K_Q49K", "D23K_Q49K",
    "T46K_Q49K", "R86K_A110K", "I36K_E171K", "A192K_H217K", "A212K_H217K",
    "R174K_T324K", "R360K_D364K", "R86K_N114K", "V89K_N114K", "P106K_N114K",
    "H217K_P247K", "R360K_Q370K", "R136K_Q370K", "Q131K_Q370K", "A395K_A400K",
    "V13K_A400K", "R174K_A400K", "H30K_Q35K", "E171K_R174K", "E228K_S229K",
    "A192K_V248K", "E243K_V248K", "H217K_V248K", "D10K_V401K", "V13K_V401K",
    "A400K_V401K", "D14K_V401K"
]

# Function to extract numbers from the string and return them as integers
def extract_numbers(string):
    # Replace non-digit characters with space and split
    numbers = [int(part.strip('K')) for part in string.split('_')]
    return numbers

# Iterate over data, extract numbers, subtract one from the other
for item in data:
    numbers = extract_numbers(item)
    # Ensure that there are exactly two numbers extracted
    if len(numbers) == 2:
        # Subtract the smaller number from the larger one
        result = abs(numbers[0] - numbers[1])
        print(f"Subtraction result for {item}: {result}")
    else:
        print(f"Error: Could not extract exactly 2 numbers from {item}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-6c9be061505c> in <cell line: 30>()
#      29 # Iterate over data, extract numbers, subtract one from the other
#      30 for item in data:
# ---> 31     numbers = extract_numbers(item)
#      32     # Ensure that there are exactly two numbers extracted
#      33     if len(numbers) == 2:
#
# <ipython-input-4-6c9be061505c> in extract_numbers(string)
#      24 def extract_numbers(string):
#      25     # Replace non-digit characters with space and split
# ---> 26     numbers = [int(part.strip('K')) for part in string.split('_')]
#      27     return numbers
#      28
#
# <ipython-input-4-6c9be061505c> in <listcomp>(.0)
#      24 def extract_numbers(string):
#      25     # Replace non-digit characters with space and split
# ---> 26     numbers = [int(part.strip('K')) for part in string.split('_')]
#      27     return numbers
#      28
#
# ValueError: invalid literal for int() with base 10: 'D29'
