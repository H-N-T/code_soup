# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import glob
import os
import shutil

# %%
! ls
! ls /content/drive/MyDrive/fun_with_code/file_renamer/LIB054
# Out:
# drive  sample_data
# 605136301_01P1_Blank_T7promoterF_A01.ab1  605136301_61P1_D299N_T7promoterF_E08.ab1
# 605136301_02P1_Blank_T7promoterF_B01.ab1  605136301_62P1_H309S_T7promoterF_F08.ab1
# 605136301_03P1_Blank_T7promoterF_C01.ab1  605136301_63P1_Q311E_T7promoterF_G08.ab1
# 605136301_04P1_Blank_T7promoterF_D01.ab1  605136301_64P1_R312A_T7promoterF_H08.ab1
# 605136301_05P1_N3Q_T7promoterF_E01.ab1	  605136301_65P1_G315E_T7promoterF_A09.ab1
# 605136301_06P1_P20N_T7promoterF_F01.ab1   605136301_66P1_G319Q_T7promoterF_B09.ab1
# 605136301_07P1_F21D_T7promoterF_G01.ab1   605136301_67P1_D320K_T7promoterF_C09.ab1
# 605136301_08P1_F21Q_T7promoterF_H01.ab1   605136301_68P1_G323Q_T7promoterF_D09.ab1
# 605136301_09P1_S24D_T7promoterF_A02.ab1   605136301_69P1_I324Q_T7promoterF_E09.ab1
# 605136301_10P1_R28N_T7promoterF_B02.ab1   605136301_70P1_V325T_T7promoterF_F09.ab1
# 605136301_11P1_Y32E_T7promoterF_C02.ab1   605136301_71P1_G328K_T7promoterF_G09.ab1
# ...

# %%
LIB054=glob.glob("/content/drive/MyDrive/fun_with_code/file_renamer/LIB054/*.ab1")

# %%
LIB054
# Out:
# ['/content/drive/MyDrive/fun_with_code/file_renamer/604449901_T7promoterF/604449901_FN2587_T7promoterF_F12.ab1',
#  '/content/drive/MyDrive/fun_with_code/file_renamer/604449901_T7promoterF/604449901_FN2588_T7promoterF_A09.ab1',
#  '/content/drive/MyDrive/fun_with_code/file_renamer/604449901_T7promoterF/604449901_FN2590_T7promoterF_B05.ab1',
#  '/content/drive/MyDrive/fun_with_code/file_renamer/604449901_T7promoterF/604449901_FN2591_T7promoterF_C12.ab1',
#  '/content/drive/MyDrive/fun_with_code/file_renamer/604449901_T7promoterF/604449901_FN2589_T7promoterF_H06.ab1',
#  '/content/drive/MyDrive/fun_with_code/file_renamer/604449901_T7promoterF/604449901_FN2583_T7promoterF_C02.ab1',
#  '/content/drive/MyDrive/fun_with_code/file_renamer/604449901_T7promoterF/604449901_FN2586_T7promoterF_C11.ab1',
#  '/content/drive/MyDrive/fun_with_code/file_renamer/604449901_T7promoterF/604449901_FN2585_T7promoterF_B03.ab1',
# ...

# %%
for file_name in t7forward:
  print("hello",file_name)
# Out:
# hello /content/drive/MyDrive/fun_with_code/file_renamer/604449901_T7promoterF/604449901_FN2587_T7promoterF_F12.ab1
# hello /content/drive/MyDrive/fun_with_code/file_renamer/604449901_T7promoterF/604449901_FN2588_T7promoterF_A09.ab1
# hello /content/drive/MyDrive/fun_with_code/file_renamer/604449901_T7promoterF/604449901_FN2590_T7promoterF_B05.ab1
# hello /content/drive/MyDrive/fun_with_code/file_renamer/604449901_T7promoterF/604449901_FN2591_T7promoterF_C12.ab1
# hello /content/drive/MyDrive/fun_with_code/file_renamer/604449901_T7promoterF/604449901_FN2589_T7promoterF_H06.ab1
# hello /content/drive/MyDrive/fun_with_code/file_renamer/604449901_T7promoterF/604449901_FN2583_T7promoterF_C02.ab1
# hello /content/drive/MyDrive/fun_with_code/file_renamer/604449901_T7promoterF/604449901_FN2586_T7promoterF_C11.ab1
# hello /content/drive/MyDrive/fun_with_code/file_renamer/604449901_T7promoterF/604449901_FN2585_T7promoterF_B03.ab1
# ...

# %%
for file_name in t7forward:
  print("hello",file_name.lower())
# Out:
# hello /content/drive/mydrive/fun_with_code/file_renamer/604449901_t7promoterf/604449901_fn2587_t7promoterf_f12.ab1
# hello /content/drive/mydrive/fun_with_code/file_renamer/604449901_t7promoterf/604449901_fn2588_t7promoterf_a09.ab1
# hello /content/drive/mydrive/fun_with_code/file_renamer/604449901_t7promoterf/604449901_fn2590_t7promoterf_b05.ab1
# hello /content/drive/mydrive/fun_with_code/file_renamer/604449901_t7promoterf/604449901_fn2591_t7promoterf_c12.ab1
# hello /content/drive/mydrive/fun_with_code/file_renamer/604449901_t7promoterf/604449901_fn2589_t7promoterf_h06.ab1
# hello /content/drive/mydrive/fun_with_code/file_renamer/604449901_t7promoterf/604449901_fn2583_t7promoterf_c02.ab1
# hello /content/drive/mydrive/fun_with_code/file_renamer/604449901_t7promoterf/604449901_fn2586_t7promoterf_c11.ab1
# hello /content/drive/mydrive/fun_with_code/file_renamer/604449901_t7promoterf/604449901_fn2585_t7promoterf_b03.ab1
# ...

# %%
for file_name in t7forward:
  print("hello",file_name.split("/")[7])
# Out:
# hello 604449901_FN2587_T7promoterF_F12.ab1
# hello 604449901_FN2588_T7promoterF_A09.ab1
# hello 604449901_FN2590_T7promoterF_B05.ab1
# hello 604449901_FN2591_T7promoterF_C12.ab1
# hello 604449901_FN2589_T7promoterF_H06.ab1
# hello 604449901_FN2583_T7promoterF_C02.ab1
# hello 604449901_FN2586_T7promoterF_C11.ab1
# hello 604449901_FN2585_T7promoterF_B03.ab1
# hello 604449901_FN2584_T7promoterF_A03.ab1
# hello 604449901_FN2582_T7promoterF_E11.ab1
# hello 604449901_FN2581_T7promoterF_H08.ab1
# hello 604449901_FN2578_T7promoterF_G11.ab1
# hello 604449901_FN2577_T7promoterF_C04.ab1
# hello 604449901_FN2580_T7promoterF_B09.ab1
# hello 604449901_FN2579_T7promoterF_B11.ab1
# hello 604449901_FN2576_T7promoterF_D02.ab1
# hello 604449901_EVC_T7promoterF_D01.ab1
# hello 604449901_FN1046_T7promoterF_B01.ab1
# hello 604449901_FN2575_T7promoterF_D03.ab1
# hello 604449901_FN1046_T7promoterF_A01.ab1
# hello 604449901_Blank_T7promoterF_H10.ab1
# hello 604449901_EVC_T7promoterF_C01.ab1
# ...

# %%
for file_name in t7forward:
  print("hello",file_name.split("/")[-1].split("_")[-1:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-16c6e56a3c3d> in <cell line: 1>()
# ----> 1 for file_name in t7forward:
#       2   print("hello",file_name.split("/")[-1].split("_")[-1:])
#
# NameError: name 't7forward' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-16c6e56a3c3d> in <cell line: 1>()
# ----> 1 for file_name in t7forward:
#       2   print("hello",file_name.split("/")[-1].split("_")[-1:])
#
# NameError: name 't7forward' is not defined

# %%
for file_name in t7forward:
  print(file_name.replace("604449901_","").replace("604450201_","").split("/")[-1])
# Out:
# Blank_T7promoterF_B10.ab1
# Blank_T7promoterF_G12.ab1
# Blank_T7promoterF_H10.ab1
# FN1046_T7promoterF_A01.ab1
# Blank_T7promoterF_H03.ab1
# FN2575_T7promoterF_D03.ab1
# FN2578_T7promoterF_G11.ab1
# EVC_T7promoterF_D01.ab1
# Blank_T7promoterF_G04.ab1
# FN2579_T7promoterF_B11.ab1
# EVC_T7promoterF_C01.ab1
# Blank_T7promoterF_F07.ab1
# FN1046_T7promoterF_B01.ab1
# FN2576_T7promoterF_D02.ab1
# Blank_T7promoterF_H12.ab1
# Blank_T7promoterF_H01.ab1
# Blank_T7promoterF_C07.ab1
# FN2577_T7promoterF_C04.ab1
# FN2591_T7promoterF_C12.ab1
# FN2596_T7promoterF_C03.ab1
# FN2587_T7promoterF_F12.ab1
# FN2589_T7promoterF_H06.ab1
# FN2590_T7promoterF_B05.ab1
# FN2602_T7promoterF_F08.ab1
# FN2597_T7promoterF_G02.ab1
# FN2580_T7promoterF_B09.ab1
# FN2601_T7promoterF_G10.ab1
# FN2595_T7promoterF_F01.ab1
# FN2585_T7promoterF_B03.ab1
# FN2582_T7promoterF_E11.ab1
# FN2586_T7promoterF_C11.ab1
# FN2593_T7promoterF_H11.ab1
# FN2592_T7promoterF_D11.ab1
# FN2583_T7promoterF_C02.ab1
# FN2584_T7promoterF_A03.ab1
# ...

# %%
os.makedirs("/content/drive/MyDrive/fun_with_code/file_renamer/output",exist_ok=True)
# Out:
#   File "<ipython-input-29-9b6e285a9c2f>", line 3
#     ls /content/drive/MyDrive/fun_with_code/file_renamer/
#                                                          ^
# SyntaxError: invalid syntax

# %%
for filename in t7forward:
  destination="/content/drive/MyDrive/fun_with_code/file_renamer/output/"+filename.replace("604449901_","").replace("604450201_","").split("/")[-1]
  shutil.copyfile(filename,destination)

# %%
! ls /content/drive/MyDrive/fun_with_code/file_renamer/output/
# Out:
# Blank_T7promoterF_B10.ab1    FN2594_T7promoterF_A10.ab1   FN2630_T7promoterF_B06.ab1
# Blank_T7promoterF_C07.ab1    FN2594_T7terminateR_A10.ab1  FN2630_T7terminateR_B06.ab1
# Blank_T7promoterF_F07.ab1    FN2595_T7promoterF_F01.ab1   FN2632_T7promoterF_B12.ab1
# Blank_T7promoterF_G04.ab1    FN2595_T7terminateR_F01.ab1  FN2632_T7terminateR_B12.ab1
# Blank_T7promoterF_G12.ab1    FN2596_T7promoterF_C03.ab1   FN2633_T7promoterF_E09.ab1
# Blank_T7promoterF_H01.ab1    FN2596_T7terminateR_C03.ab1  FN2633_T7terminateR_E09.ab1
# Blank_T7promoterF_H03.ab1    FN2597_T7promoterF_G02.ab1   FN2634_T7promoterF_F06.ab1
# Blank_T7promoterF_H10.ab1    FN2597_T7terminateR_G02.ab1  FN2634_T7terminateR_F06.ab1
# Blank_T7promoterF_H12.ab1    FN2598_T7promoterF_C08.ab1   FN2636_T7promoterF_H07.ab1
# Blank_T7terminateR_B10.ab1   FN2598_T7terminateR_C08.ab1  FN2636_T7terminateR_H07.ab1
# Blank_T7terminateR_C07.ab1   FN2600_T7promoterF_E05.ab1   FN2637_T7promoterF_G06.ab1
# ...

# %%
shutil.copyfile(de
# Out:
# /content/drive/MyDrive/fun_with_code/file_renamer/output/FN2659_T7terminateR_G03.ab1
