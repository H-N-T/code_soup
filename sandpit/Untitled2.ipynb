# %%
library_name = "Lib062" # @param {type:"string"}
input_folder = "/content/drive/My Drive/fun_with_code/file_renamer/Lib062" # @param {type:"string"}
output_folder = "/content/drive/My Drive/fun_with_code/file_renamer/LIB062_output" # @param {type:"string"}
fwd_order_number = "606521901" # @param {type:"string"}
rev_order_number = "606521902" # @param {type:"string"}

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import glob
import os
import shutil

# %%
#Generation of list containing .ab1 input sequence files
#replace LIB_NAME with your library name
library_name=glob.glob(input_folder + '/*.ab1')

# %%
#Creation of new folder for the output sequences
os.makedirs(output_folder,exist_ok=True)

# %%
#Generation of new files excluding the Source Bioscience order number
#replace LIB_NAME with your library name from above
#replace [forward order number] with the forward order number
#replace [reverse order number] with the reverse order number
for file_name in library_name:
  destination="output_folder"+file_name.replace("606521901_","").replace("606521902_","").split("/")[-1]
  shutil.copyfile(file_name,destination)
