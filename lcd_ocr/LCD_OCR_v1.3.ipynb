# %%
import cv2
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

class Segments:
    def __init__(self):
        self.flags = []
        self.segments = self.create_segments()

    def create_segments(self):
        segments = [
            [[0.4, 0.7], [0.025, 0.225]],
            [[0.35, 0.65], [0.45, 0.65]],
            [[0.325, 0.625], [0.8, 1]],
            [[0.15, 0.45], [0.2, 0.4]],
            [[0.125, 0.425], [0.6, .8]],
            [[0.7, 1], [0.2, 0.4]],
            [[0.65, 0.95], [0.6, .8]]
        ]
        return segments

    def digest(self, number, segment_threshold):
        self.flags = []
        h, w = number.shape[:2]
        for a in range(len(self.segments)):
            seg = self.segments[a]
            xl, xh = seg[0]
            yl, yh = seg[1]
            xl = int(xl * w)
            xh = int(xh * w)
            yl = int(yl * h)
            yh = int(yh * h)
            sw = xh - xl
            sh = yh - yl
            if sw == 0 or sh == 0:
                continue
            count = np.count_nonzero(number[yl:yh, xl:xh] == 255)
            if count / (sh * sw) > segment_threshold:
                self.flags.append(a)
            print(f"Segment {a}: Count = {count}, Area = {sh * sw}, Ratio = {count / (sh * sw):.2f}")
            cv2.rectangle(number, (xl, yl), (xh, yh), (128, 128, 128), 1)

    def getNum(self):
        print(f"Flags: {self.flags}")
        if self.flags == [0, 2, 3, 4, 5, 6]:
            return 0
        if self.flags == [5, 6]:
            return 1
        if self.flags == [0, 1, 2, 4, 5]:
            return 2
        if self.flags == [0, 1, 2, 5, 6]:
            return 3
        if self.flags == [1, 3, 5, 6]:
            return 4
        if self.flags == [0, 1, 2, 3, 6]:
            return 5
        if self.flags == [0, 1, 2, 3, 4, 6]:
            return 6
        if self.flags == [0, 5, 6]:
            return 7
        if self.flags == [0, 1, 2, 3, 4, 5, 6]:
            return 8
        if self.flags == [0, 1, 2, 3, 5, 6]:
            return 9
        if self.flags == []:
            return 0
        return -1

def process_video(video_path, output_csv, output_dir, frame_skip, binary_threshold, segment_threshold):
    video_path = os.path.normpath(video_path.replace('"', ''))
    output_csv = os.path.normpath(output_csv.replace('"', ''))
    output_dir = os.path.normpath(output_dir.replace('"', ''))

    cap = cv2.VideoCapture(video_path)
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    frame_list = []
    frame_numbers = []
    model = Segments()

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for i in range(0, frame_count, frame_skip):
        cap.set(cv2.CAP_PROP_POS_FRAMES, i)
        ret, frame = cap.read()
        if not ret:
            break

        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        _, binary = cv2.threshold(gray, binary_threshold, 255, cv2.THRESH_BINARY_INV)
        height, width = binary.shape
        segment_width = width // 4
        segments = [binary[:, j*segment_width:(j+1)*segment_width] for j in range(4)]
        detected_numbers = []

        for j, segment in enumerate(segments):
            segment_copy = segment.copy()
            model.digest(segment_copy, segment_threshold)
            number = model.getNum()
            detected_numbers.append(number if number != -1 else '_')

            # Annotate the segment with the detected number
            cv2.putText(segment_copy, str(number), (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 0, 0), 2)

            # Save the annotated segment
            annotated_segment_path = os.path.join(output_dir, f"frame_{i:04d}_segment_{j}.png")
            cv2.imwrite(annotated_segment_path, segment_copy)

        combined_result = ''.join(map(str, detected_numbers))
        frame_list.append(int(combined_result) / 100 if combined_result.isdigit() else 0)
        frame_numbers.append(i)

    cap.release()
    cv2.destroyAllWindows()

    df = pd.DataFrame(list(enumerate(frame_list, start=1)), columns=['Frame Number', 'Detected Numbers'])
    df.to_csv(output_csv, index=False)
    print(f"Output saved to {output_csv}")

    # Plotting output number for each frame against the frame number
    plt.figure(figsize=(10, 5))
    plt.plot(frame_numbers, frame_list, marker='o')
    plt.xlabel('Frame Number')
    plt.ylabel('Output Number / 100')
    plt.title('Output Number for Each Frame (Divided by 100)')
    plt.grid(True)

    # Save the plot as a PNG file to a specific path
    plot_output_path = os.path.join(output_dir, "output_plot.png")
    plt.savefig(plot_output_path)
    print(f"Plot saved to {plot_output_path}")

    #plt.show()

def process_multiple_videos(video_paths, output_dir_base, frame_skip, binary_threshold, segment_threshold):
    output_dir_base = os.path.normpath(output_dir_base.replace('"', ''))
    for video_path in video_paths:
        video_path = os.path.normpath(video_path.replace('"', ''))
        base_filename = os.path.splitext(os.path.basename(video_path))[0]
        output_csv = os.path.join(output_dir_base, f"output_data_{base_filename}.csv")
        output_dir = os.path.join(output_dir_base, f"processed_frames_{base_filename}")
        process_video(video_path, output_csv, output_dir, frame_skip, binary_threshold, segment_threshold)

def get_int_input(prompt):
    while True:
        try:
            return int(input(prompt))
        except ValueError:
            print("Please enter a valid integer.")

def get_float_input(prompt):
    while True:
        try:
            return float(input(prompt))
        except ValueError:
            print("Please enter a valid float.")

# User Inputs
video_paths = input("Enter video paths separated by spaces: ").split()
output_dir_base = os.path.normpath(input("Enter the base output directory: ").replace('"', ''))

frame_skip = get_int_input("Skip every X frames: ")
binary_threshold = get_int_input("Image processing threshold (default is 75): ")
segment_threshold = get_float_input("Segment recognition threshold (default is 0.2): ")

# Main code
process_multiple_videos(video_paths, output_dir_base, frame_skip, binary_threshold, segment_threshold)
# Out:
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 701, Area = 1755, Ratio = 0.40
# Segment 6: Count = 714, Area = 1755, Ratio = 0.41
# Flags: [5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 3, Area = 1755, Ratio = 0.00
# Segment 2: Count = 23, Area = 1755, Ratio = 0.01
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 717, Area = 1755, Ratio = 0.41
# Segment 6: Count = 715, Area = 1755, Ratio = 0.41
# Flags: [5, 6]
# Segment 0: Count = 810, Area = 1755, Ratio = 0.46
# Segment 1: Count = 2, Area = 1755, Ratio = 0.00
# Segment 2: Count = 702, Area = 1755, Ratio = 0.40
# Segment 3: Count = 757, Area = 1755, Ratio = 0.43
# Segment 4: Count = 702, Area = 1755, Ratio = 0.40
# Segment 5: Count = 763, Area = 1755, Ratio = 0.43
# Segment 6: Count = 749, Area = 1755, Ratio = 0.43
# Flags: [0, 2, 3, 4, 5, 6]
# Segment 0: Count = 804, Area = 1755, Ratio = 0.46
# Segment 1: Count = 802, Area = 1755, Ratio = 0.46
# Segment 2: Count = 658, Area = 1755, Ratio = 0.37
# Segment 3: Count = 773, Area = 1755, Ratio = 0.44
# Segment 4: Count = 689, Area = 1755, Ratio = 0.39
# Segment 5: Count = 764, Area = 1755, Ratio = 0.44
# Segment 6: Count = 616, Area = 1755, Ratio = 0.35
# Flags: [0, 1, 2, 3, 4, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 771, Area = 1755, Ratio = 0.44
# Segment 1: Count = 774, Area = 1755, Ratio = 0.44
# Segment 2: Count = 694, Area = 1755, Ratio = 0.40
# Segment 3: Count = 737, Area = 1755, Ratio = 0.42
# Segment 4: Count = 647, Area = 1755, Ratio = 0.37
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 710, Area = 1755, Ratio = 0.40
# Flags: [0, 1, 2, 3, 4, 6]
# Segment 0: Count = 816, Area = 1755, Ratio = 0.46
# Segment 1: Count = 2, Area = 1755, Ratio = 0.00
# Segment 2: Count = 699, Area = 1755, Ratio = 0.40
# Segment 3: Count = 759, Area = 1755, Ratio = 0.43
# Segment 4: Count = 704, Area = 1755, Ratio = 0.40
# Segment 5: Count = 764, Area = 1755, Ratio = 0.44
# Segment 6: Count = 754, Area = 1755, Ratio = 0.43
# Flags: [0, 2, 3, 4, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 8, Area = 1755, Ratio = 0.00
# Segment 2: Count = 41, Area = 1755, Ratio = 0.02
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 767, Area = 1755, Ratio = 0.44
# Segment 6: Count = 649, Area = 1755, Ratio = 0.37
# Flags: [5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 771, Area = 1755, Ratio = 0.44
# Segment 1: Count = 770, Area = 1755, Ratio = 0.44
# Segment 2: Count = 695, Area = 1755, Ratio = 0.40
# Segment 3: Count = 735, Area = 1755, Ratio = 0.42
# Segment 4: Count = 648, Area = 1755, Ratio = 0.37
# Segment 5: Count = 701, Area = 1755, Ratio = 0.40
# Segment 6: Count = 683, Area = 1755, Ratio = 0.39
# Flags: [0, 1, 2, 3, 4, 5, 6]
# Segment 0: Count = 809, Area = 1755, Ratio = 0.46
# Segment 1: Count = 2, Area = 1755, Ratio = 0.00
# Segment 2: Count = 699, Area = 1755, Ratio = 0.40
# Segment 3: Count = 760, Area = 1755, Ratio = 0.43
# Segment 4: Count = 698, Area = 1755, Ratio = 0.40
# Segment 5: Count = 768, Area = 1755, Ratio = 0.44
# Segment 6: Count = 752, Area = 1755, Ratio = 0.43
# Flags: [0, 2, 3, 4, 5, 6]
# Segment 0: Count = 821, Area = 1755, Ratio = 0.47
# Segment 1: Count = 8, Area = 1755, Ratio = 0.00
# Segment 2: Count = 43, Area = 1755, Ratio = 0.02
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 771, Area = 1755, Ratio = 0.44
# Segment 6: Count = 643, Area = 1755, Ratio = 0.37
# Flags: [0, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 771, Area = 1755, Ratio = 0.44
# Segment 1: Count = 767, Area = 1755, Ratio = 0.44
# Segment 2: Count = 696, Area = 1755, Ratio = 0.40
# Segment 3: Count = 738, Area = 1755, Ratio = 0.42
# Segment 4: Count = 647, Area = 1755, Ratio = 0.37
# Segment 5: Count = 701, Area = 1755, Ratio = 0.40
# Segment 6: Count = 673, Area = 1755, Ratio = 0.38
# Flags: [0, 1, 2, 3, 4, 5, 6]
# Segment 0: Count = 815, Area = 1755, Ratio = 0.46
# Segment 1: Count = 2, Area = 1755, Ratio = 0.00
# Segment 2: Count = 25, Area = 1755, Ratio = 0.01
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 766, Area = 1755, Ratio = 0.44
# Segment 6: Count = 747, Area = 1755, Ratio = 0.43
# Flags: [0, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 8, Area = 1755, Ratio = 0.00
# Segment 2: Count = 44, Area = 1755, Ratio = 0.03
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 772, Area = 1755, Ratio = 0.44
# Segment 6: Count = 656, Area = 1755, Ratio = 0.37
# Flags: [5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 792, Area = 1755, Ratio = 0.45
# Segment 1: Count = 773, Area = 1755, Ratio = 0.44
# Segment 2: Count = 703, Area = 1755, Ratio = 0.40
# Segment 3: Count = 749, Area = 1755, Ratio = 0.43
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 700, Area = 1755, Ratio = 0.40
# Segment 6: Count = 655, Area = 1755, Ratio = 0.37
# Flags: [0, 1, 2, 3, 5, 6]
# Segment 0: Count = 804, Area = 1755, Ratio = 0.46
# Segment 1: Count = 2, Area = 1755, Ratio = 0.00
# Segment 2: Count = 686, Area = 1755, Ratio = 0.39
# Segment 3: Count = 756, Area = 1755, Ratio = 0.43
# Segment 4: Count = 689, Area = 1755, Ratio = 0.39
# Segment 5: Count = 781, Area = 1755, Ratio = 0.45
# Segment 6: Count = 741, Area = 1755, Ratio = 0.42
# Flags: [0, 2, 3, 4, 5, 6]
# Segment 0: Count = 814, Area = 1755, Ratio = 0.46
# Segment 1: Count = 795, Area = 1755, Ratio = 0.45
# Segment 2: Count = 666, Area = 1755, Ratio = 0.38
# Segment 3: Count = 758, Area = 1755, Ratio = 0.43
# Segment 4: Count = 669, Area = 1755, Ratio = 0.38
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 631, Area = 1755, Ratio = 0.36
# Flags: [0, 1, 2, 3, 4, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 775, Area = 1755, Ratio = 0.44
# Segment 1: Count = 772, Area = 1755, Ratio = 0.44
# Segment 2: Count = 713, Area = 1755, Ratio = 0.41
# Segment 3: Count = 751, Area = 1755, Ratio = 0.43
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 707, Area = 1755, Ratio = 0.40
# Segment 6: Count = 701, Area = 1755, Ratio = 0.40
# Flags: [0, 1, 2, 3, 5, 6]
# Segment 0: Count = 814, Area = 1755, Ratio = 0.46
# Segment 1: Count = 787, Area = 1755, Ratio = 0.45
# Segment 2: Count = 678, Area = 1755, Ratio = 0.39
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 780, Area = 1755, Ratio = 0.44
# Segment 5: Count = 746, Area = 1755, Ratio = 0.43
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: [0, 1, 2, 4, 5]
# Segment 0: Count = 825, Area = 1755, Ratio = 0.47
# Segment 1: Count = 9, Area = 1755, Ratio = 0.01
# Segment 2: Count = 44, Area = 1755, Ratio = 0.03
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 778, Area = 1755, Ratio = 0.44
# Segment 6: Count = 662, Area = 1755, Ratio = 0.38
# Flags: [0, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 790, Area = 1755, Ratio = 0.45
# Segment 1: Count = 773, Area = 1755, Ratio = 0.44
# Segment 2: Count = 714, Area = 1755, Ratio = 0.41
# Segment 3: Count = 753, Area = 1755, Ratio = 0.43
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 710, Area = 1755, Ratio = 0.40
# Segment 6: Count = 696, Area = 1755, Ratio = 0.40
# Flags: [0, 1, 2, 3, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 778, Area = 1755, Ratio = 0.44
# Segment 2: Count = 25, Area = 1755, Ratio = 0.01
# Segment 3: Count = 833, Area = 1755, Ratio = 0.47
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 745, Area = 1755, Ratio = 0.42
# Segment 6: Count = 722, Area = 1755, Ratio = 0.41
# Flags: [1, 3, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 10, Area = 1755, Ratio = 0.01
# Segment 2: Count = 44, Area = 1755, Ratio = 0.03
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 774, Area = 1755, Ratio = 0.44
# Segment 6: Count = 634, Area = 1755, Ratio = 0.36
# Flags: [5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 779, Area = 1755, Ratio = 0.44
# Segment 1: Count = 768, Area = 1755, Ratio = 0.44
# Segment 2: Count = 708, Area = 1755, Ratio = 0.40
# Segment 3: Count = 749, Area = 1755, Ratio = 0.43
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 711, Area = 1755, Ratio = 0.41
# Segment 6: Count = 689, Area = 1755, Ratio = 0.39
# Flags: [0, 1, 2, 3, 5, 6]
# Segment 0: Count = 816, Area = 1755, Ratio = 0.46
# Segment 1: Count = 788, Area = 1755, Ratio = 0.45
# Segment 2: Count = 706, Area = 1755, Ratio = 0.40
# Segment 3: Count = 774, Area = 1755, Ratio = 0.44
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 732, Area = 1755, Ratio = 0.42
# Flags: [0, 1, 2, 3, 6]
# Segment 0: Count = 813, Area = 1755, Ratio = 0.46
# Segment 1: Count = 797, Area = 1755, Ratio = 0.45
# Segment 2: Count = 626, Area = 1755, Ratio = 0.36
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 699, Area = 1755, Ratio = 0.40
# Segment 5: Count = 767, Area = 1755, Ratio = 0.44
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: [0, 1, 2, 4, 5]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 780, Area = 1755, Ratio = 0.44
# Segment 1: Count = 771, Area = 1755, Ratio = 0.44
# Segment 2: Count = 710, Area = 1755, Ratio = 0.40
# Segment 3: Count = 755, Area = 1755, Ratio = 0.43
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 711, Area = 1755, Ratio = 0.41
# Segment 6: Count = 702, Area = 1755, Ratio = 0.40
# Flags: [0, 1, 2, 3, 5, 6]
# Segment 0: Count = 810, Area = 1755, Ratio = 0.46
# Segment 1: Count = 789, Area = 1755, Ratio = 0.45
# Segment 2: Count = 707, Area = 1755, Ratio = 0.40
# Segment 3: Count = 758, Area = 1755, Ratio = 0.43
# Segment 4: Count = 693, Area = 1755, Ratio = 0.39
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 739, Area = 1755, Ratio = 0.42
# Flags: [0, 1, 2, 3, 4, 6]
# Segment 0: Count = 814, Area = 1755, Ratio = 0.46
# Segment 1: Count = 797, Area = 1755, Ratio = 0.45
# Segment 2: Count = 624, Area = 1755, Ratio = 0.36
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 713, Area = 1755, Ratio = 0.41
# Segment 5: Count = 765, Area = 1755, Ratio = 0.44
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: [0, 1, 2, 4, 5]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 782, Area = 1755, Ratio = 0.45
# Segment 1: Count = 770, Area = 1755, Ratio = 0.44
# Segment 2: Count = 715, Area = 1755, Ratio = 0.41
# Segment 3: Count = 761, Area = 1755, Ratio = 0.43
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 710, Area = 1755, Ratio = 0.40
# Segment 6: Count = 708, Area = 1755, Ratio = 0.40
# Flags: [0, 1, 2, 3, 5, 6]
# Segment 0: Count = 819, Area = 1755, Ratio = 0.47
# Segment 1: Count = 2, Area = 1755, Ratio = 0.00
# Segment 2: Count = 25, Area = 1755, Ratio = 0.01
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 770, Area = 1755, Ratio = 0.44
# Segment 6: Count = 751, Area = 1755, Ratio = 0.43
# Flags: [0, 5, 6]
# Segment 0: Count = 806, Area = 1755, Ratio = 0.46
# Segment 1: Count = 9, Area = 1755, Ratio = 0.01
# Segment 2: Count = 660, Area = 1755, Ratio = 0.38
# Segment 3: Count = 763, Area = 1755, Ratio = 0.43
# Segment 4: Count = 690, Area = 1755, Ratio = 0.39
# Segment 5: Count = 769, Area = 1755, Ratio = 0.44
# Segment 6: Count = 636, Area = 1755, Ratio = 0.36
# Flags: [0, 2, 3, 4, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 779, Area = 1755, Ratio = 0.44
# Segment 1: Count = 770, Area = 1755, Ratio = 0.44
# Segment 2: Count = 712, Area = 1755, Ratio = 0.41
# Segment 3: Count = 748, Area = 1755, Ratio = 0.43
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 708, Area = 1755, Ratio = 0.40
# Segment 6: Count = 692, Area = 1755, Ratio = 0.39
# Flags: [0, 1, 2, 3, 5, 6]
# Segment 0: Count = 819, Area = 1755, Ratio = 0.47
# Segment 1: Count = 2, Area = 1755, Ratio = 0.00
# Segment 2: Count = 27, Area = 1755, Ratio = 0.02
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 771, Area = 1755, Ratio = 0.44
# Segment 6: Count = 746, Area = 1755, Ratio = 0.43
# Flags: [0, 5, 6]
# Segment 0: Count = 820, Area = 1755, Ratio = 0.47
# Segment 1: Count = 9, Area = 1755, Ratio = 0.01
# Segment 2: Count = 42, Area = 1755, Ratio = 0.02
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 776, Area = 1755, Ratio = 0.44
# Segment 6: Count = 658, Area = 1755, Ratio = 0.37
# Flags: [0, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 782, Area = 1755, Ratio = 0.45
# Segment 1: Count = 764, Area = 1755, Ratio = 0.44
# Segment 2: Count = 704, Area = 1755, Ratio = 0.40
# Segment 3: Count = 746, Area = 1755, Ratio = 0.43
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 697, Area = 1755, Ratio = 0.40
# Segment 6: Count = 663, Area = 1755, Ratio = 0.38
# Flags: [0, 1, 2, 3, 5, 6]
# Segment 0: Count = 811, Area = 1755, Ratio = 0.46
# Segment 1: Count = 782, Area = 1755, Ratio = 0.45
# Segment 2: Count = 702, Area = 1755, Ratio = 0.40
# Segment 3: Count = 752, Area = 1755, Ratio = 0.43
# Segment 4: Count = 695, Area = 1755, Ratio = 0.40
# Segment 5: Count = 741, Area = 1755, Ratio = 0.42
# Segment 6: Count = 726, Area = 1755, Ratio = 0.41
# Flags: [0, 1, 2, 3, 4, 5, 6]
# Segment 0: Count = 812, Area = 1755, Ratio = 0.46
# Segment 1: Count = 805, Area = 1755, Ratio = 0.46
# Segment 2: Count = 661, Area = 1755, Ratio = 0.38
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 760, Area = 1755, Ratio = 0.43
# Segment 6: Count = 630, Area = 1755, Ratio = 0.36
# Flags: [0, 1, 2, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 780, Area = 1755, Ratio = 0.44
# Segment 1: Count = 771, Area = 1755, Ratio = 0.44
# Segment 2: Count = 707, Area = 1755, Ratio = 0.40
# Segment 3: Count = 744, Area = 1755, Ratio = 0.42
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 697, Area = 1755, Ratio = 0.40
# Flags: [0, 1, 2, 3, 6]
# Segment 0: Count = 819, Area = 1755, Ratio = 0.47
# Segment 1: Count = 3, Area = 1755, Ratio = 0.00
# Segment 2: Count = 29, Area = 1755, Ratio = 0.02
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 761, Area = 1755, Ratio = 0.43
# Segment 6: Count = 737, Area = 1755, Ratio = 0.42
# Flags: [0, 5, 6]
# Segment 0: Count = 817, Area = 1755, Ratio = 0.47
# Segment 1: Count = 796, Area = 1755, Ratio = 0.45
# Segment 2: Count = 669, Area = 1755, Ratio = 0.38
# Segment 3: Count = 764, Area = 1755, Ratio = 0.44
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 754, Area = 1755, Ratio = 0.43
# Segment 6: Count = 603, Area = 1755, Ratio = 0.34
# Flags: [0, 1, 2, 3, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 780, Area = 1755, Ratio = 0.44
# Segment 1: Count = 774, Area = 1755, Ratio = 0.44
# Segment 2: Count = 694, Area = 1755, Ratio = 0.40
# Segment 3: Count = 734, Area = 1755, Ratio = 0.42
# Segment 4: Count = 646, Area = 1755, Ratio = 0.37
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 712, Area = 1755, Ratio = 0.41
# Flags: [0, 1, 2, 3, 4, 6]
# Segment 0: Count = 815, Area = 1755, Ratio = 0.46
# Segment 1: Count = 788, Area = 1755, Ratio = 0.45
# Segment 2: Count = 725, Area = 1755, Ratio = 0.41
# Segment 3: Count = 773, Area = 1755, Ratio = 0.44
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 725, Area = 1755, Ratio = 0.41
# Flags: [0, 1, 2, 3, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 796, Area = 1755, Ratio = 0.45
# Segment 2: Count = 41, Area = 1755, Ratio = 0.02
# Segment 3: Count = 791, Area = 1755, Ratio = 0.45
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 764, Area = 1755, Ratio = 0.44
# Segment 6: Count = 609, Area = 1755, Ratio = 0.35
# Flags: [1, 3, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 786, Area = 1755, Ratio = 0.45
# Segment 1: Count = 4, Area = 1755, Ratio = 0.00
# Segment 2: Count = 24, Area = 1755, Ratio = 0.01
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 719, Area = 1755, Ratio = 0.41
# Segment 6: Count = 725, Area = 1755, Ratio = 0.41
# Flags: [0, 5, 6]
# Segment 0: Count = 817, Area = 1755, Ratio = 0.47
# Segment 1: Count = 781, Area = 1755, Ratio = 0.45
# Segment 2: Count = 721, Area = 1755, Ratio = 0.41
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 743, Area = 1755, Ratio = 0.42
# Segment 6: Count = 721, Area = 1755, Ratio = 0.41
# Flags: [0, 1, 2, 5, 6]
# Segment 0: Count = 821, Area = 1755, Ratio = 0.47
# Segment 1: Count = 10, Area = 1755, Ratio = 0.01
# Segment 2: Count = 46, Area = 1755, Ratio = 0.03
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 766, Area = 1755, Ratio = 0.44
# Segment 6: Count = 620, Area = 1755, Ratio = 0.35
# Flags: [0, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 786, Area = 1755, Ratio = 0.45
# Segment 1: Count = 4, Area = 1755, Ratio = 0.00
# Segment 2: Count = 25, Area = 1755, Ratio = 0.01
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 724, Area = 1755, Ratio = 0.41
# Segment 6: Count = 734, Area = 1755, Ratio = 0.42
# Flags: [0, 5, 6]
# Segment 0: Count = 814, Area = 1755, Ratio = 0.46
# Segment 1: Count = 786, Area = 1755, Ratio = 0.45
# Segment 2: Count = 728, Area = 1755, Ratio = 0.41
# Segment 3: Count = 765, Area = 1755, Ratio = 0.44
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 742, Area = 1755, Ratio = 0.42
# Segment 6: Count = 738, Area = 1755, Ratio = 0.42
# Flags: [0, 1, 2, 3, 5, 6]
# Segment 0: Count = 821, Area = 1755, Ratio = 0.47
# Segment 1: Count = 10, Area = 1755, Ratio = 0.01
# Segment 2: Count = 44, Area = 1755, Ratio = 0.03
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 770, Area = 1755, Ratio = 0.44
# Segment 6: Count = 627, Area = 1755, Ratio = 0.36
# Flags: [0, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 776, Area = 1755, Ratio = 0.44
# Segment 1: Count = 762, Area = 1755, Ratio = 0.43
# Segment 2: Count = 690, Area = 1755, Ratio = 0.39
# Segment 3: Count = 735, Area = 1755, Ratio = 0.42
# Segment 4: Count = 650, Area = 1755, Ratio = 0.37
# Segment 5: Count = 692, Area = 1755, Ratio = 0.39
# Segment 6: Count = 672, Area = 1755, Ratio = 0.38
# Flags: [0, 1, 2, 3, 4, 5, 6]
# Segment 0: Count = 818, Area = 1755, Ratio = 0.47
# Segment 1: Count = 783, Area = 1755, Ratio = 0.45
# Segment 2: Count = 683, Area = 1755, Ratio = 0.39
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 761, Area = 1755, Ratio = 0.43
# Segment 5: Count = 744, Area = 1755, Ratio = 0.42
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: [0, 1, 2, 4, 5]
# Segment 0: Count = 810, Area = 1755, Ratio = 0.46
# Segment 1: Count = 803, Area = 1755, Ratio = 0.46
# Segment 2: Count = 671, Area = 1755, Ratio = 0.38
# Segment 3: Count = 766, Area = 1755, Ratio = 0.44
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 762, Area = 1755, Ratio = 0.43
# Segment 6: Count = 634, Area = 1755, Ratio = 0.36
# Flags: [0, 1, 2, 3, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 786, Area = 1755, Ratio = 0.45
# Segment 1: Count = 772, Area = 1755, Ratio = 0.44
# Segment 2: Count = 697, Area = 1755, Ratio = 0.40
# Segment 3: Count = 738, Area = 1755, Ratio = 0.42
# Segment 4: Count = 649, Area = 1755, Ratio = 0.37
# Segment 5: Count = 705, Area = 1755, Ratio = 0.40
# Segment 6: Count = 678, Area = 1755, Ratio = 0.39
# Flags: [0, 1, 2, 3, 4, 5, 6]
# Segment 0: Count = 812, Area = 1755, Ratio = 0.46
# Segment 1: Count = 791, Area = 1755, Ratio = 0.45
# Segment 2: Count = 726, Area = 1755, Ratio = 0.41
# Segment 3: Count = 782, Area = 1755, Ratio = 0.45
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 742, Area = 1755, Ratio = 0.42
# Flags: [0, 1, 2, 3, 6]
# Segment 0: Count = 807, Area = 1755, Ratio = 0.46
# Segment 1: Count = 10, Area = 1755, Ratio = 0.01
# Segment 2: Count = 662, Area = 1755, Ratio = 0.38
# Segment 3: Count = 761, Area = 1755, Ratio = 0.43
# Segment 4: Count = 678, Area = 1755, Ratio = 0.39
# Segment 5: Count = 775, Area = 1755, Ratio = 0.44
# Segment 6: Count = 649, Area = 1755, Ratio = 0.37
# Flags: [0, 2, 3, 4, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 788, Area = 1755, Ratio = 0.45
# Segment 1: Count = 769, Area = 1755, Ratio = 0.44
# Segment 2: Count = 692, Area = 1755, Ratio = 0.39
# Segment 3: Count = 737, Area = 1755, Ratio = 0.42
# Segment 4: Count = 640, Area = 1755, Ratio = 0.36
# Segment 5: Count = 706, Area = 1755, Ratio = 0.40
# Segment 6: Count = 671, Area = 1755, Ratio = 0.38
# Flags: [0, 1, 2, 3, 4, 5, 6]
# Segment 0: Count = 812, Area = 1755, Ratio = 0.46
# Segment 1: Count = 787, Area = 1755, Ratio = 0.45
# Segment 2: Count = 717, Area = 1755, Ratio = 0.41
# Segment 3: Count = 755, Area = 1755, Ratio = 0.43
# Segment 4: Count = 685, Area = 1755, Ratio = 0.39
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 737, Area = 1755, Ratio = 0.42
# Flags: [0, 1, 2, 3, 4, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 809, Area = 1755, Ratio = 0.46
# Segment 2: Count = 45, Area = 1755, Ratio = 0.03
# Segment 3: Count = 819, Area = 1755, Ratio = 0.47
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 763, Area = 1755, Ratio = 0.43
# Segment 6: Count = 611, Area = 1755, Ratio = 0.35
# Flags: [1, 3, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 791, Area = 1755, Ratio = 0.45
# Segment 1: Count = 772, Area = 1755, Ratio = 0.44
# Segment 2: Count = 701, Area = 1755, Ratio = 0.40
# Segment 3: Count = 738, Area = 1755, Ratio = 0.42
# Segment 4: Count = 646, Area = 1755, Ratio = 0.37
# Segment 5: Count = 706, Area = 1755, Ratio = 0.40
# Segment 6: Count = 691, Area = 1755, Ratio = 0.39
# Flags: [0, 1, 2, 3, 4, 5, 6]
# Segment 0: Count = 814, Area = 1755, Ratio = 0.46
# Segment 1: Count = 3, Area = 1755, Ratio = 0.00
# Segment 2: Count = 28, Area = 1755, Ratio = 0.02
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 770, Area = 1755, Ratio = 0.44
# Segment 6: Count = 743, Area = 1755, Ratio = 0.42
# Flags: [0, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 807, Area = 1755, Ratio = 0.46
# Segment 2: Count = 41, Area = 1755, Ratio = 0.02
# Segment 3: Count = 820, Area = 1755, Ratio = 0.47
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 756, Area = 1755, Ratio = 0.43
# Segment 6: Count = 603, Area = 1755, Ratio = 0.34
# Flags: [1, 3, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 782, Area = 1755, Ratio = 0.45
# Segment 1: Count = 770, Area = 1755, Ratio = 0.44
# Segment 2: Count = 693, Area = 1755, Ratio = 0.39
# Segment 3: Count = 737, Area = 1755, Ratio = 0.42
# Segment 4: Count = 645, Area = 1755, Ratio = 0.37
# Segment 5: Count = 708, Area = 1755, Ratio = 0.40
# Segment 6: Count = 685, Area = 1755, Ratio = 0.39
# Flags: [0, 1, 2, 3, 4, 5, 6]
# Segment 0: Count = 808, Area = 1755, Ratio = 0.46
# Segment 1: Count = 777, Area = 1755, Ratio = 0.44
# Segment 2: Count = 707, Area = 1755, Ratio = 0.40
# Segment 3: Count = 753, Area = 1755, Ratio = 0.43
# Segment 4: Count = 680, Area = 1755, Ratio = 0.39
# Segment 5: Count = 739, Area = 1755, Ratio = 0.42
# Segment 6: Count = 713, Area = 1755, Ratio = 0.41
# Flags: [0, 1, 2, 3, 4, 5, 6]
# Segment 0: Count = 816, Area = 1755, Ratio = 0.46
# Segment 1: Count = 796, Area = 1755, Ratio = 0.45
# Segment 2: Count = 622, Area = 1755, Ratio = 0.35
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 708, Area = 1755, Ratio = 0.40
# Segment 5: Count = 761, Area = 1755, Ratio = 0.43
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: [0, 1, 2, 4, 5]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 790, Area = 1755, Ratio = 0.45
# Segment 1: Count = 767, Area = 1755, Ratio = 0.44
# Segment 2: Count = 689, Area = 1755, Ratio = 0.39
# Segment 3: Count = 735, Area = 1755, Ratio = 0.42
# Segment 4: Count = 635, Area = 1755, Ratio = 0.36
# Segment 5: Count = 706, Area = 1755, Ratio = 0.40
# Segment 6: Count = 675, Area = 1755, Ratio = 0.38
# Flags: [0, 1, 2, 3, 4, 5, 6]
# Segment 0: Count = 799, Area = 1755, Ratio = 0.46
# Segment 1: Count = 777, Area = 1755, Ratio = 0.44
# Segment 2: Count = 701, Area = 1755, Ratio = 0.40
# Segment 3: Count = 748, Area = 1755, Ratio = 0.43
# Segment 4: Count = 675, Area = 1755, Ratio = 0.38
# Segment 5: Count = 739, Area = 1755, Ratio = 0.42
# Segment 6: Count = 708, Area = 1755, Ratio = 0.40
# Flags: [0, 1, 2, 3, 4, 5, 6]
# Segment 0: Count = 812, Area = 1755, Ratio = 0.46
# Segment 1: Count = 801, Area = 1755, Ratio = 0.46
# Segment 2: Count = 667, Area = 1755, Ratio = 0.38
# Segment 3: Count = 769, Area = 1755, Ratio = 0.44
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 757, Area = 1755, Ratio = 0.43
# Segment 6: Count = 593, Area = 1755, Ratio = 0.34
# Flags: [0, 1, 2, 3, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 787, Area = 1755, Ratio = 0.45
# Segment 1: Count = 772, Area = 1755, Ratio = 0.44
# Segment 2: Count = 694, Area = 1755, Ratio = 0.40
# Segment 3: Count = 737, Area = 1755, Ratio = 0.42
# Segment 4: Count = 643, Area = 1755, Ratio = 0.37
# Segment 5: Count = 711, Area = 1755, Ratio = 0.41
# Segment 6: Count = 692, Area = 1755, Ratio = 0.39
# Flags: [0, 1, 2, 3, 4, 5, 6]
# Segment 0: Count = 812, Area = 1755, Ratio = 0.46
# Segment 1: Count = 778, Area = 1755, Ratio = 0.44
# Segment 2: Count = 727, Area = 1755, Ratio = 0.41
# Segment 3: Count = 759, Area = 1755, Ratio = 0.43
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 742, Area = 1755, Ratio = 0.42
# Segment 6: Count = 719, Area = 1755, Ratio = 0.41
# Flags: [0, 1, 2, 3, 5, 6]
# Segment 0: Count = 806, Area = 1755, Ratio = 0.46
# Segment 1: Count = 810, Area = 1755, Ratio = 0.46
# Segment 2: Count = 662, Area = 1755, Ratio = 0.38
# Segment 3: Count = 760, Area = 1755, Ratio = 0.43
# Segment 4: Count = 664, Area = 1755, Ratio = 0.38
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 611, Area = 1755, Ratio = 0.35
# Flags: [0, 1, 2, 3, 4, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 794, Area = 1755, Ratio = 0.45
# Segment 1: Count = 772, Area = 1755, Ratio = 0.44
# Segment 2: Count = 710, Area = 1755, Ratio = 0.40
# Segment 3: Count = 746, Area = 1755, Ratio = 0.43
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 709, Area = 1755, Ratio = 0.40
# Segment 6: Count = 695, Area = 1755, Ratio = 0.40
# Flags: [0, 1, 2, 3, 5, 6]
# Segment 0: Count = 810, Area = 1755, Ratio = 0.46
# Segment 1: Count = 3, Area = 1755, Ratio = 0.00
# Segment 2: Count = 706, Area = 1755, Ratio = 0.40
# Segment 3: Count = 753, Area = 1755, Ratio = 0.43
# Segment 4: Count = 697, Area = 1755, Ratio = 0.40
# Segment 5: Count = 754, Area = 1755, Ratio = 0.43
# Segment 6: Count = 741, Area = 1755, Ratio = 0.42
# Flags: [0, 2, 3, 4, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 9, Area = 1755, Ratio = 0.01
# Segment 2: Count = 45, Area = 1755, Ratio = 0.03
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 771, Area = 1755, Ratio = 0.44
# Segment 6: Count = 618, Area = 1755, Ratio = 0.35
# Flags: [5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 786, Area = 1755, Ratio = 0.45
# Segment 1: Count = 776, Area = 1755, Ratio = 0.44
# Segment 2: Count = 718, Area = 1755, Ratio = 0.41
# Segment 3: Count = 752, Area = 1755, Ratio = 0.43
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 701, Area = 1755, Ratio = 0.40
# Flags: [0, 1, 2, 3, 6]
# Segment 0: Count = 813, Area = 1755, Ratio = 0.46
# Segment 1: Count = 777, Area = 1755, Ratio = 0.44
# Segment 2: Count = 711, Area = 1755, Ratio = 0.41
# Segment 3: Count = 753, Area = 1755, Ratio = 0.43
# Segment 4: Count = 684, Area = 1755, Ratio = 0.39
# Segment 5: Count = 743, Area = 1755, Ratio = 0.42
# Segment 6: Count = 712, Area = 1755, Ratio = 0.41
# Flags: [0, 1, 2, 3, 4, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 10, Area = 1755, Ratio = 0.01
# Segment 2: Count = 44, Area = 1755, Ratio = 0.03
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 764, Area = 1755, Ratio = 0.44
# Segment 6: Count = 621, Area = 1755, Ratio = 0.35
# Flags: [5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 781, Area = 1755, Ratio = 0.45
# Segment 1: Count = 779, Area = 1755, Ratio = 0.44
# Segment 2: Count = 696, Area = 1755, Ratio = 0.40
# Segment 3: Count = 738, Area = 1755, Ratio = 0.42
# Segment 4: Count = 650, Area = 1755, Ratio = 0.37
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 710, Area = 1755, Ratio = 0.40
# Flags: [0, 1, 2, 3, 4, 6]
# Segment 0: Count = 815, Area = 1755, Ratio = 0.46
# Segment 1: Count = 785, Area = 1755, Ratio = 0.45
# Segment 2: Count = 691, Area = 1755, Ratio = 0.39
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 761, Area = 1755, Ratio = 0.43
# Segment 5: Count = 751, Area = 1755, Ratio = 0.43
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: [0, 1, 2, 4, 5]
# Segment 0: Count = 806, Area = 1755, Ratio = 0.46
# Segment 1: Count = 805, Area = 1755, Ratio = 0.46
# Segment 2: Count = 659, Area = 1755, Ratio = 0.38
# Segment 3: Count = 758, Area = 1755, Ratio = 0.43
# Segment 4: Count = 666, Area = 1755, Ratio = 0.38
# Segment 5: Count = 757, Area = 1755, Ratio = 0.43
# Segment 6: Count = 604, Area = 1755, Ratio = 0.34
# Flags: [0, 1, 2, 3, 4, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 786, Area = 1755, Ratio = 0.45
# Segment 1: Count = 781, Area = 1755, Ratio = 0.45
# Segment 2: Count = 696, Area = 1755, Ratio = 0.40
# Segment 3: Count = 742, Area = 1755, Ratio = 0.42
# Segment 4: Count = 657, Area = 1755, Ratio = 0.37
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 721, Area = 1755, Ratio = 0.41
# Flags: [0, 1, 2, 3, 4, 6]
# Segment 0: Count = 816, Area = 1755, Ratio = 0.46
# Segment 1: Count = 3, Area = 1755, Ratio = 0.00
# Segment 2: Count = 25, Area = 1755, Ratio = 0.01
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 769, Area = 1755, Ratio = 0.44
# Segment 6: Count = 745, Area = 1755, Ratio = 0.42
# Flags: [0, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 9, Area = 1755, Ratio = 0.01
# Segment 2: Count = 47, Area = 1755, Ratio = 0.03
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 769, Area = 1755, Ratio = 0.44
# Segment 6: Count = 624, Area = 1755, Ratio = 0.36
# Flags: [5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 795, Area = 1755, Ratio = 0.45
# Segment 1: Count = 4, Area = 1755, Ratio = 0.00
# Segment 2: Count = 24, Area = 1755, Ratio = 0.01
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 716, Area = 1755, Ratio = 0.41
# Segment 6: Count = 700, Area = 1755, Ratio = 0.40
# Flags: [0, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 4, Area = 1755, Ratio = 0.00
# Segment 2: Count = 27, Area = 1755, Ratio = 0.02
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 751, Area = 1755, Ratio = 0.43
# Segment 6: Count = 733, Area = 1755, Ratio = 0.42
# Flags: [5, 6]
# Segment 0: Count = 811, Area = 1755, Ratio = 0.46
# Segment 1: Count = 10, Area = 1755, Ratio = 0.01
# Segment 2: Count = 44, Area = 1755, Ratio = 0.03
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 761, Area = 1755, Ratio = 0.43
# Segment 6: Count = 594, Area = 1755, Ratio = 0.34
# Flags: [0, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 791, Area = 1755, Ratio = 0.45
# Segment 1: Count = 4, Area = 1755, Ratio = 0.00
# Segment 2: Count = 24, Area = 1755, Ratio = 0.01
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 717, Area = 1755, Ratio = 0.41
# Segment 6: Count = 685, Area = 1755, Ratio = 0.39
# Flags: [0, 5, 6]
# Segment 0: Count = 813, Area = 1755, Ratio = 0.46
# Segment 1: Count = 783, Area = 1755, Ratio = 0.45
# Segment 2: Count = 707, Area = 1755, Ratio = 0.40
# Segment 3: Count = 753, Area = 1755, Ratio = 0.43
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 709, Area = 1755, Ratio = 0.40
# Flags: [0, 1, 2, 3, 6]
# Segment 0: Count = 807, Area = 1755, Ratio = 0.46
# Segment 1: Count = 803, Area = 1755, Ratio = 0.46
# Segment 2: Count = 659, Area = 1755, Ratio = 0.38
# Segment 3: Count = 754, Area = 1755, Ratio = 0.43
# Segment 4: Count = 653, Area = 1755, Ratio = 0.37
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 598, Area = 1755, Ratio = 0.34
# Flags: [0, 1, 2, 3, 4, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 795, Area = 1755, Ratio = 0.45
# Segment 1: Count = 4, Area = 1755, Ratio = 0.00
# Segment 2: Count = 23, Area = 1755, Ratio = 0.01
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 712, Area = 1755, Ratio = 0.41
# Segment 6: Count = 690, Area = 1755, Ratio = 0.39
# Flags: [0, 5, 6]
# Segment 0: Count = 804, Area = 1755, Ratio = 0.46
# Segment 1: Count = 775, Area = 1755, Ratio = 0.44
# Segment 2: Count = 703, Area = 1755, Ratio = 0.40
# Segment 3: Count = 750, Area = 1755, Ratio = 0.43
# Segment 4: Count = 668, Area = 1755, Ratio = 0.38
# Segment 5: Count = 738, Area = 1755, Ratio = 0.42
# Segment 6: Count = 695, Area = 1755, Ratio = 0.40
# Flags: [0, 1, 2, 3, 4, 5, 6]
# Segment 0: Count = 810, Area = 1755, Ratio = 0.46
# Segment 1: Count = 808, Area = 1755, Ratio = 0.46
# Segment 2: Count = 667, Area = 1755, Ratio = 0.38
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 745, Area = 1755, Ratio = 0.42
# Segment 6: Count = 587, Area = 1755, Ratio = 0.33
# Flags: [0, 1, 2, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 773, Area = 1755, Ratio = 0.44
# Segment 1: Count = 765, Area = 1755, Ratio = 0.44
# Segment 2: Count = 688, Area = 1755, Ratio = 0.39
# Segment 3: Count = 734, Area = 1755, Ratio = 0.42
# Segment 4: Count = 614, Area = 1755, Ratio = 0.35
# Segment 5: Count = 700, Area = 1755, Ratio = 0.40
# Segment 6: Count = 637, Area = 1755, Ratio = 0.36
# Flags: [0, 1, 2, 3, 4, 5, 6]
# Segment 0: Count = 811, Area = 1755, Ratio = 0.46
# Segment 1: Count = 3, Area = 1755, Ratio = 0.00
# Segment 2: Count = 699, Area = 1755, Ratio = 0.40
# Segment 3: Count = 749, Area = 1755, Ratio = 0.43
# Segment 4: Count = 670, Area = 1755, Ratio = 0.38
# Segment 5: Count = 755, Area = 1755, Ratio = 0.43
# Segment 6: Count = 720, Area = 1755, Ratio = 0.41
# Flags: [0, 2, 3, 4, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 10, Area = 1755, Ratio = 0.01
# Segment 2: Count = 45, Area = 1755, Ratio = 0.03
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 760, Area = 1755, Ratio = 0.43
# Segment 6: Count = 604, Area = 1755, Ratio = 0.34
# Flags: [5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 783, Area = 1755, Ratio = 0.45
# Segment 1: Count = 761, Area = 1755, Ratio = 0.43
# Segment 2: Count = 690, Area = 1755, Ratio = 0.39
# Segment 3: Count = 734, Area = 1755, Ratio = 0.42
# Segment 4: Count = 622, Area = 1755, Ratio = 0.35
# Segment 5: Count = 705, Area = 1755, Ratio = 0.40
# Segment 6: Count = 641, Area = 1755, Ratio = 0.37
# Flags: [0, 1, 2, 3, 4, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 3, Area = 1755, Ratio = 0.00
# Segment 2: Count = 29, Area = 1755, Ratio = 0.02
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 748, Area = 1755, Ratio = 0.43
# Segment 6: Count = 717, Area = 1755, Ratio = 0.41
# Flags: [5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 803, Area = 1755, Ratio = 0.46
# Segment 2: Count = 44, Area = 1755, Ratio = 0.03
# Segment 3: Count = 773, Area = 1755, Ratio = 0.44
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 749, Area = 1755, Ratio = 0.43
# Segment 6: Count = 586, Area = 1755, Ratio = 0.33
# Flags: [1, 3, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 782, Area = 1755, Ratio = 0.45
# Segment 1: Count = 767, Area = 1755, Ratio = 0.44
# Segment 2: Count = 689, Area = 1755, Ratio = 0.39
# Segment 3: Count = 729, Area = 1755, Ratio = 0.42
# Segment 4: Count = 616, Area = 1755, Ratio = 0.35
# Segment 5: Count = 704, Area = 1755, Ratio = 0.40
# Segment 6: Count = 648, Area = 1755, Ratio = 0.37
# Flags: [0, 1, 2, 3, 4, 5, 6]
# Segment 0: Count = 814, Area = 1755, Ratio = 0.46
# Segment 1: Count = 776, Area = 1755, Ratio = 0.44
# Segment 2: Count = 676, Area = 1755, Ratio = 0.39
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 713, Area = 1755, Ratio = 0.41
# Segment 5: Count = 740, Area = 1755, Ratio = 0.42
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: [0, 1, 2, 4, 5]
# Segment 0: Count = 806, Area = 1755, Ratio = 0.46
# Segment 1: Count = 803, Area = 1755, Ratio = 0.46
# Segment 2: Count = 659, Area = 1755, Ratio = 0.38
# Segment 3: Count = 757, Area = 1755, Ratio = 0.43
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 596, Area = 1755, Ratio = 0.34
# Flags: [0, 1, 2, 3, 6]
# ...
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 770, Area = 1755, Ratio = 0.44
# Segment 1: Count = 772, Area = 1755, Ratio = 0.44
# Segment 2: Count = 691, Area = 1755, Ratio = 0.39
# Segment 3: Count = 734, Area = 1755, Ratio = 0.42
# Segment 4: Count = 640, Area = 1755, Ratio = 0.36
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 670, Area = 1755, Ratio = 0.38
# Flags: [0, 1, 2, 3, 4, 6]
# Segment 0: Count = 811, Area = 1755, Ratio = 0.46
# Segment 1: Count = 783, Area = 1755, Ratio = 0.45
# Segment 2: Count = 695, Area = 1755, Ratio = 0.40
# Segment 3: Count = 754, Area = 1755, Ratio = 0.43
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 738, Area = 1755, Ratio = 0.42
# Segment 6: Count = 692, Area = 1755, Ratio = 0.39
# Flags: [0, 1, 2, 3, 5, 6]
# Segment 0: Count = 824, Area = 1755, Ratio = 0.47
# Segment 1: Count = 14, Area = 1755, Ratio = 0.01
# Segment 2: Count = 48, Area = 1755, Ratio = 0.03
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 756, Area = 1755, Ratio = 0.43
# Segment 6: Count = 589, Area = 1755, Ratio = 0.34
# Flags: [0, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 786, Area = 1755, Ratio = 0.45
# Segment 1: Count = 3, Area = 1755, Ratio = 0.00
# Segment 2: Count = 21, Area = 1755, Ratio = 0.01
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 715, Area = 1755, Ratio = 0.41
# Segment 6: Count = 714, Area = 1755, Ratio = 0.41
# Flags: [0, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 3, Area = 1755, Ratio = 0.00
# Segment 2: Count = 28, Area = 1755, Ratio = 0.02
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 744, Area = 1755, Ratio = 0.42
# Segment 6: Count = 720, Area = 1755, Ratio = 0.41
# Flags: [5, 6]
# Segment 0: Count = 816, Area = 1755, Ratio = 0.46
# Segment 1: Count = 12, Area = 1755, Ratio = 0.01
# Segment 2: Count = 47, Area = 1755, Ratio = 0.03
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 750, Area = 1755, Ratio = 0.43
# Segment 6: Count = 593, Area = 1755, Ratio = 0.34
# Flags: [0, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 785, Area = 1755, Ratio = 0.45
# Segment 1: Count = 4, Area = 1755, Ratio = 0.00
# Segment 2: Count = 25, Area = 1755, Ratio = 0.01
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 716, Area = 1755, Ratio = 0.41
# Segment 6: Count = 707, Area = 1755, Ratio = 0.40
# Flags: [0, 5, 6]
# Segment 0: Count = 816, Area = 1755, Ratio = 0.46
# Segment 1: Count = 782, Area = 1755, Ratio = 0.45
# Segment 2: Count = 705, Area = 1755, Ratio = 0.40
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 737, Area = 1755, Ratio = 0.42
# Segment 6: Count = 671, Area = 1755, Ratio = 0.38
# Flags: [0, 1, 2, 5, 6]
# Segment 0: Count = 808, Area = 1755, Ratio = 0.46
# Segment 1: Count = 798, Area = 1755, Ratio = 0.45
# Segment 2: Count = 663, Area = 1755, Ratio = 0.38
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 748, Area = 1755, Ratio = 0.43
# Segment 6: Count = 585, Area = 1755, Ratio = 0.33
# Flags: [0, 1, 2, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 787, Area = 1755, Ratio = 0.45
# Segment 1: Count = 4, Area = 1755, Ratio = 0.00
# Segment 2: Count = 25, Area = 1755, Ratio = 0.01
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 719, Area = 1755, Ratio = 0.41
# Segment 6: Count = 703, Area = 1755, Ratio = 0.40
# Flags: [0, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 778, Area = 1755, Ratio = 0.44
# Segment 2: Count = 28, Area = 1755, Ratio = 0.02
# Segment 3: Count = 788, Area = 1755, Ratio = 0.45
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 739, Area = 1755, Ratio = 0.42
# Segment 6: Count = 670, Area = 1755, Ratio = 0.38
# Flags: [1, 3, 5, 6]
# Segment 0: Count = 817, Area = 1755, Ratio = 0.47
# Segment 1: Count = 12, Area = 1755, Ratio = 0.01
# Segment 2: Count = 47, Area = 1755, Ratio = 0.03
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 755, Area = 1755, Ratio = 0.43
# Segment 6: Count = 588, Area = 1755, Ratio = 0.34
# Flags: [0, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 791, Area = 1755, Ratio = 0.45
# Segment 1: Count = 4, Area = 1755, Ratio = 0.00
# Segment 2: Count = 24, Area = 1755, Ratio = 0.01
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 732, Area = 1755, Ratio = 0.42
# Segment 6: Count = 714, Area = 1755, Ratio = 0.41
# Flags: [0, 5, 6]
# Segment 0: Count = 806, Area = 1755, Ratio = 0.46
# Segment 1: Count = 782, Area = 1755, Ratio = 0.45
# Segment 2: Count = 702, Area = 1755, Ratio = 0.40
# Segment 3: Count = 756, Area = 1755, Ratio = 0.43
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 704, Area = 1755, Ratio = 0.40
# Flags: [0, 1, 2, 3, 6]
# Segment 0: Count = 814, Area = 1755, Ratio = 0.46
# Segment 1: Count = 793, Area = 1755, Ratio = 0.45
# Segment 2: Count = 662, Area = 1755, Ratio = 0.38
# Segment 3: Count = 762, Area = 1755, Ratio = 0.43
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 751, Area = 1755, Ratio = 0.43
# Segment 6: Count = 588, Area = 1755, Ratio = 0.34
# Flags: [0, 1, 2, 3, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 799, Area = 1755, Ratio = 0.46
# Segment 1: Count = 4, Area = 1755, Ratio = 0.00
# Segment 2: Count = 25, Area = 1755, Ratio = 0.01
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 729, Area = 1755, Ratio = 0.42
# Segment 6: Count = 713, Area = 1755, Ratio = 0.41
# Flags: [0, 5, 6]
# Segment 0: Count = 810, Area = 1755, Ratio = 0.46
# Segment 1: Count = 783, Area = 1755, Ratio = 0.45
# Segment 2: Count = 691, Area = 1755, Ratio = 0.39
# Segment 3: Count = 748, Area = 1755, Ratio = 0.43
# Segment 4: Count = 675, Area = 1755, Ratio = 0.38
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 711, Area = 1755, Ratio = 0.41
# Flags: [0, 1, 2, 3, 4, 6]
# Segment 0: Count = 809, Area = 1755, Ratio = 0.46
# Segment 1: Count = 796, Area = 1755, Ratio = 0.45
# Segment 2: Count = 658, Area = 1755, Ratio = 0.37
# Segment 3: Count = 754, Area = 1755, Ratio = 0.43
# Segment 4: Count = 652, Area = 1755, Ratio = 0.37
# Segment 5: Count = 757, Area = 1755, Ratio = 0.43
# Segment 6: Count = 591, Area = 1755, Ratio = 0.34
# Flags: [0, 1, 2, 3, 4, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 789, Area = 1755, Ratio = 0.45
# Segment 1: Count = 4, Area = 1755, Ratio = 0.00
# Segment 2: Count = 24, Area = 1755, Ratio = 0.01
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 719, Area = 1755, Ratio = 0.41
# Segment 6: Count = 712, Area = 1755, Ratio = 0.41
# Flags: [0, 5, 6]
# Segment 0: Count = 814, Area = 1755, Ratio = 0.46
# Segment 1: Count = 3, Area = 1755, Ratio = 0.00
# Segment 2: Count = 29, Area = 1755, Ratio = 0.02
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 743, Area = 1755, Ratio = 0.42
# Segment 6: Count = 714, Area = 1755, Ratio = 0.41
# Flags: [0, 5, 6]
# Segment 0: Count = 815, Area = 1755, Ratio = 0.46
# Segment 1: Count = 802, Area = 1755, Ratio = 0.46
# Segment 2: Count = 661, Area = 1755, Ratio = 0.38
# Segment 3: Count = 757, Area = 1755, Ratio = 0.43
# Segment 4: Count = 642, Area = 1755, Ratio = 0.37
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 593, Area = 1755, Ratio = 0.34
# Flags: [0, 1, 2, 3, 4, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 794, Area = 1755, Ratio = 0.45
# Segment 1: Count = 4, Area = 1755, Ratio = 0.00
# Segment 2: Count = 24, Area = 1755, Ratio = 0.01
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 715, Area = 1755, Ratio = 0.41
# Segment 6: Count = 694, Area = 1755, Ratio = 0.40
# Flags: [0, 5, 6]
# Segment 0: Count = 808, Area = 1755, Ratio = 0.46
# Segment 1: Count = 785, Area = 1755, Ratio = 0.45
# Segment 2: Count = 697, Area = 1755, Ratio = 0.40
# Segment 3: Count = 751, Area = 1755, Ratio = 0.43
# Segment 4: Count = 671, Area = 1755, Ratio = 0.38
# Segment 5: Count = 733, Area = 1755, Ratio = 0.42
# Segment 6: Count = 694, Area = 1755, Ratio = 0.40
# Flags: [0, 1, 2, 3, 4, 5, 6]
# Segment 0: Count = 819, Area = 1755, Ratio = 0.47
# Segment 1: Count = 801, Area = 1755, Ratio = 0.46
# Segment 2: Count = 663, Area = 1755, Ratio = 0.38
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 750, Area = 1755, Ratio = 0.43
# Segment 6: Count = 581, Area = 1755, Ratio = 0.33
# Flags: [0, 1, 2, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 793, Area = 1755, Ratio = 0.45
# Segment 1: Count = 4, Area = 1755, Ratio = 0.00
# Segment 2: Count = 24, Area = 1755, Ratio = 0.01
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 720, Area = 1755, Ratio = 0.41
# Segment 6: Count = 696, Area = 1755, Ratio = 0.40
# Flags: [0, 5, 6]
# Segment 0: Count = 803, Area = 1755, Ratio = 0.46
# Segment 1: Count = 780, Area = 1755, Ratio = 0.44
# Segment 2: Count = 689, Area = 1755, Ratio = 0.39
# Segment 3: Count = 752, Area = 1755, Ratio = 0.43
# Segment 4: Count = 674, Area = 1755, Ratio = 0.38
# Segment 5: Count = 733, Area = 1755, Ratio = 0.42
# Segment 6: Count = 699, Area = 1755, Ratio = 0.40
# Flags: [0, 1, 2, 3, 4, 5, 6]
# Segment 0: Count = 809, Area = 1755, Ratio = 0.46
# Segment 1: Count = 798, Area = 1755, Ratio = 0.45
# Segment 2: Count = 664, Area = 1755, Ratio = 0.38
# Segment 3: Count = 761, Area = 1755, Ratio = 0.43
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 746, Area = 1755, Ratio = 0.43
# Segment 6: Count = 586, Area = 1755, Ratio = 0.33
# Flags: [0, 1, 2, 3, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 787, Area = 1755, Ratio = 0.45
# Segment 1: Count = 3, Area = 1755, Ratio = 0.00
# Segment 2: Count = 23, Area = 1755, Ratio = 0.01
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 720, Area = 1755, Ratio = 0.41
# Segment 6: Count = 717, Area = 1755, Ratio = 0.41
# Flags: [0, 5, 6]
# Segment 0: Count = 807, Area = 1755, Ratio = 0.46
# Segment 1: Count = 778, Area = 1755, Ratio = 0.44
# Segment 2: Count = 697, Area = 1755, Ratio = 0.40
# Segment 3: Count = 762, Area = 1755, Ratio = 0.43
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 741, Area = 1755, Ratio = 0.42
# Segment 6: Count = 719, Area = 1755, Ratio = 0.41
# Flags: [0, 1, 2, 3, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 793, Area = 1755, Ratio = 0.45
# Segment 2: Count = 43, Area = 1755, Ratio = 0.02
# Segment 3: Count = 781, Area = 1755, Ratio = 0.45
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 759, Area = 1755, Ratio = 0.43
# Segment 6: Count = 602, Area = 1755, Ratio = 0.34
# Flags: [1, 3, 5, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 0, Area = 1755, Ratio = 0.00
# Segment 2: Count = 0, Area = 1755, Ratio = 0.00
# Segment 3: Count = 0, Area = 1755, Ratio = 0.00
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 0, Area = 1755, Ratio = 0.00
# Flags: []
# Segment 0: Count = 773, Area = 1755, Ratio = 0.44
# Segment 1: Count = 767, Area = 1755, Ratio = 0.44
# Segment 2: Count = 696, Area = 1755, Ratio = 0.40
# Segment 3: Count = 741, Area = 1755, Ratio = 0.42
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 0, Area = 1755, Ratio = 0.00
# Segment 6: Count = 679, Area = 1755, Ratio = 0.39
# Flags: [0, 1, 2, 3, 6]
# Segment 0: Count = 0, Area = 1755, Ratio = 0.00
# Segment 1: Count = 780, Area = 1755, Ratio = 0.44
# Segment 2: Count = 25, Area = 1755, Ratio = 0.01
# Segment 3: Count = 773, Area = 1755, Ratio = 0.44
# Segment 4: Count = 0, Area = 1755, Ratio = 0.00
# Segment 5: Count = 737, Area = 1755, Ratio = 0.42
# Segment 6: Count = 690, Area = 1755, Ratio = 0.39
# Flags: [1, 3, 5, 6]
# Segment 0: Count = 803, Area = 1755, Ratio = 0.46
# Segment 1: Count = 9, Area = 1755, Ratio = 0.01
# Segment 2: Count = 654, Area = 1755, Ratio = 0.37
# Segment 3: Count = 753, Area = 1755, Ratio = 0.43
# Segment 4: Count = 646, Area = 1755, Ratio = 0.37
# Segment 5: Count = 757, Area = 1755, Ratio = 0.43
# Segment 6: Count = 598, Area = 1755, Ratio = 0.34
# Flags: [0, 2, 3, 4, 5, 6]
# Output saved to C:\Users\Henry\Downloads\OCR_test\output_data_IMG_3011.csv
# Plot saved to C:\Users\Henry\Downloads\OCR_test\processed_frames_IMG_3011\output_plot.png
