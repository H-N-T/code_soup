# %% [markdown]
# Notes on version:
#
# *   No ChemPy
# *   Closed system (no gas input but no molar count)
# *   No [H2CO3] production
# *   Assumes constant pressure of 1 atm
# *   Runs until mass transfer rate drops below 1 umol/minute
# *   No time count

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants
R = 8.314  # Universal gas constant, J/(mol·K)
print(f"R: {R} J/(mol·K)")
T = 298.15  # Temperature in Kelvin (25°C)
print(f"T: {T} K")
H_atm = 29.4  # Henry's Law constant for CO2 in water at 25°C, atm·m³/mol
print(f"H_atm: {H_atm} atm·m³/mol")
H_Pa = H_atm * 101325  # Henry's Law constant in Pa·m³/mol
print(f"H_Pa: {H_Pa} Pa·m³/mol")
k = 1e-6  # Mass transfer coefficient, m/s
print(f"k: {k} m/s")
hydration_level = 0.1  # 10%
print(f"hydration_level: {hydration_level}")
rho_concrete = 2400  # Density of concrete, kg/m³
print(f"rho_concrete: {rho_concrete} kg/m³")
rho_water = 1000  # Density of water, kg/m³
print(f"rho_water: {rho_water} kg/m³")
wetting_coefficient = 0.8  # Wetting coefficient
print(f"wetting_coefficient: {wetting_coefficient}")
P_total_atm = 1.0  # Total pressure in atm (standard pressure)
P_total_Pa = P_total_atm * 101325  # Total pressure in Pa (standard pressure)
print(f"P_total_atm: {P_total_atm} atm")
print(f"P_total_Pa: {P_total_Pa} Pa")
percentage_CO2 = 0.04  # Percentage of CO2 in air (4%)
print(f"percentage_CO2: {percentage_CO2}")
V = 1.0  # Volume in m³
print(f"V: {V} m³")
# Out:
# R: 8.314 J/(mol·K)
# T: 298.15 K
# H_atm: 29.4 atm·m³/mol
# H_Pa: 2978955.0 Pa·m³/mol
# k: 1e-06 m/s
# hydration_level: 0.1
# rho_concrete: 2400 kg/m³
# rho_water: 1000 kg/m³
# wetting_coefficient: 0.8
# P_total_atm: 1.0 atm
# P_total_Pa: 101325.0 Pa
# percentage_CO2: 0.04
# V: 1.0 m³

# %%
# Function to calculate total surface area
def calculate_surface_area_normal_distribution(mean_diameter, std_deviation, min_diameter, max_diameter, reactor_volume, void_fraction, num_samples=100000):
    diameters = np.random.normal(loc=mean_diameter, scale=std_deviation, size=num_samples)
    diameters = diameters[(diameters >= min_diameter) & (diameters <= max_diameter)]
    radii = diameters / 2
    volumes = (4/3) * np.pi * (radii ** 3)
    total_particle_volume = reactor_volume * (1 - void_fraction)
    total_volume_of_sampled_particles = np.sum(volumes)
    scaling_factor = total_particle_volume / total_volume_of_sampled_particles
    surface_areas = 4 * np.pi * (radii ** 2)
    total_surface_area = np.sum(surface_areas * scaling_factor)
    return total_surface_area

# Example usage:
mean_diameter = 0.01  # Mean diameter of 1 cm in meters
print(f"mean_diameter: {mean_diameter} m")
std_deviation = 0.002  # Standard deviation of 0.2 cm in meters
print(f"std_deviation: {std_deviation} m")
min_diameter = 0.005  # Minimum diameter of 0.5 cm in meters
print(f"min_diameter: {min_diameter} m")
max_diameter = 0.015  # Maximum diameter of 1.5 cm in meters
print(f"max_diameter: {max_diameter} m")
reactor_volume = 1.0  # 1 cubic meter
print(f"reactor_volume: {reactor_volume} m³")
void_fraction = 0.4  # 40% void fraction
print(f"void_fraction: {void_fraction}")

total_surface_area = calculate_surface_area_normal_distribution(
    mean_diameter, std_deviation, min_diameter, max_diameter, reactor_volume, void_fraction
)

# Total surface area
print("total_surface_area:", f"{total_surface_area:.4g}", "m²")

# Available surface area for gas exchange
available_surface_area = total_surface_area * wetting_coefficient
print("available_surface_area:", f"{available_surface_area:.4g}", "m²")
# Out:
# mean_diameter: 0.01 m
# std_deviation: 0.002 m
# min_diameter: 0.005 m
# max_diameter: 0.015 m
# reactor_volume: 1.0 m³
# void_fraction: 0.4
# total_surface_area: 336.3 m²
# available_surface_area: 269 m²

# %%
# Calculate the partial pressure of CO2 in air
P_CO2 = percentage_CO2 * P_total_Pa
print(f"P_CO2: {P_CO2:.4g} Pa")

# Convert partial pressure to concentration in mol/m³
n_CO2 = P_CO2 / (R * T) * V
concentration_CO2 = n_CO2 / V
print("n_CO2:", f"{n_CO2:.4g}", "mol")
print("concentration_CO2:", f"{concentration_CO2:.4g}", "mol/m³")

# Solid phase volume and mass
solid_volume = reactor_volume * (1 - void_fraction)
solid_mass = solid_volume * rho_concrete
print("solid_volume:", f"{solid_volume:.4g}", "m³")
print("solid_mass:", f"{solid_mass:.4g}", "kg")

# Liquid phase mass and volume
liquid_mass = hydration_level * solid_mass
liquid_volume = liquid_mass / rho_water
print("liquid_mass:", f"{liquid_mass:.4g}", "kg")
print("liquid_volume:", f"{liquid_volume:.4g}", "m³")

# Gas phase volume
gas_volume = reactor_volume - solid_volume - liquid_volume
print("gas_volume:", f"{gas_volume:.4g}", "m³")

# Initial partial pressure of CO2 in the gas phase
P_CO2_initial = concentration_CO2 * R * T
print("P_CO2_initial:", f"{P_CO2_initial:.4g}", "Pa")

# Initial equilibrium concentration of CO2 in the liquid phase using Henry's Law and standard CO2 concentration in air
C_l_initial_eq = ((P_total_Pa * 0.0004) / H_Pa)*1000
print("C_l_initial_eq:", f"{C_l_initial_eq:.4g}", "mol/m³")
print(f"P_CO2: {(P_total_Pa * 0.0004):.4g} Pa")


# CO2 solubility
C_sol_initial = (P_CO2 / H_Pa)*1000
print("C_sol_initial:", f"{C_sol_initial:.4g}", "mol/m³")

# Initial concentration of CO2 in the gas phase
C_g_initial = P_CO2_initial / (R * T)
print("C_g_initial:", f"{C_g_initial:.4g}", "mol/m³")


# Lists to store results
time_points = [0]  # Initial time
C_g_values = [C_g_initial]  # Initial gas phase CO2 concentration
C_l_values = [C_l_initial_eq]  # Initial liquid phase CO2 concentration
C_sol_values = [C_sol_initial]  # CO2 solubiliy
mass_transfer_rates = []  # Mass transfer rates
CO2_transferred = []  # CO2 transferred from gas to liquid phase
# Out:
# P_CO2: 4053 Pa
# n_CO2: 1.635 mol
# concentration_CO2: 1.635 mol/m³
# solid_volume: 0.6 m³
# solid_mass: 1440 kg
# liquid_mass: 144 kg
# liquid_volume: 0.144 m³
# gas_volume: 0.256 m³
# P_CO2_initial: 4053 Pa
# C_l_initial_eq: 0.01361 mol/m³
# P_CO2: 40.53 Pa
# C_sol_initial: 1.361 mol/m³
# C_g_initial: 1.635 mol/m³

# %%
# Lists to store results
time_points = [0]  # Initial time

# Main loop
iteration = 0
while True:
    iteration += 1
    # Calculate mass transfer rate
    if (0.9*C_l_values[-1]) < C_sol_values[-1]:
        mass_transfer_rate = k * available_surface_area * (C_sol_values[-1] - C_l_values[-1])
        mass_transfer_rates.append(mass_transfer_rate)
        print("mass_transfer_rate:", mass_transfer_rate)
        print("(C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]):", (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1])))
        print("(C_sol_values[-1] - C_l_values[-1]):", (C_sol_values[-1] - C_l_values[-1]))
        print("C_g_values[-1]:", C_g_values[-1])
        print("C_l_values[-1]:", C_l_values[-1])
        print("C_sol_values[-1]:", C_sol_values[-1])

    else:
        break

    # Limit the time step to prevent large changes in concentrations
    time_step = min(1, 0.1 * gas_volume / abs(mass_transfer_rate)) if mass_transfer_rate < 0 else 1

    # Update concentrations in gas and liquid phases
    C_g_new = C_g_values[-1] - mass_transfer_rate * time_step / gas_volume
    C_l_new = C_l_values[-1] + mass_transfer_rate * time_step / liquid_volume

    # Calculate new equilibrium concentration in the liquid phase considering the updated gas phase concentration
    if C_g_new > 0:
        P_CO2_gas_new = C_g_new * R * T  # Calculate new partial pressure of CO2 in the gas phase
        C_sol_new = (P_CO2_gas_new / H_Pa)*1000  # Calculate equilibrium concentration using updated partial pressure
    else:
        break

    # Print debug information
    print(f"Iteration {iteration}:")
    print(f"Time: {time_points[-1]} seconds")
    print(f"Time step: {time_step:.6f} seconds")
    print(f"Mass transfer rate: {mass_transfer_rate:.6f} mol/s")
    print(f"CO2 concentration in gas phase: {C_g_new:.6f} mol/m³")
    print(f"CO2 concentration in liquid phase: {C_l_new:.6f} mol/m³")
    print(f"Equilibrium concentration in liquid phase: {C_sol_new:.6f} mol/m³\n")

    # Check if the equilibrium concentration matches the concentration in the liquid phase
    if abs(C_l_new - C_sol_new) < 1e-6:  # Using a small tolerance for convergence
        break  # Break the loop if equilibrium is reached

    # Check if the mass transfer rate is less than 1 umol/minute
    if abs(mass_transfer_rate) < 0.00000001666666:
        print("Mass transfer rate is less than 1 umol/minute. Breaking loop.")
        break

    # Update time and concentrations for the next iteration
    time_points.append(time_points[-1] + time_step)  # Increment time by the time step
    C_g_values.append(C_g_new)
    C_l_values.append(C_l_new)
    C_sol_values.append(C_sol_new)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# mass_transfer_rate: 4.4232576532671406e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188607037255736
# (C_sol_values[-1] - C_l_values[-1]): 0.00016442119203330385
# C_g_values[-1]: 1.1190251249176069
# C_l_values[-1]: 0.9309878966595789
# C_sol_values[-1]: 0.9311523178516122
# Iteration 3282:
# Time: 3281 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119025 mol/m³
# CO2 concentration in liquid phase: 0.930988 mol/m³
# Equilibrium concentration in liquid phase: 0.931152 mol/m³
#
# mass_transfer_rate: 4.4111263181811504e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188609818876714
# (C_sol_values[-1] - C_l_values[-1]): 0.0001639702464334425
# C_g_values[-1]: 1.1190249521341047
# C_l_values[-1]: 0.9309882038302493
# C_sol_values[-1]: 0.9311521740766827
# Iteration 3283:
# Time: 3282 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119025 mol/m³
# CO2 concentration in liquid phase: 0.930989 mol/m³
# Equilibrium concentration in liquid phase: 0.931152 mol/m³
#
# mass_transfer_rate: 4.399028254789275e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.118861259286875
# (C_sol_values[-1] - C_l_values[-1]): 0.00016352053760793073
# C_g_values[-1]: 1.1190247798244828
# C_l_values[-1]: 0.9309885101584658
# C_sol_values[-1]: 0.9311520306960738
# Iteration 3284:
# Time: 3283 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119025 mol/m³
# CO2 concentration in liquid phase: 0.930989 mol/m³
# Equilibrium concentration in liquid phase: 0.931152 mol/m³
#
# mass_transfer_rate: 4.3869633718441964e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188615359252765
# (C_sol_values[-1] - C_l_values[-1]): 0.0001630720621649262
# C_g_values[-1]: 1.1190246079874415
# C_l_values[-1]: 0.9309888156465391
# C_sol_values[-1]: 0.931151887708704
# Iteration 3285:
# Time: 3284 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119024 mol/m³
# CO2 concentration in liquid phase: 0.930989 mol/m³
# Equilibrium concentration in liquid phase: 0.931152 mol/m³
#
# mass_transfer_rate: 4.3749315783464946e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188618118049631
# (C_sol_values[-1] - C_l_values[-1]): 0.0001626248167218014
# C_g_values[-1]: 1.1190244366216848
# C_l_values[-1]: 0.9309891202967733
# C_sol_values[-1]: 0.9311517451134951
# Iteration 3286:
# Time: 3285 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119024 mol/m³
# CO2 concentration in liquid phase: 0.930989 mol/m³
# Equilibrium concentration in liquid phase: 0.931152 mol/m³
#
# mass_transfer_rate: 4.3629327835386755e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.118862086928015
# (C_sol_values[-1] - C_l_values[-1]): 0.00016217879790492162
# C_g_values[-1]: 1.11902426572592
# C_l_values[-1]: 0.9309894241114662
# C_sol_values[-1]: 0.9311516029093712
# Iteration 3287:
# Time: 3286 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119024 mol/m³
# CO2 concentration in liquid phase: 0.930990 mol/m³
# Equilibrium concentration in liquid phase: 0.931151 mol/m³
#
# mass_transfer_rate: 4.350966896923089e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188623612965078
# (C_sol_values[-1] - C_l_values[-1]): 0.0001617340023503111
# C_g_values[-1]: 1.1190240952988582
# C_l_values[-1]: 0.9309897270929095
# C_sol_values[-1]: 0.9311514610952598
# Iteration 3288:
# Time: 3287 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119024 mol/m³
# CO2 concentration in liquid phase: 0.930990 mol/m³
# Equilibrium concentration in liquid phase: 0.931151 mol/m³
#
# mass_transfer_rate: 4.3390338282440074e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188626349125108
# (C_sol_values[-1] - C_l_values[-1]): 0.00016129042670298688
# C_g_values[-1]: 1.1190239253392138
# C_l_values[-1]: 0.9309900292433885
# C_sol_values[-1]: 0.9311513196700915
# Iteration 3289:
# Time: 3288 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119024 mol/m³
# CO2 concentration in liquid phase: 0.930990 mol/m³
# Equilibrium concentration in liquid phase: 0.931151 mol/m³
#
# mass_transfer_rate: 4.327133487481657e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.118862907778088
# (C_sol_values[-1] - C_l_values[-1]): 0.00016084806761673676
# C_g_values[-1]: 1.1190237558457048
# C_l_values[-1]: 0.9309903305651821
# C_sol_values[-1]: 0.9311511786327988
# Iteration 3290:
# Time: 3289 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119024 mol/m³
# CO2 concentration in liquid phase: 0.930991 mol/m³
# Equilibrium concentration in liquid phase: 0.931151 mol/m³
#
# mass_transfer_rate: 4.3152657848970154e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.118863179895297
# (C_sol_values[-1] - C_l_values[-1]): 0.00016040692175578464
# C_g_values[-1]: 1.1190235868170528
# C_l_values[-1]: 0.9309906310605631
# C_sol_values[-1]: 0.9311510379823189
# Iteration 3291:
# Time: 3290 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119023 mol/m³
# CO2 concentration in liquid phase: 0.930991 mol/m³
# Equilibrium concentration in liquid phase: 0.931151 mol/m³
#
# mass_transfer_rate: 4.303430630963115e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188634512661908
# (C_sol_values[-1] - C_l_values[-1]): 0.000159966985792237
# C_g_values[-1]: 1.1190234182519831
# C_l_values[-1]: 0.9309909307317982
# C_sol_values[-1]: 0.9311508977175904
# Iteration 3292:
# Time: 3291 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119023 mol/m³
# CO2 concentration in liquid phase: 0.930991 mol/m³
# Equilibrium concentration in liquid phase: 0.931151 mol/m³
#
# mass_transfer_rate: 4.291627936406862e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188637218928164
# (C_sol_values[-1] - C_l_values[-1]): 0.00015952825640763724
# C_g_values[-1]: 1.119023250149224
# C_l_values[-1]: 0.9309912295811476
# C_sol_values[-1]: 0.9311507578375552
# Iteration 3293:
# Time: 3292 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119023 mol/m³
# CO2 concentration in liquid phase: 0.930992 mol/m³
# Equilibrium concentration in liquid phase: 0.931151 mol/m³
#
# mass_transfer_rate: 4.279857612217993e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188639917772145
# (C_sol_values[-1] - C_l_values[-1]): 0.00015909073029329868
# C_g_values[-1]: 1.1190230825075078
# C_l_values[-1]: 0.9309915276108653
# C_sol_values[-1]: 0.9311506183411586
# Iteration 3294:
# Time: 3293 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119023 mol/m³
# CO2 concentration in liquid phase: 0.930992 mol/m³
# Equilibrium concentration in liquid phase: 0.931150 mol/m³
#
# mass_transfer_rate: 4.2681195696042756e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188642609214212
# (C_sol_values[-1] - C_l_values[-1]): 0.0001586544041486393
# C_g_values[-1]: 1.1190229153255697
# C_l_values[-1]: 0.9309918248231995
# C_sol_values[-1]: 0.9311504792273482
# Iteration 3295:
# Time: 3294 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119023 mol/m³
# CO2 concentration in liquid phase: 0.930992 mol/m³
# Equilibrium concentration in liquid phase: 0.931150 mol/m³
#
# mass_transfer_rate: 4.256413720039295e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188645293274662
# (C_sol_values[-1] - C_l_values[-1]): 0.00015821927468295804
# C_g_values[-1]: 1.1190227486021491
# C_l_values[-1]: 0.9309921212203919
# C_sol_values[-1]: 0.9311503404950748
# Iteration 3296:
# Time: 3295 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119023 mol/m³
# CO2 concentration in liquid phase: 0.930992 mol/m³
# Equilibrium concentration in liquid phase: 0.931150 mol/m³
#
# mass_transfer_rate: 4.244739975217654e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188647969973746
# (C_sol_values[-1] - C_l_values[-1]): 0.00015778533861376953
# C_g_values[-1]: 1.1190225823359883
# C_l_values[-1]: 0.930992416804678
# C_sol_values[-1]: 0.9311502021432918
# Iteration 3297:
# Time: 3296 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119022 mol/m³
# CO2 concentration in liquid phase: 0.930993 mol/m³
# Equilibrium concentration in liquid phase: 0.931150 mol/m³
#
# mass_transfer_rate: 4.233098247099775e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188650639331645
# (C_sol_values[-1] - C_l_values[-1]): 0.00015735259266846935
# C_g_values[-1]: 1.119022416525833
# C_l_values[-1]: 0.9309927115782874
# C_sol_values[-1]: 0.9311500641709559
# Iteration 3298:
# Time: 3297 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119022 mol/m³
# CO2 concentration in liquid phase: 0.930993 mol/m³
# Equilibrium concentration in liquid phase: 0.931150 mol/m³
#
# mass_transfer_rate: 4.221488447873069e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188653301368499
# (C_sol_values[-1] - C_l_values[-1]): 0.00015692103358289078
# C_g_values[-1]: 1.1190222511704326
# C_l_values[-1]: 0.9309930055434434
# C_sol_values[-1]: 0.9311499265770263
# Iteration 3299:
# Time: 3298 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119022 mol/m³
# CO2 concentration in liquid phase: 0.930993 mol/m³
# Equilibrium concentration in liquid phase: 0.931150 mol/m³
#
# mass_transfer_rate: 4.209910489960898e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188655956104383
# (C_sol_values[-1] - C_l_values[-1]): 0.00015649065810163787
# C_g_values[-1]: 1.11902208626854
# C_l_values[-1]: 0.9309932987023635
# C_sol_values[-1]: 0.9311497893604651
# Iteration 3300:
# Time: 3299 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119022 mol/m³
# CO2 concentration in liquid phase: 0.930994 mol/m³
# Equilibrium concentration in liquid phase: 0.931150 mol/m³
#
# mass_transfer_rate: 4.1983642860434854e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188658603559327
# (C_sol_values[-1] - C_l_values[-1]): 0.00015606146297886259
# C_g_values[-1]: 1.1190219218189115
# C_l_values[-1]: 0.9309935910572587
# C_sol_values[-1]: 0.9311496525202375
# Iteration 3301:
# Time: 3300 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119022 mol/m³
# CO2 concentration in liquid phase: 0.930994 mol/m³
# Equilibrium concentration in liquid phase: 0.931150 mol/m³
#
# mass_transfer_rate: 4.1868497490310273e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188661243753293
# (C_sol_values[-1] - C_l_values[-1]): 0.0001556334449772656
# C_g_values[-1]: 1.1190217578203066
# C_l_values[-1]: 0.9309938826103341
# C_sol_values[-1]: 0.9311495160553114
# Iteration 3302:
# Time: 3301 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119022 mol/m³
# CO2 concentration in liquid phase: 0.930994 mol/m³
# Equilibrium concentration in liquid phase: 0.931149 mol/m³
#
# mass_transfer_rate: 4.1753667920696743e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.11886638767062
# (C_sol_values[-1] - C_l_values[-1]): 0.0001552066008683184
# C_g_values[-1]: 1.1190215942714883
# C_l_values[-1]: 0.9309941733637889
# C_sol_values[-1]: 0.9311493799646572
# Iteration 3303:
# Time: 3302 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119021 mol/m³
# CO2 concentration in liquid phase: 0.930994 mol/m³
# Equilibrium concentration in liquid phase: 0.931149 mol/m³
#
# mass_transfer_rate: 4.163915328550486e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188666502437905
# (C_sol_values[-1] - C_l_values[-1]): 0.0001547809274325962
# C_g_values[-1]: 1.119021431171223
# C_l_values[-1]: 0.9309944633198161
# C_sol_values[-1]: 0.9311492442472487
# Iteration 3304:
# Time: 3303 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119021 mol/m³
# CO2 concentration in liquid phase: 0.930995 mol/m³
# Equilibrium concentration in liquid phase: 0.931149 mol/m³
#
# mass_transfer_rate: 4.152495272097489e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188669120968213
# (C_sol_values[-1] - C_l_values[-1]): 0.00015435642145933404
# C_g_values[-1]: 1.1190212685182805
# C_l_values[-1]: 0.9309947524806028
# C_sol_values[-1]: 0.9311491089020622
# Iteration 3305:
# Time: 3304 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119021 mol/m³
# CO2 concentration in liquid phase: 0.930995 mol/m³
# Equilibrium concentration in liquid phase: 0.931149 mol/m³
#
# mass_transfer_rate: 4.141106536567671e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188671732316875
# (C_sol_values[-1] - C_l_values[-1]): 0.00015393307974642667
# C_g_values[-1]: 1.119021106311434
# C_l_values[-1]: 0.9309950408483301
# C_sol_values[-1]: 0.9311489739280765
# Iteration 3306:
# Time: 3305 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119021 mol/m³
# CO2 concentration in liquid phase: 0.930995 mol/m³
# Equilibrium concentration in liquid phase: 0.931149 mol/m³
#
# mass_transfer_rate: 4.129749036065919e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.118867433650359
# (C_sol_values[-1] - C_l_values[-1]): 0.0001535108991009837
# C_g_values[-1]: 1.1190209445494599
# C_l_values[-1]: 0.9309953284251729
# C_sol_values[-1]: 0.9311488393242738
# Iteration 3307:
# Time: 3306 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119021 mol/m³
# CO2 concentration in liquid phase: 0.930996 mol/m³
# Equilibrium concentration in liquid phase: 0.931149 mol/m³
#
# mass_transfer_rate: 4.1184226849211244e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188676933547996
# (C_sol_values[-1] - C_l_values[-1]): 0.0001530898763384414
# C_g_values[-1]: 1.119020783231138
# C_l_values[-1]: 0.9309956152133003
# C_sol_values[-1]: 0.9311487050896388
# Iteration 3308:
# Time: 3307 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119021 mol/m³
# CO2 concentration in liquid phase: 0.930996 mol/m³
# Equilibrium concentration in liquid phase: 0.931149 mol/m³
#
# mass_transfer_rate: 4.107127397701116e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188679523469687
# (C_sol_values[-1] - C_l_values[-1]): 0.00015267000828311783
# C_g_values[-1]: 1.119020622355252
# C_l_values[-1]: 0.9309959012148756
# C_sol_values[-1]: 0.9311485712231587
# Iteration 3309:
# Time: 3308 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119020 mol/m³
# CO2 concentration in liquid phase: 0.930996 mol/m³
# Equilibrium concentration in liquid phase: 0.931148 mol/m³
#
# mass_transfer_rate: 4.095863089218633e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188682106288195
# (C_sol_values[-1] - C_l_values[-1]): 0.00015225129176843488
# C_g_values[-1]: 1.119020461920588
# C_l_values[-1]: 0.9309961864320561
# C_sol_values[-1]: 0.9311484377238245
# Iteration 3310:
# Time: 3309 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119020 mol/m³
# CO2 concentration in liquid phase: 0.930996 mol/m³
# Equilibrium concentration in liquid phase: 0.931148 mol/m³
#
# mass_transfer_rate: 4.084629674507433e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188684682023
# (C_sol_values[-1] - C_l_values[-1]): 0.0001518337236360301
# C_g_values[-1]: 1.119020301925936
# C_l_values[-1]: 0.9309964708669928
# C_sol_values[-1]: 0.9311483045906288
# Iteration 3311:
# Time: 3310 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119020 mol/m³
# CO2 concentration in liquid phase: 0.930997 mol/m³
# Equilibrium concentration in liquid phase: 0.931148 mol/m³
#
# mass_transfer_rate: 4.0734270688312505e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.118868725069353
# (C_sol_values[-1] - C_l_values[-1]): 0.00015141730073608972
# C_g_values[-1]: 1.1190201423700892
# C_l_values[-1]: 0.9309967545218313
# C_sol_values[-1]: 0.9311481718225674
# Iteration 3312:
# Time: 3311 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119020 mol/m³
# CO2 concentration in liquid phase: 0.930997 mol/m³
# Equilibrium concentration in liquid phase: 0.931148 mol/m³
#
# mass_transfer_rate: 4.062255187701719e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188689812319164
# (C_sol_values[-1] - C_l_values[-1]): 0.00015100201992801487
# C_g_values[-1]: 1.1190199832518444
# C_l_values[-1]: 0.9309970373987111
# C_sol_values[-1]: 0.9311480394186391
# Iteration 3313:
# Time: 3312 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119020 mol/m³
# CO2 concentration in liquid phase: 0.930997 mol/m³
# Equilibrium concentration in liquid phase: 0.931148 mol/m³
#
# mass_transfer_rate: 4.0511139468425266e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188692366919222
# (C_sol_values[-1] - C_l_values[-1]): 0.00015058787807908924
# C_g_values[-1]: 1.1190198245700012
# C_l_values[-1]: 0.9309973194997658
# C_sol_values[-1]: 0.9311479073778449
# Iteration 3314:
# Time: 3313 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119020 mol/m³
# CO2 concentration in liquid phase: 0.930998 mol/m³
# Equilibrium concentration in liquid phase: 0.931148 mol/m³
#
# mass_transfer_rate: 4.040003262231236e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188694914512967
# (C_sol_values[-1] - C_l_values[-1]): 0.00015017487206603342
# C_g_values[-1]: 1.1190196663233627
# C_l_values[-1]: 0.9309976008271232
# C_sol_values[-1]: 0.9311477756991893
# Iteration 3315:
# Time: 3314 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119020 mol/m³
# CO2 concentration in liquid phase: 0.930998 mol/m³
# Equilibrium concentration in liquid phase: 0.931148 mol/m³
#
# mass_transfer_rate: 4.028923050051491e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.118869745511962
# (C_sol_values[-1] - C_l_values[-1]): 0.00014976299877322852
# C_g_values[-1]: 1.1190195085107353
# C_l_values[-1]: 0.9309978813829053
# C_sol_values[-1]: 0.9311476443816785
# Iteration 3316:
# Time: 3315 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119019 mol/m³
# CO2 concentration in liquid phase: 0.930998 mol/m³
# Equilibrium concentration in liquid phase: 0.931148 mol/m³
#
# mass_transfer_rate: 4.0178732267318476e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188699988758344
# (C_sol_values[-1] - C_l_values[-1]): 0.0001493522550941595
# C_g_values[-1]: 1.1190193511309285
# C_l_values[-1]: 0.9309981611692282
# C_sol_values[-1]: 0.9311475134243223
# Iteration 3317:
# Time: 3316 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119019 mol/m³
# CO2 concentration in liquid phase: 0.930998 mol/m³
# Equilibrium concentration in liquid phase: 0.931147 mol/m³
#
# mass_transfer_rate: 4.00685370893084e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188702515448248
# (C_sol_values[-1] - C_l_values[-1]): 0.00014894263793086004
# C_g_values[-1]: 1.1190191941827556
# C_l_values[-1]: 0.9309984401882022
# C_sol_values[-1]: 0.9311473828261331
# Iteration 3318:
# Time: 3317 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119019 mol/m³
# CO2 concentration in liquid phase: 0.930999 mol/m³
# Equilibrium concentration in liquid phase: 0.931147 mol/m³
#
# mass_transfer_rate: 3.995864413531005e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.118870503520839
# (C_sol_values[-1] - C_l_values[-1]): 0.0001485341441936905
# C_g_values[-1]: 1.1190190376650326
# C_l_values[-1]: 0.930998718441932
# C_sol_values[-1]: 0.9311472525861257
# Iteration 3319:
# Time: 3318 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119019 mol/m³
# CO2 concentration in liquid phase: 0.930999 mol/m³
# Equilibrium concentration in liquid phase: 0.931147 mol/m³
#
# mass_transfer_rate: 3.984905257638885e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188707548057777
# (C_sol_values[-1] - C_l_values[-1]): 0.00014812677080133785
# C_g_values[-1]: 1.119018881576579
# C_l_values[-1]: 0.9309989959325163
# C_sol_values[-1]: 0.9311471227033177
# Iteration 3320:
# Time: 3319 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119019 mol/m³
# CO2 concentration in liquid phase: 0.930999 mol/m³
# Equilibrium concentration in liquid phase: 0.931147 mol/m³
#
# mass_transfer_rate: 3.9739761586029456e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188710054015356
# (C_sol_values[-1] - C_l_values[-1]): 0.00014772051468148195
# C_g_values[-1]: 1.1190187259162172
# C_l_values[-1]: 0.9309992726620481
# C_sol_values[-1]: 0.9311469931767296
# Iteration 3321:
# Time: 3320 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119019 mol/m³
# CO2 concentration in liquid phase: 0.931000 mol/m³
# Equilibrium concentration in liquid phase: 0.931147 mol/m³
#
# mass_transfer_rate: 3.9630770339747495e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188712553100042
# (C_sol_values[-1] - C_l_values[-1]): 0.00014731537276935214
# C_g_values[-1]: 1.1190185706827736
# C_l_values[-1]: 0.9309995486326147
# C_sol_values[-1]: 0.931146864005384
# Iteration 3322:
# Time: 3321 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119018 mol/m³
# CO2 concentration in liquid phase: 0.931000 mol/m³
# Equilibrium concentration in liquid phase: 0.931147 mol/m³
#
# mass_transfer_rate: 3.9522078015597324e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188715045330673
# (C_sol_values[-1] - C_l_values[-1]): 0.00014691134200961464
# C_g_values[-1]: 1.1190184158750769
# C_l_values[-1]: 0.9309998238462976
# C_sol_values[-1]: 0.9311467351883073
# Iteration 3323:
# Time: 3322 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119018 mol/m³
# CO2 concentration in liquid phase: 0.931000 mol/m³
# Equilibrium concentration in liquid phase: 0.931147 mol/m³
#
# mass_transfer_rate: 3.941368379369411e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188717530726051
# (C_sol_values[-1] - C_l_values[-1]): 0.00014650841935459624
# C_g_values[-1]: 1.1190182614919597
# C_l_values[-1]: 0.9310000983051727
# C_sol_values[-1]: 0.9311466067245273
# Iteration 3324:
# Time: 3323 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119018 mol/m³
# CO2 concentration in liquid phase: 0.931000 mol/m³
# Equilibrium concentration in liquid phase: 0.931146 mol/m³
#
# mass_transfer_rate: 3.9305586856393087e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188720009304924
# (C_sol_values[-1] - C_l_values[-1]): 0.00014610660176495038
# C_g_values[-1]: 1.1190181075322574
# C_l_values[-1]: 0.9310003720113101
# C_sol_values[-1]: 0.9311464786130751
# Iteration 3325:
# Time: 3324 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119018 mol/m³
# CO2 concentration in liquid phase: 0.931001 mol/m³
# Equilibrium concentration in liquid phase: 0.931146 mol/m³
#
# mass_transfer_rate: 3.9197786388438843e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188722481085984
# (C_sol_values[-1] - C_l_values[-1]): 0.0001457058862102123
# C_g_values[-1]: 1.1190179539948086
# C_l_values[-1]: 0.9310006449667744
# C_sol_values[-1]: 0.9311463508529846
# Iteration 3326:
# Time: 3325 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119018 mol/m³
# CO2 concentration in liquid phase: 0.931001 mol/m³
# Equilibrium concentration in liquid phase: 0.931146 mol/m³
#
# mass_transfer_rate: 3.909028157669656e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188724946087878
# (C_sol_values[-1] - C_l_values[-1]): 0.0001453062696677998
# C_g_values[-1]: 1.1190178008784555
# C_l_values[-1]: 0.9310009171736243
# C_sol_values[-1]: 0.9311462234432921
# Iteration 3327:
# Time: 3326 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119018 mol/m³
# CO2 concentration in liquid phase: 0.931001 mol/m³
# Equilibrium concentration in liquid phase: 0.931146 mol/m³
#
# mass_transfer_rate: 3.898307161030131e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188727404329195
# (C_sol_values[-1] - C_l_values[-1]): 0.0001449077491235684
# C_g_values[-1]: 1.119017648182043
# C_l_values[-1]: 0.931001188633913
# C_sol_values[-1]: 0.9311460963830366
# Iteration 3328:
# Time: 3327 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119017 mol/m³
# CO2 concentration in liquid phase: 0.931001 mol/m³
# Equilibrium concentration in liquid phase: 0.931146 mol/m³
#
# mass_transfer_rate: 3.8876155680568484e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188729855828483
# (C_sol_values[-1] - C_l_values[-1]): 0.00014451032157147825
# C_g_values[-1]: 1.1190174959044197
# C_l_values[-1]: 0.931001459349688
# C_sol_values[-1]: 0.9311459696712595
# Iteration 3329:
# Time: 3328 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119017 mol/m³
# CO2 concentration in liquid phase: 0.931002 mol/m³
# Equilibrium concentration in liquid phase: 0.931146 mol/m³
#
# mass_transfer_rate: 3.8769532981113246e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188732300604225
# (C_sol_values[-1] - C_l_values[-1]): 0.0001441139840140382
# C_g_values[-1]: 1.1190173440444366
# C_l_values[-1]: 0.9310017293229914
# C_sol_values[-1]: 0.9311458433070054
# Iteration 3330:
# Time: 3329 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119017 mol/m³
# CO2 concentration in liquid phase: 0.931002 mol/m³
# Equilibrium concentration in liquid phase: 0.931146 mol/m³
#
# mass_transfer_rate: 3.8663202707671316e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188734738674868
# (C_sol_values[-1] - C_l_values[-1]): 0.00014371873346163966
# C_g_values[-1]: 1.1190171926009485
# C_l_values[-1]: 0.9310019985558593
# C_sol_values[-1]: 0.9311457172893209
# Iteration 3331:
# Time: 3330 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119017 mol/m³
# CO2 concentration in liquid phase: 0.931002 mol/m³
# Equilibrium concentration in liquid phase: 0.931146 mol/m³
#
# mass_transfer_rate: 3.855716405833795e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188737170058793
# (C_sol_values[-1] - C_l_values[-1]): 0.00014332456693344486
# C_g_values[-1]: 1.119017041572813
# C_l_values[-1]: 0.9310022670503225
# C_sol_values[-1]: 0.931145591617256
# Iteration 3332:
# Time: 3331 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119017 mol/m³
# CO2 concentration in liquid phase: 0.931003 mol/m³
# Equilibrium concentration in liquid phase: 0.931145 mol/m³
#
# mass_transfer_rate: 3.845141623311989e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.118873959477435
# (C_sol_values[-1] - C_l_values[-1]): 0.00014293148145572143
# C_g_values[-1]: 1.119016890958891
# C_l_values[-1]: 0.9310025348084062
# C_sol_values[-1]: 0.931145466289862
# Iteration 3333:
# Time: 3332 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119017 mol/m³
# CO2 concentration in liquid phase: 0.931003 mol/m³
# Equilibrium concentration in liquid phase: 0.931145 mol/m³
#
# mass_transfer_rate: 3.834595843453272e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188742012839823
# (C_sol_values[-1] - C_l_values[-1]): 0.00014253947406406287
# C_g_values[-1]: 1.1190167407580462
# C_l_values[-1]: 0.93100280183213
# C_sol_values[-1]: 0.9311453413061941
# Iteration 3334:
# Time: 3333 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119017 mol/m³
# CO2 concentration in liquid phase: 0.931003 mol/m³
# Equilibrium concentration in liquid phase: 0.931145 mol/m³
#
# mass_transfer_rate: 3.8240789866973665e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.118874442427345
# (C_sol_values[-1] - C_l_values[-1]): 0.00014214854180105707
# C_g_values[-1]: 1.119016590969146
# C_l_values[-1]: 0.9310030681235081
# C_sol_values[-1]: 0.9311452166653091
# Iteration 3335:
# Time: 3334 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119016 mol/m³
# CO2 concentration in liquid phase: 0.931003 mol/m³
# Equilibrium concentration in liquid phase: 0.931145 mol/m³
#
# mass_transfer_rate: 3.8135909737438404e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188746829093417
# (C_sol_values[-1] - C_l_values[-1]): 0.0001417586817189509
# C_g_values[-1]: 1.1190164415910606
# C_l_values[-1]: 0.9310033336845488
# C_sol_values[-1]: 0.9311450923662677
# Iteration 3336:
# Time: 3335 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119016 mol/m³
# CO2 concentration in liquid phase: 0.931004 mol/m³
# Equilibrium concentration in liquid phase: 0.931145 mol/m³
#
# mass_transfer_rate: 3.803131725468477e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188749227317867
# (C_sol_values[-1] - C_l_values[-1]): 0.0001413698908765415
# C_g_values[-1]: 1.1190162926226632
# C_l_values[-1]: 0.9310035985172553
# C_sol_values[-1]: 0.9311449684081319
# Iteration 3337:
# Time: 3336 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119016 mol/m³
# CO2 concentration in liquid phase: 0.931004 mol/m³
# Equilibrium concentration in liquid phase: 0.931145 mol/m³
#
# mass_transfer_rate: 3.7927011629830115e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188751618964887
# (C_sol_values[-1] - C_l_values[-1]): 0.00014098216634139682
# C_g_values[-1]: 1.1190161440628301
# C_l_values[-1]: 0.9310038626236251
# C_sol_values[-1]: 0.9311448447899665
# Iteration 3338:
# Time: 3337 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119016 mol/m³
# CO2 concentration in liquid phase: 0.931004 mol/m³
# Equilibrium concentration in liquid phase: 0.931145 mol/m³
#
# mass_transfer_rate: 3.782299207617208e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188754004052517
# (C_sol_values[-1] - C_l_values[-1]): 0.0001405955051891894
# C_g_values[-1]: 1.1190159959104409
# C_l_values[-1]: 0.9310041260056503
# C_sol_values[-1]: 0.9311447215108395
# Iteration 3339:
# Time: 3338 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119016 mol/m³
# CO2 concentration in liquid phase: 0.931004 mol/m³
# Equilibrium concentration in liquid phase: 0.931145 mol/m³
#
# mass_transfer_rate: 3.7719257809039305e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.118875638259875
# (C_sol_values[-1] - C_l_values[-1]): 0.0001402099045031413
# C_g_values[-1]: 1.1190158481643782
# C_l_values[-1]: 0.9310043886653175
# C_sol_values[-1]: 0.9311445985698207
# Iteration 3340:
# Time: 3339 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119016 mol/m³
# CO2 concentration in liquid phase: 0.931005 mol/m³
# Equilibrium concentration in liquid phase: 0.931144 mol/m³
#
# mass_transfer_rate: 3.761580804609004e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188758754621522
# (C_sol_values[-1] - C_l_values[-1]): 0.00013982536137513435
# C_g_values[-1]: 1.1190157008235273
# C_l_values[-1]: 0.9310046506046079
# C_sol_values[-1]: 0.931144475965983
# Iteration 3341:
# Time: 3340 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119016 mol/m³
# CO2 concentration in liquid phase: 0.931005 mol/m³
# Equilibrium concentration in liquid phase: 0.931144 mol/m³
#
# mass_transfer_rate: 3.7512642006983666e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188761120138726
# (C_sol_values[-1] - C_l_values[-1]): 0.00013944187290448884
# C_g_values[-1]: 1.1190155538867772
# C_l_values[-1]: 0.9310049118254972
# C_sol_values[-1]: 0.9311443536984017
# Iteration 3342:
# Time: 3341 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119015 mol/m³
# CO2 concentration in liquid phase: 0.931005 mol/m³
# Equilibrium concentration in liquid phase: 0.931144 mol/m³
#
# mass_transfer_rate: 3.740975891364945e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188763479168204
# (C_sol_values[-1] - C_l_values[-1]): 0.00013905943619896277
# C_g_values[-1]: 1.1190154073530194
# C_l_values[-1]: 0.9310051723299555
# C_sol_values[-1]: 0.9311442317661545
# Iteration 3343:
# Time: 3342 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119015 mol/m³
# CO2 concentration in liquid phase: 0.931005 mol/m³
# Equilibrium concentration in liquid phase: 0.931144 mol/m³
#
# mass_transfer_rate: 3.7307157989958056e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188765831727752
# (C_sol_values[-1] - C_l_values[-1]): 0.0001386780483735306
# C_g_values[-1]: 1.1190152612211486
# C_l_values[-1]: 0.9310054321199479
# C_sol_values[-1]: 0.9311441101683214
# Iteration 3344:
# Time: 3343 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119015 mol/m³
# CO2 concentration in liquid phase: 0.931006 mol/m³
# Equilibrium concentration in liquid phase: 0.931144 mol/m³
#
# mass_transfer_rate: 3.720483846210975e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.118876817783511
# (C_sol_values[-1] - C_l_values[-1]): 0.0001382977065518265
# C_g_values[-1]: 1.1190151154900627
# C_l_values[-1]: 0.9310056911974339
# C_sol_values[-1]: 0.9311439889039858
# Iteration 3345:
# Time: 3344 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119015 mol/m³
# CO2 concentration in liquid phase: 0.931006 mol/m³
# Equilibrium concentration in liquid phase: 0.931144 mol/m³
#
# mass_transfer_rate: 3.710279955833581e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188770517507973
# (C_sol_values[-1] - C_l_values[-1]): 0.00013791840786503418
# C_g_values[-1]: 1.1190149701586625
# C_l_values[-1]: 0.9310059495643677
# C_sol_values[-1]: 0.9311438679722327
# Iteration 3346:
# Time: 3345 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119015 mol/m³
# CO2 concentration in liquid phase: 0.931006 mol/m³
# Equilibrium concentration in liquid phase: 0.931144 mol/m³
#
# mass_transfer_rate: 3.7001040508868597e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188772850763997
# (C_sol_values[-1] - C_l_values[-1]): 0.00013754014945177584
# C_g_values[-1]: 1.1190148252258516
# C_l_values[-1]: 0.9310062072226979
# C_sol_values[-1]: 0.9311437473721497
# Iteration 3347:
# Time: 3346 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119015 mol/m³
# CO2 concentration in liquid phase: 0.931006 mol/m³
# Equilibrium concentration in liquid phase: 0.931144 mol/m³
#
# mass_transfer_rate: 3.689956054641944e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188775177620773
# (C_sol_values[-1] - C_l_values[-1]): 0.00013716292845988853
# C_g_values[-1]: 1.1190146806905372
# C_l_values[-1]: 0.931006464174368
# C_sol_values[-1]: 0.9311436271028279
# Iteration 3348:
# Time: 3347 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119015 mol/m³
# CO2 concentration in liquid phase: 0.931007 mol/m³
# Equilibrium concentration in liquid phase: 0.931144 mol/m³
#
# mass_transfer_rate: 3.679835890531251e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188777498095857
# (C_sol_values[-1] - C_l_values[-1]): 0.0001367867420432045
# C_g_values[-1]: 1.1190145365516289
# C_l_values[-1]: 0.9310067204213163
# C_sol_values[-1]: 0.9311435071633595
# Iteration 3349:
# Time: 3348 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119014 mol/m³
# CO2 concentration in liquid phase: 0.931007 mol/m³
# Equilibrium concentration in liquid phase: 0.931143 mol/m³
#
# mass_transfer_rate: 3.669743482229123e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188779812206748
# (C_sol_values[-1] - C_l_values[-1]): 0.00013641158736454884
# C_g_values[-1]: 1.1190143928080394
# C_l_values[-1]: 0.9310069759654753
# C_sol_values[-1]: 0.9311433875528399
# Iteration 3350:
# Time: 3349 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119014 mol/m³
# CO2 concentration in liquid phase: 0.931007 mol/m³
# Equilibrium concentration in liquid phase: 0.931143 mol/m³
#
# mass_transfer_rate: 3.659678753618972e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188782119970901
# (C_sol_values[-1] - C_l_values[-1]): 0.00013603746159451813
# C_g_values[-1]: 1.1190142494586846
# C_l_values[-1]: 0.9310072308087727
# C_sol_values[-1]: 0.9311432682703672
# Iteration 3351:
# Time: 3350 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119014 mol/m³
# CO2 concentration in liquid phase: 0.931007 mol/m³
# Equilibrium concentration in liquid phase: 0.931143 mol/m³
#
# mass_transfer_rate: 3.649641628775359e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188784421405724
# (C_sol_values[-1] - C_l_values[-1]): 0.00013566436191081443
# C_g_values[-1]: 1.1190141065024832
# C_l_values[-1]: 0.9310074849531306
# C_sol_values[-1]: 0.9311431493150414
# Iteration 3352:
# Time: 3351 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119014 mol/m³
# CO2 concentration in liquid phase: 0.931008 mol/m³
# Equilibrium concentration in liquid phase: 0.931143 mol/m³
#
# mass_transfer_rate: 3.6396320319998373e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188786716528576
# (C_sol_values[-1] - C_l_values[-1]): 0.0001352922854995775
# C_g_values[-1]: 1.1190139639383572
# C_l_values[-1]: 0.9310077384004659
# C_sol_values[-1]: 0.9311430306859655
# Iteration 3353:
# Time: 3352 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119014 mol/m³
# CO2 concentration in liquid phase: 0.931008 mol/m³
# Equilibrium concentration in liquid phase: 0.931143 mol/m³
#
# mass_transfer_rate: 3.629649887797058e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188789005356765
# (C_sol_values[-1] - C_l_values[-1]): 0.0001349212295544966
# C_g_values[-1]: 1.119013821765231
# C_l_values[-1]: 0.9310079911526904
# C_sol_values[-1]: 0.9311429123822449
# Iteration 3354:
# Time: 3353 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119014 mol/m³
# CO2 concentration in liquid phase: 0.931008 mol/m³
# Equilibrium concentration in liquid phase: 0.931143 mol/m³
#
# mass_transfer_rate: 3.619695120862819e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.118879128790756
# (C_sol_values[-1] - C_l_values[-1]): 0.0001345511912763664
# C_g_values[-1]: 1.1190136799820323
# C_l_values[-1]: 0.9310082432117104
# C_sol_values[-1]: 0.9311427944029868
# Iteration 3355:
# Time: 3354 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119014 mol/m³
# CO2 concentration in liquid phase: 0.931008 mol/m³
# Equilibrium concentration in liquid phase: 0.931143 mol/m³
#
# mass_transfer_rate: 3.6097676561109524e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188793564198174
# (C_sol_values[-1] - C_l_values[-1]): 0.0001341821678740862
# C_g_values[-1]: 1.1190135385876916
# C_l_values[-1]: 0.9310084945794271
# C_sol_values[-1]: 0.9311426767473012
# Iteration 3356:
# Time: 3355 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119013 mol/m³
# CO2 concentration in liquid phase: 0.931009 mol/m³
# Equilibrium concentration in liquid phase: 0.931143 mol/m³
#
# mass_transfer_rate: 3.599867418667346e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188795834245782
# (C_sol_values[-1] - C_l_values[-1]): 0.00013381415656443796
# C_g_values[-1]: 1.1190133975811425
# C_l_values[-1]: 0.9310087452577366
# C_sol_values[-1]: 0.931142559414301
# Iteration 3357:
# Time: 3356 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119013 mol/m³
# CO2 concentration in liquid phase: 0.931009 mol/m³
# Equilibrium concentration in liquid phase: 0.931142 mol/m³
#
# mass_transfer_rate: 3.589994333866958e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188798098067494
# (C_sol_values[-1] - C_l_values[-1]): 0.0001334471545719751
# C_g_values[-1]: 1.1190132569613214
# C_l_values[-1]: 0.9310089952485295
# C_sol_values[-1]: 0.9311424424031015
# Iteration 3358:
# Time: 3357 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119013 mol/m³
# CO2 concentration in liquid phase: 0.931009 mol/m³
# Equilibrium concentration in liquid phase: 0.931142 mol/m³
#
# mass_transfer_rate: 3.580148327226937e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188800355680397
# (C_sol_values[-1] - C_l_values[-1]): 0.00013308115912802343
# C_g_values[-1]: 1.1190131167271677
# C_l_values[-1]: 0.9310092445536916
# C_sol_values[-1]: 0.9311423257128196
# Iteration 3359:
# Time: 3358 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119013 mol/m³
# CO2 concentration in liquid phase: 0.931009 mol/m³
# Equilibrium concentration in liquid phase: 0.931142 mol/m³
#
# mass_transfer_rate: 3.5703293244914226e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188802607101516
# (C_sol_values[-1] - C_l_values[-1]): 0.0001327161674723465
# C_g_values[-1]: 1.1190129768776238
# C_l_values[-1]: 0.9310094931751032
# C_sol_values[-1]: 0.9311422093425755
# Iteration 3360:
# Time: 3359 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119013 mol/m³
# CO2 concentration in liquid phase: 0.931010 mol/m³
# Equilibrium concentration in liquid phase: 0.931142 mol/m³
#
# mass_transfer_rate: 3.560537251589729e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.118880485234783
# (C_sol_values[-1] - C_l_values[-1]): 0.00013235217685159117
# C_g_values[-1]: 1.1190128374116346
# C_l_values[-1]: 0.9310097411146396
# C_sol_values[-1]: 0.9311420932914912
# Iteration 3361:
# Time: 3360 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119013 mol/m³
# CO2 concentration in liquid phase: 0.931010 mol/m³
# Equilibrium concentration in liquid phase: 0.931142 mol/m³
#
# mass_transfer_rate: 3.5507720346662176e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.118880709143628
# (C_sol_values[-1] - C_l_values[-1]): 0.00013198918452039798
# C_g_values[-1]: 1.1190126983281483
# C_l_values[-1]: 0.931009988374171
# C_sol_values[-1]: 0.9311419775586914
# Iteration 3362:
# Time: 3361 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119013 mol/m³
# CO2 concentration in liquid phase: 0.931010 mol/m³
# Equilibrium concentration in liquid phase: 0.931142 mol/m³
#
# mass_transfer_rate: 3.541033600071331e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188809324383748
# (C_sol_values[-1] - C_l_values[-1]): 0.00013162718774106796
# C_g_values[-1]: 1.1190125596261158
# C_l_values[-1]: 0.9310102349555623
# C_sol_values[-1]: 0.9311418621433034
# Iteration 3363:
# Time: 3362 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119012 mol/m³
# CO2 concentration in liquid phase: 0.931010 mol/m³
# Equilibrium concentration in liquid phase: 0.931142 mol/m³
#
# mass_transfer_rate: 3.5313218743406907e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188811551207078
# (C_sol_values[-1] - C_l_values[-1]): 0.00013126618378278554
# C_g_values[-1]: 1.1190124213044907
# C_l_values[-1]: 0.9310104808606735
# C_sol_values[-1]: 0.9311417470444563
# Iteration 3364:
# Time: 3363 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119012 mol/m³
# CO2 concentration in liquid phase: 0.931011 mol/m³
# Equilibrium concentration in liquid phase: 0.931142 mol/m³
#
# mass_transfer_rate: 3.521636784227946e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188813771923072
# (C_sol_values[-1] - C_l_values[-1]): 0.00013090616992283977
# C_g_values[-1]: 1.11901228336223
# C_l_values[-1]: 0.9310107260913593
# C_sol_values[-1]: 0.9311416322612821
# Iteration 3365:
# Time: 3364 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119012 mol/m³
# CO2 concentration in liquid phase: 0.931011 mol/m³
# Equilibrium concentration in liquid phase: 0.931142 mol/m³
#
# mass_transfer_rate: 3.5119782566838726e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188815986548473
# (C_sol_values[-1] - C_l_values[-1]): 0.00013054714344584717
# C_g_values[-1]: 1.1190121457982931
# C_l_values[-1]: 0.9310109706494692
# C_sol_values[-1]: 0.9311415177929151
# Iteration 3366:
# Time: 3365 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119012 mol/m³
# CO2 concentration in liquid phase: 0.931011 mol/m³
# Equilibrium concentration in liquid phase: 0.931141 mol/m³
#
# mass_transfer_rate: 3.502346218850395e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.118881819509999
# (C_sol_values[-1] - C_l_values[-1]): 0.0001301891016435297
# C_g_values[-1]: 1.1190120086116424
# C_l_values[-1]: 0.9310112145368482
# C_sol_values[-1]: 0.9311414036384917
# Iteration 3367:
# Time: 3366 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119012 mol/m³
# CO2 concentration in liquid phase: 0.931011 mol/m³
# Equilibrium concentration in liquid phase: 0.931141 mol/m³
#
# mass_transfer_rate: 3.492740598081495e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188820397594277
# (C_sol_values[-1] - C_l_values[-1]): 0.0001298320418154919
# C_g_values[-1]: 1.1190118718012432
# C_l_values[-1]: 0.9310114577553357
# C_sol_values[-1]: 0.9311412897971512
# Iteration 3368:
# Time: 3367 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119012 mol/m³
# CO2 concentration in liquid phase: 0.931012 mol/m³
# Equilibrium concentration in liquid phase: 0.931141 mol/m³
#
# mass_transfer_rate: 3.483161321928278e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.118882259404795
# (C_sol_values[-1] - C_l_values[-1]): 0.00012947596126866578
# C_g_values[-1]: 1.1190117353660636
# C_l_values[-1]: 0.931011700306766
# C_sol_values[-1]: 0.9311411762680347
# Iteration 3369:
# Time: 3368 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119012 mol/m³
# CO2 concentration in liquid phase: 0.931012 mol/m³
# Equilibrium concentration in liquid phase: 0.931141 mol/m³
#
# mass_transfer_rate: 3.4736083181329985e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1188824784477573
# (C_sol_values[-1] - C_l_values[-1]): 0.00012912085731708878
# C_g_values[-1]: 1.1190115993050744
# C_l_values[-1]: 0.931011942192969
# C_sol_values[-1]: 0.9311410630502861
# Iteration 3370:
# Time: 3369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.119011 mol/m³
# CO2 concentration in liquid phase: 0.931012 mol/m³
# ...
# C_sol_values[-1]: 0.931121249983378
# Iteration 3609:
# Time: 3608 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.118988 mol/m³
# CO2 concentration in liquid phase: 0.931054 mol/m³
# Equilibrium concentration in liquid phase: 0.931121 mol/m³
#
# mass_transfer_rate: 1.7968941948143166e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1189209242012232
# (C_sol_values[-1] - C_l_values[-1]): 6.679409354570787e-05
# C_g_values[-1]: 1.118987718294769
# C_l_values[-1]: 0.9310543973224014
# C_sol_values[-1]: 0.9311211914159471
# Iteration 3610:
# Time: 3609 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.118988 mol/m³
# CO2 concentration in liquid phase: 0.931055 mol/m³
# Equilibrium concentration in liquid phase: 0.931121 mol/m³
#
# mass_transfer_rate: 1.7919659886559586e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1189210372011655
# (C_sol_values[-1] - C_l_values[-1]): 6.661090242399137e-05
# C_g_values[-1]: 1.1189876481035894
# C_l_values[-1]: 0.9310545221067205
# C_sol_values[-1]: 0.9311211330091445
# Iteration 3611:
# Time: 3610 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.118988 mol/m³
# CO2 concentration in liquid phase: 0.931055 mol/m³
# Equilibrium concentration in liquid phase: 0.931121 mol/m³
#
# mass_transfer_rate: 1.7870512987189138e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.118921149891191
# (C_sol_values[-1] - C_l_values[-1]): 6.642821372682128e-05
# C_g_values[-1]: 1.118987578104918
# C_l_values[-1]: 0.931054646548803
# C_sol_values[-1]: 0.9311210747625298
# Iteration 3612:
# Time: 3611 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.118988 mol/m³
# CO2 concentration in liquid phase: 0.931055 mol/m³
# Equilibrium concentration in liquid phase: 0.931121 mol/m³
#
# mass_transfer_rate: 1.7821500879319995e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1189212622721505
# (C_sol_values[-1] - C_l_values[-1]): 6.624602607618879e-05
# C_g_values[-1]: 1.1189875082982266
# C_l_values[-1]: 0.9310547706495876
# C_sol_values[-1]: 0.9311210166756638
# Iteration 3613:
# Time: 3612 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.118987 mol/m³
# CO2 concentration in liquid phase: 0.931055 mol/m³
# Equilibrium concentration in liquid phase: 0.931121 mol/m³
#
# mass_transfer_rate: 1.777262319328568e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.118921374344891
# (C_sol_values[-1] - C_l_values[-1]): 6.606433809797085e-05
# C_g_values[-1]: 1.1189874386829888
# C_l_values[-1]: 0.9310548944100104
# C_sol_values[-1]: 0.9311209587481084
# Iteration 3614:
# Time: 3613 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.118987 mol/m³
# CO2 concentration in liquid phase: 0.931055 mol/m³
# Equilibrium concentration in liquid phase: 0.931121 mol/m³
#
# mass_transfer_rate: 1.772387956031574e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.118921486110258
# (C_sol_values[-1] - C_l_values[-1]): 6.58831484213751e-05
# C_g_values[-1]: 1.1189873692586794
# C_l_values[-1]: 0.9310550178310049
# C_sol_values[-1]: 0.9311209009794262
# Iteration 3615:
# Time: 3614 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.118987 mol/m³
# CO2 concentration in liquid phase: 0.931055 mol/m³
# Equilibrium concentration in liquid phase: 0.931121 mol/m³
#
# mass_transfer_rate: 1.7675269612924007e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1189215975690945
# (C_sol_values[-1] - C_l_values[-1]): 6.570245568038313e-05
# C_g_values[-1]: 1.1189873000247748
# C_l_values[-1]: 0.9310551409135018
# C_sol_values[-1]: 0.9311208433691822
# Iteration 3616:
# Time: 3615 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.118987 mol/m³
# CO2 concentration in liquid phase: 0.931055 mol/m³
# Equilibrium concentration in liquid phase: 0.931121 mol/m³
#
# mass_transfer_rate: 1.7626792984341117e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1189217087222412
# (C_sol_values[-1] - C_l_values[-1]): 6.552225851164106e-05
# C_g_values[-1]: 1.118987230980753
# C_l_values[-1]: 0.9310552636584297
# C_sol_values[-1]: 0.9311207859169414
# Iteration 3617:
# Time: 3616 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.118987 mol/m³
# CO2 concentration in liquid phase: 0.931055 mol/m³
# Equilibrium concentration in liquid phase: 0.931121 mol/m³
#
# mass_transfer_rate: 1.757844930890281e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1189218195705368
# (C_sol_values[-1] - C_l_values[-1]): 6.534255555590285e-05
# C_g_values[-1]: 1.1189871621260927
# C_l_values[-1]: 0.9310553860667143
# C_sol_values[-1]: 0.9311207286222702
# Iteration 3618:
# Time: 3617 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.118987 mol/m³
# CO2 concentration in liquid phase: 0.931056 mol/m³
# Equilibrium concentration in liquid phase: 0.931121 mol/m³
#
# mass_transfer_rate: 1.7530238222079765e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.118921930114817
# (C_sol_values[-1] - C_l_values[-1]): 6.516334545814129e-05
# C_g_values[-1]: 1.118987093460275
# C_l_values[-1]: 0.931055508139279
# C_sol_values[-1]: 0.9311206714847371
# Iteration 3619:
# Time: 3618 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.118987 mol/m³
# CO2 concentration in liquid phase: 0.931056 mol/m³
# Equilibrium concentration in liquid phase: 0.931121 mol/m³
#
# mass_transfer_rate: 1.7482159360089355e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.118922040355916
# (C_sol_values[-1] - C_l_values[-1]): 6.498462686610473e-05
# C_g_values[-1]: 1.118987024982782
# C_l_values[-1]: 0.9310556298770444
# C_sol_values[-1]: 0.9311206145039105
# Iteration 3620:
# Time: 3619 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.118987 mol/m³
# CO2 concentration in liquid phase: 0.931056 mol/m³
# Equilibrium concentration in liquid phase: 0.931121 mol/m³
#
# mass_transfer_rate: 1.7434212360492965e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1189221502946645
# (C_sol_values[-1] - C_l_values[-1]): 6.480639843253755e-05
# C_g_values[-1]: 1.118986956693097
# C_l_values[-1]: 0.9310557512809288
# C_sol_values[-1]: 0.9311205576793613
# Iteration 3621:
# Time: 3620 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.118987 mol/m³
# CO2 concentration in liquid phase: 0.931056 mol/m³
# Equilibrium concentration in liquid phase: 0.931121 mol/m³
#
# mass_transfer_rate: 1.7386396861449334e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1189222599318926
# (C_sol_values[-1] - C_l_values[-1]): 6.462865881240454e-05
# C_g_values[-1]: 1.118986888590705
# C_l_values[-1]: 0.931055872351848
# C_sol_values[-1]: 0.9311205010106604
# Iteration 3622:
# Time: 3621 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.118987 mol/m³
# CO2 concentration in liquid phase: 0.931056 mol/m³
# Equilibrium concentration in liquid phase: 0.931120 mol/m³
#
# mass_transfer_rate: 1.733871250231188e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1189223692684274
# (C_sol_values[-1] - C_l_values[-1]): 6.44514066651114e-05
# C_g_values[-1]: 1.1189868206750924
# C_l_values[-1]: 0.9310559930907151
# C_sol_values[-1]: 0.9311204444973802
# Iteration 3623:
# Time: 3622 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.118987 mol/m³
# CO2 concentration in liquid phase: 0.931056 mol/m³
# Equilibrium concentration in liquid phase: 0.931120 mol/m³
#
# mass_transfer_rate: 1.7291158923568985e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1189224783050924
# (C_sol_values[-1] - C_l_values[-1]): 6.427464065428268e-05
# C_g_values[-1]: 1.1189867529457467
# C_l_values[-1]: 0.9310561134984408
# C_sol_values[-1]: 0.931120388139095
# Iteration 3624:
# Time: 3623 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.118987 mol/m³
# CO2 concentration in liquid phase: 0.931056 mol/m³
# Equilibrium concentration in liquid phase: 0.931120 mol/m³
#
# mass_transfer_rate: 1.7243735766366102e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.118922587042711
# (C_sol_values[-1] - C_l_values[-1]): 6.409835944598541e-05
# C_g_values[-1]: 1.118986685402157
# C_l_values[-1]: 0.9310562335759333
# C_sol_values[-1]: 0.9311203319353792
# Iteration 3625:
# Time: 3624 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.118987 mol/m³
# CO2 concentration in liquid phase: 0.931056 mol/m³
# Equilibrium concentration in liquid phase: 0.931120 mol/m³
#
# mass_transfer_rate: 1.7196442673132976e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.118922695482103
# (C_sol_values[-1] - C_l_values[-1]): 6.392256171106059e-05
# C_g_values[-1]: 1.1189866180438142
# C_l_values[-1]: 0.9310563533240983
# C_sol_values[-1]: 0.9311202758858094
# Iteration 3626:
# Time: 3625 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.118987 mol/m³
# CO2 concentration in liquid phase: 0.931056 mol/m³
# Equilibrium concentration in liquid phase: 0.931120 mol/m³
#
# mass_transfer_rate: 1.714927928704604e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1189228036240868
# (C_sol_values[-1] - C_l_values[-1]): 6.374724612312477e-05
# C_g_values[-1]: 1.11898655087021
# C_l_values[-1]: 0.9310564727438391
# C_sol_values[-1]: 0.9311202199899622
# Iteration 3627:
# Time: 3626 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.118986 mol/m³
# CO2 concentration in liquid phase: 0.931057 mol/m³
# Equilibrium concentration in liquid phase: 0.931120 mol/m³
#
# mass_transfer_rate: 1.7102245252446532e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1189229114694776
# (C_sol_values[-1] - C_l_values[-1]): 6.357241136012437e-05
# C_g_values[-1]: 1.1189864838808377
# C_l_values[-1]: 0.9310565918360564
# C_sol_values[-1]: 0.9311201642474165
# Iteration 3628:
# Time: 3627 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.118986 mol/m³
# CO2 concentration in liquid phase: 0.931057 mol/m³
# Equilibrium concentration in liquid phase: 0.931120 mol/m³
#
# mass_transfer_rate: 1.7055340214541854e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.118923019019089
# (C_sol_values[-1] - C_l_values[-1]): 6.339805610322546e-05
# C_g_values[-1]: 1.1189864170751922
# C_l_values[-1]: 0.9310567106016484
# C_sol_values[-1]: 0.9311201086577516
# Iteration 3629:
# Time: 3628 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.118986 mol/m³
# CO2 concentration in liquid phase: 0.931057 mol/m³
# Equilibrium concentration in liquid phase: 0.931120 mol/m³
#
# mass_transfer_rate: 1.7008563819554887e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.118923126273732
# (C_sol_values[-1] - C_l_values[-1]): 6.322417903736888e-05
# C_g_values[-1]: 1.1189863504527695
# C_l_values[-1]: 0.931056829041511
# C_sol_values[-1]: 0.9311200532205484
# Iteration 3630:
# Time: 3629 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.118986 mol/m³
# CO2 concentration in liquid phase: 0.931057 mol/m³
# Equilibrium concentration in liquid phase: 0.931120 mol/m³
#
# mass_transfer_rate: 1.6961915714604527e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1189232332342163
# (C_sol_values[-1] - C_l_values[-1]): 6.30507788508261e-05
# C_g_values[-1]: 1.118986284013067
# C_l_values[-1]: 0.9310569471565375
# C_sol_values[-1]: 0.9311199979353884
# Iteration 3631:
# Time: 3630 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.118986 mol/m³
# CO2 concentration in liquid phase: 0.931057 mol/m³
# Equilibrium concentration in liquid phase: 0.931120 mol/m³
#
# mass_transfer_rate: 1.69153955479745e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1189233399013476
# (C_sol_values[-1] - C_l_values[-1]): 6.287785423619852e-05
# C_g_values[-1]: 1.1189862177555838
# C_l_values[-1]: 0.9310570649476189
# C_sol_values[-1]: 0.9311199428018551
# Iteration 3632:
# Time: 3631 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.118986 mol/m³
# CO2 concentration in liquid phase: 0.931057 mol/m³
# Equilibrium concentration in liquid phase: 0.931120 mol/m³
#
# mass_transfer_rate: 1.6869002968695196e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1189234462759312
# (C_sol_values[-1] - C_l_values[-1]): 6.270540388886303e-05
# C_g_values[-1]: 1.11898615167982
# C_l_values[-1]: 0.9310571824156435
# C_sol_values[-1]: 0.9311198878195324
# Iteration 3633:
# Time: 3632 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.118986 mol/m³
# CO2 concentration in liquid phase: 0.931057 mol/m³
# Equilibrium concentration in liquid phase: 0.931120 mol/m³
#
# mass_transfer_rate: 1.6822737626782636e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1189235523587693
# (C_sol_values[-1] - C_l_values[-1]): 6.253342650786031e-05
# C_g_values[-1]: 1.1189860857852771
# C_l_values[-1]: 0.9310572995614974
# C_sol_values[-1]: 0.9311198329880053
# Iteration 3634:
# Time: 3633 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.118986 mol/m³
# CO2 concentration in liquid phase: 0.931057 mol/m³
# Equilibrium concentration in liquid phase: 0.931120 mol/m³
#
# mass_transfer_rate: 1.677659917341766e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1189236581506616
# (C_sol_values[-1] - C_l_values[-1]): 6.236192079656089e-05
# C_g_values[-1]: 1.1189860200714583
# C_l_values[-1]: 0.9310574163860642
# C_sol_values[-1]: 0.9311197783068608
# Iteration 3635:
# Time: 3634 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.118986 mol/m³
# CO2 concentration in liquid phase: 0.931058 mol/m³
# Equilibrium concentration in liquid phase: 0.931120 mol/m³
#
# mass_transfer_rate: 1.6730587260408322e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1189237636524072
# (C_sol_values[-1] - C_l_values[-1]): 6.219088546066676e-05
# C_g_values[-1]: 1.1189859545378678
# C_l_values[-1]: 0.9310575328902251
# C_sol_values[-1]: 0.9311197237756857
# Iteration 3636:
# Time: 3635 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.118986 mol/m³
# CO2 concentration in liquid phase: 0.931058 mol/m³
# Equilibrium concentration in liquid phase: 0.931120 mol/m³
#
# mass_transfer_rate: 1.668470154081709e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.1189238688648007
# (C_sol_values[-1] - C_l_values[-1]): 6.202031921054285e-05
# C_g_values[-1]: 1.1189858891840112
# C_l_values[-1]: 0.9310576490748589
# C_sol_values[-1]: 0.9311196693940694
# Iteration 3637:
# Time: 3636 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.118986 mol/m³
# CO2 concentration in liquid phase: 0.931058 mol/m³
# Equilibrium concentration in liquid phase: 0.931120 mol/m³
#
# mass_transfer_rate: 1.663894166854272e-08
# (C_g_values[-1] - (C_sol_values[-1] - C_l_values[-1]): 1.118923973788636
# (C_sol_values[-1] - C_l_values[-1]): 6.185022075966273e-05
# C_g_values[-1]: 1.1189858240093957
# C_l_values[-1]: 0.9310577649408418
# C_sol_values[-1]: 0.9311196151616015
# Iteration 3638:
# Time: 3637 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 1.118986 mol/m³
# CO2 concentration in liquid phase: 0.931058 mol/m³
# Equilibrium concentration in liquid phase: 0.931120 mol/m³
#
# Mass transfer rate is less than 1 umol/minute. Breaking loop.

# %%
# Print final concentrations and mass transfer rate at the end of the simulation
final_mass_transfer_rate = k * available_surface_area * (C_g_values[-1] - C_l_values[-1])
print(f"Final concentration of CO2 in the gas phase: {C_g_values[-1]:.6f} mol/m³")
print(f"Final concentration of CO2 in the liquid phase: {C_l_values[-1]:.6f} mol/m³")
print(f"Final mass transfer rate: {final_mass_transfer_rate:.6f} mol/s")

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(time_points, C_g_values, label='CO2 concentration in gas phase')
plt.plot(time_points, C_l_values, label='CO2 concentration in liquid phase')
plt.plot(time_points, C_sol_values, label='CO2 solubility in liquid phase')
plt.xlabel('Time (seconds)')
plt.ylabel('CO2 concentration (mol/m³)')
plt.title('CO2 Concentration in Gas and Liquid Phases Over Time')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Final concentration of CO2 in the gas phase: 1.118986 mol/m³
# Final concentration of CO2 in the liquid phase: 0.931058 mol/m³
# Final mass transfer rate: 0.000051 mol/s
