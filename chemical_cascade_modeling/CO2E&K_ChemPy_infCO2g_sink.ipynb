# %% [markdown]
# Notes on version:
#
# *   With ChemPy
# *   No drop in CO2(g) (assuming infinite supply)
# *   CO2(aq) governed by MT
# *   [H2CO3] production governed by ChemPy
# *   [H2CO3] removal governed by K_carb * [H2CO3] * x
# *   Assumes constant pressure of 1 atm
# *   Output as time to reach set target mass of captured CO2 as a % of concrete (mass for mass)
# *   Output of flow rate CO2 to maintain steady state *** change to average flow rate and plot ***
# *   increasing K_carb reduces total time -> problem!

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# Ensure ChemPy is installed
try:
    import chempy
except ModuleNotFoundError:
    # !pip install chempy
    import chempy

from chempy.kinetics.ode import get_odesys
from chempy.kinetics.rates import MassAction
from chempy import ReactionSystem
from chempy.chemistry import Reaction, Substance

# Constants
R = 8.314  # Universal gas constant, J/(mol·K)
print(f"R: {R} J/(mol·K)")
T = 298.15  # Temperature in Kelvin (25°C)
print(f"T: {T} K")
H_atm = 29.4  # Henry's Law constant for CO2 in water at 25°C, atm·m³/mol
print(f"H_atm: {H_atm} atm·m³/mol")
H_Pa = H_atm * 101325  # Henry's Law constant in Pa·m³/mol
print(f"H_Pa: {H_Pa} Pa·m³/mol")
k = 1e-1  # Mass transfer coefficient, m/s
print(f"k: {k} m/s")
hydration_level = 0.1  # 10%
print(f"hydration_level: {hydration_level}")
rho_concrete = 2400  # Density of concrete, kg/m³
print(f"rho_concrete: {rho_concrete} kg/m³")
rho_water = 1000  # Density of water, kg/m³
print(f"rho_water: {rho_water} kg/m³")
wetting_coefficient = 0.8  # Wetting coefficient
print(f"wetting_coefficient: {wetting_coefficient}")
P_total_atm = 1.0  # Total pressure in atm (standard pressure)
P_total_Pa = P_total_atm * 101325  # Total pressure in Pa (standard pressure)
print(f"P_total_atm: {P_total_atm} atm")
print(f"P_total_Pa: {P_total_Pa} Pa")
percentage_CO2 = 1  # Percentage of CO2 input
print(f"percentage_CO2: {percentage_CO2}")
K_carb = 1  # Define K_carb appropriately
print(f"K_carb: {K_carb} ")

# Rate constants for the reaction CO2 + H2O <-> H2CO3 NATIVE
k_forward = 0.039  # Forward rate constant (1/s)
k_reverse = 23  # Reverse rate constant (1/s)

# Rate constants for the reaction CO2 + H2O <-> H2CO3 CA
#k_forward = .39  # Forward rate constant (1/s)
#k_reverse = 230  # Reverse rate constant (1/s)

#Variables
Reactor_dia = 10  # Insert the diameter of the reactor
Reactor_height = 30  # Insert the height of the reactor

# Calculate the volume of the cylindrical reactor
V = math.pi * (Reactor_dia / 2) ** 2 * Reactor_height

print(f"V: {V:.4g} m³")
# Out:
# R: 8.314 J/(mol·K)
# T: 298.15 K
# H_atm: 29.4 atm·m³/mol
# H_Pa: 2978955.0 Pa·m³/mol
# k: 0.1 m/s
# hydration_level: 0.1
# rho_concrete: 2400 kg/m³
# rho_water: 1000 kg/m³
# wetting_coefficient: 0.8
# P_total_atm: 1.0 atm
# P_total_Pa: 101325.0 Pa
# percentage_CO2: 1
# K_carb: 1
# V: 2356 m³

# %%
# Function to calculate total surface area
def calculate_surface_area_normal_distribution(mean_diameter, std_deviation, min_diameter, max_diameter, reactor_volume, void_fraction, num_samples=100000):
    diameters = np.random.normal(loc=mean_diameter, scale=std_deviation, size=num_samples)
    diameters = diameters[(diameters >= min_diameter) & (diameters <= max_diameter)]
    radii = diameters / 2
    volumes = (4/3) * np.pi * (radii ** 3)
    total_particle_volume = reactor_volume * (1 - void_fraction)
    total_volume_of_sampled_particles = np.sum(volumes)
    scaling_factor = total_particle_volume / total_volume_of_sampled_particles
    surface_areas = 4 * np.pi * (radii ** 2)
    total_surface_area = np.sum(surface_areas * scaling_factor)
    return total_surface_area

# Example usage:
mean_diameter = 0.01  # Mean diameter of 1 cm in meters
print(f"mean_diameter: {mean_diameter} m")
std_deviation = 0.002  # Standard deviation of 0.2 cm in meters
print(f"std_deviation: {std_deviation} m")
min_diameter = 0.005  # Minimum diameter of 0.5 cm in meters
print(f"min_diameter: {min_diameter} m")
max_diameter = 0.015  # Maximum diameter of 1.5 cm in meters
print(f"max_diameter: {max_diameter} m")
reactor_volume = V  # meter
print(f"reactor_volume: {reactor_volume} m³")
void_fraction = 0.5  # 40% void fraction
print(f"void_fraction: {void_fraction}")

total_surface_area = calculate_surface_area_normal_distribution(
    mean_diameter, std_deviation, min_diameter, max_diameter, reactor_volume, void_fraction
)

# Total surface area
print("total_surface_area:", f"{total_surface_area:.4g}", "m²")

# Available surface area for gas exchange
available_surface_area = total_surface_area * wetting_coefficient
print("available_surface_area:", f"{available_surface_area:.4g}", "m²")
# Out:
# mean_diameter: 0.01 m
# std_deviation: 0.002 m
# min_diameter: 0.005 m
# max_diameter: 0.015 m
# reactor_volume: 2356.194490192345 m³
# void_fraction: 0.5
# total_surface_area: 6.605e+05 m²
# available_surface_area: 5.284e+05 m²

# %%
# Total reactor volume
print(f"reactor_volume: {reactor_volume} m³")
#void_fraction = 0.4  # 40% void fraction
print(f"void_fraction: {void_fraction} m³")

# Solid phase volume and mass
solid_volume = reactor_volume * (1 - void_fraction)
solid_mass = solid_volume * rho_concrete
print("solid_volume:", f"{solid_volume:.4g}", "m³")
print("solid_mass:", f"{solid_mass:.4g}", "kg")

# Liquid phase mass and volume
liquid_mass = hydration_level * solid_mass
liquid_volume = liquid_mass / rho_water
print("liquid_volume:", f"{liquid_volume:.4g}", "m³")
print("liquid_mass:", f"{liquid_mass:.4g}", "kg")

# Gas phase volume
gas_volume = reactor_volume - solid_volume - liquid_volume
print("gas_volume:", f"{gas_volume:.4g}", "m³")

# Calculate the partial pressure of CO2 in gas phase
P_CO2 = percentage_CO2 * P_total_Pa
print(f"P_CO2: {P_CO2:.4g} Pa")

# Convert partial pressure to concentration in mol/m³
n_CO2 = P_CO2 / (R * T) * gas_volume
concentration_CO2 = n_CO2 / gas_volume
print("n_CO2:", f"{n_CO2:.4g}", "mol")
print("concentration_CO2:", f"{concentration_CO2:.4g}", "mol/m³")


# Initial partial pressure of CO2 in the gas phase
P_CO2_initial = concentration_CO2 * R * T
print("P_CO2_initial:", f"{P_CO2_initial:.4g}", "Pa")


# Initial equilibrium concentration of CO2 in the liquid phase using Henry's Law and standard CO2 concentration in air
C_l_initial_eq = ((P_total_Pa * 0.0004) / H_Pa)*1000
print("C_l_initial_eq (eq in air):", f"{C_l_initial_eq:.4g}", "mol/m³")
#print(f"P_CO2: {(P_total_Pa * 0.0004):.4g} Pa")


# CO2 solubility
C_sol_initial = (P_CO2 / H_Pa)*1000
print("C_sol_initial:", f"{C_sol_initial:.4g}", "mol/m³")

# Initial concentration of CO2 in the gas phase
C_g_initial = P_CO2_initial / (R * T)
print("C_g_initial:", f"{C_g_initial:.4g}", "mol/m³")

# Initial concentration of carbonic acid
H2CO3_initial = 0.0  # Initial concentration of H2CO3 in liquid phase (mol/m³)
print("H2CO3_initial:", f"{H2CO3_initial:.4g}", "mol/m³")

target_removal_mass = 0.01 * solid_mass
print("target_removal_mass:", f"{target_removal_mass:.4g}", "kg")
print("target_removal_mass:", f"{0.001 * target_removal_mass:.4g}", "Tonnes")

# Lists to store results
time_points = [0]  # Initial time
C_g_values = [C_g_initial]  # Initial gas phase CO2 concentration
C_l_values = [C_l_initial_eq]  # Initial liquid phase CO2 concentration
C_sol_values = [C_sol_initial]  # CO2 solubiliy
mass_transfer_rates = []  # Mass transfer rates
CO2_transferred = []  # CO2 transferred from gas to liquid phase
H2CO3_values = [H2CO3_initial]  # Initial carbonic acid concentration
cumulative_moles_removed = 0
cumulative_removal_values = [0]
cumulative_mass_removed = [0]
C_flow_values = [0]

# Initial total moles of carbon in the system
initial_moles_CO2_gas = C_g_values[0] * gas_volume
initial_moles_CO2_liquid = C_l_values[0] * liquid_volume
initial_moles_H2CO3 = H2CO3_values[0] * liquid_volume
initial_total_moles_carbon = initial_moles_CO2_gas + initial_moles_CO2_liquid + initial_moles_H2CO3
total_moles_carbon_values = [initial_total_moles_carbon]



print(f"Initial moles CO2 (gas): {initial_moles_CO2_gas:.6f} mol")
print(f"Initial moles CO2 (liquid): {initial_moles_CO2_liquid:.6f} mol")
print(f"Initial moles H2CO3: {initial_moles_H2CO3:.6f} mol")
print(f"Initial total moles of carbon: {initial_total_moles_carbon:.6f} mol")
# Out:
# reactor_volume: 2356.194490192345 m³
# void_fraction: 0.5 m³
# solid_volume: 1178 m³
# solid_mass: 2.827e+06 kg
# liquid_volume: 282.7 m³
# liquid_mass: 2.827e+05 kg
# gas_volume: 895.4 m³
# P_CO2: 1.013e+05 Pa
# n_CO2: 3.66e+04 mol
# concentration_CO2: 40.88 mol/m³
# P_CO2_initial: 1.013e+05 Pa
# C_l_initial_eq (eq in air): 0.01361 mol/m³
# C_sol_initial: 34.01 mol/m³
# C_g_initial: 40.88 mol/m³
# H2CO3_initial: 0 mol/m³
# target_removal_mass: 2.827e+04 kg
# target_removal_mass: 28.27 Tonnes
# Initial moles CO2 (gas): 36598.771791 mol
# Initial moles CO2 (liquid): 3.846848 mol
# Initial moles H2CO3: 0.000000 mol
# Initial total moles of carbon: 36602.618640 mol

# %%
# Define the reaction system
substances = {
    'CO2(aq)': Substance('CO2(aq)'),
    'H2O': Substance('H2O'),
    'H2CO3(aq)': Substance('H2CO3(aq)')
}

reactions = [
    Reaction({'CO2(aq)': 1, 'H2O': 1}, {'H2CO3(aq)': 1}, MassAction(k_forward)),
    Reaction({'H2CO3(aq)': 1}, {'CO2(aq)': 1, 'H2O': 1}, MassAction(k_reverse))
]

rsys = ReactionSystem(reactions, substances)

# ODE system
odesys, extra = get_odesys(rsys)

# %%
# Main loop
iteration = 0
while cumulative_mass_removed [-1] < target_removal_mass:
#while True:
    iteration += 1
    if iteration == 100000:
        break

    if len(C_sol_values) > 0 and C_l_values[-1] < C_sol_values[-1]:
        mass_transfer_rate = k * available_surface_area * (C_sol_values[-1] - C_l_values[-1])
        mass_transfer_rates.append(mass_transfer_rate)
    else:
        mass_transfer_rate = 0

    # Limit the time step to prevent large changes in concentrations
    time_step = min(1, 0.1 * gas_volume / abs(mass_transfer_rate)) if mass_transfer_rate != 0 else 1

    # Update concentrations in gas and liquid phases
    #C_g_new = C_g_values[-1] - mass_transfer_rate * time_step / gas_volume
    C_g_new = C_g_values[-1]
    C_l_new = C_l_values[-1] + mass_transfer_rate * time_step / liquid_volume

    # Solve the equilibrium reaction using ChemPy
    y0 = {'CO2(aq)': (C_l_new/1000), 'H2O': 55.5, 'H2CO3(aq)': (H2CO3_values[-1]/1000)}
    params = {}

    result = odesys.integrate([0, time_step], y0, params=params)

    # Extract the concentration values from the result object
    H2CO3_index = odesys.names.index('H2CO3(aq)')
    CO2_index = odesys.names.index('CO2(aq)')
    H2CO3_new = 1000* result.yout[-1][H2CO3_index]  # Extract H2CO3(aq) concentration at the end of the time step
    CO2_l_new =1000* result.yout[-1][CO2_index]  # Extract CO2(aq) concentration at the end of the time step

    # Update the liquid phase CO2 concentration based on the formation of H2CO3
    C_l_new = CO2_l_new

    # Remove H2CO3 from the system
    removal_rate = (H2CO3_new * K_carb * time_step) #mol/m3/s

    #removal_rate = K_carb * time_step / liquid_volume
    if (H2CO3_new - removal_rate)  > 0:
        # Remove H2CO3 from the liquid phase
        H2CO3_new = H2CO3_new - removal_rate

    else:
        H2CO3_new = H2CO3_new  # no removal

    CO2_consumption_rate = removal_rate * liquid_volume #mol/s
    CO2_flow_rate = (CO2_consumption_rate * R * T) / P_total_atm
    print(f"CO2 flow rate required: {CO2_flow_rate:.6f} cubic meters per second")

    # Calculate new equilibrium concentration in the liquid phase considering the updated gas phase concentration
    if C_g_new > 0:
        #P_CO2_gas_new = C_g_new * R * T
        P_CO2_gas_new = C_g_new * R * T
        C_sol_new = (P_CO2_gas_new / H_Pa) * 1000  # Convert to mol/m³
    else:
        break

    # Update time and concentrations for the next iteration
    time_points.append(time_points[-1] + time_step)
    C_g_values.append(C_g_new)
    C_l_values.append(C_l_new)
    C_sol_values.append(C_sol_new)
    H2CO3_values.append(H2CO3_new)
    cumulative_removal_values.append(cumulative_removal_values[-1] + (removal_rate * liquid_volume))
    cumulative_mass_removed.append(44*0.001*(cumulative_removal_values[-1]))
    C_flow_values.append(CO2_flow_rate)

    total_moles_CO2_gas = C_g_values[-1] * gas_volume
    total_moles_CO2_liquid = C_l_values[-1] * liquid_volume
    total_moles_H2CO3 = H2CO3_values[-1] * liquid_volume
    total_moles_carbon = total_moles_CO2_gas + total_moles_CO2_liquid + total_moles_H2CO3 + cumulative_removal_values[-1]
    total_moles_carbon_values.append(total_moles_carbon)

    print("")
    print(f"Iteration {iteration}:")
    print(f"Time: {time_points[-1]} seconds")
    print(f"Time step: {time_step:.6f} seconds")
    print(f"Mass transfer rate: {mass_transfer_rate:.6f} mol/s")
    print(f"CO2 concentration in gas phase: {C_g_new:.6f} mol/m³")
    print(f"CO2 concentration in liquid phase: {C_l_new:.6f} mol/m³")
    print(f"Equilibrium concentration in liquid phase: {C_sol_new:.6f} mol/m³")
    print(f"Carbonic acid concentration: {H2CO3_new:.6f} mol/m³")
    print(f"Removal rate: {removal_rate:.6f} mol/s")
    print(f"Total moles CO2 (gas): {total_moles_CO2_gas:.6f} mol")
    print(f"Total moles CO2 (liquid): {total_moles_CO2_liquid:.6f} mol")
    print(f"Total moles H2CO3: {total_moles_H2CO3:.6f} mol")
    print(f"Cumulative moles removed: {cumulative_removal_values[-1]:.6f} mol")
    print(f"cumulative_mass_removed: {cumulative_mass_removed[-1]:.6f} kg")
    print(f"C_flow_values: {C_flow_values[-1]:.6f} m3/s")
    #print(f"Total moles of carbon: {total_moles_carbon:.6f} mol\n")

    # Check if the mass transfer rate is less than 100 umol/minute
    #if abs(mass_transfer_rate) < 1e-7 / 60:
    #    print("Mass transfer rate is less than 100 umol/minute. Breaking loop.")
    #    break
# Out:
# /usr/local/lib/python3.10/dist-packages/pyodesys/core.py:519: UserWarning: 'adaptive' mode with SciPy's integrator (vode/lsoda) may overshoot (itask=2)
#   warnings.warn("'adaptive' mode with SciPy's integrator (vode/lsoda) may overshoot (itask=2)")
# /usr/local/lib/python3.10/dist-packages/pyodesys/core.py:520: UserWarning: 'adaptive' mode with SciPy's integrator is unreliable, consider using e.g. cvode
#   warnings.warn("'adaptive' mode with SciPy's integrator is unreliable, consider using e.g. cvode")
# Streaming output truncated to the last 5000 lines.
# cumulative_mass_removed: 16554.422869 kg
# C_flow_values: 2246600.389808 m3/s
# CO2 flow rate required: 2246600.305424 cubic meters per second
#
# Iteration 535:
# Time: 416.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553395 mol
# Total moles H2CO3: 906.318781 mol
# Cumulative moles removed: 377143.202161 mol
# cumulative_mass_removed: 16594.300895 kg
# C_flow_values: 2246600.305424 m3/s
# CO2 flow rate required: 2246600.389797 cubic meters per second
#
# Iteration 536:
# Time: 417.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 378049.520976 mol
# cumulative_mass_removed: 16634.178923 kg
# C_flow_values: 2246600.389797 m3/s
# CO2 flow rate required: 2246600.480561 cubic meters per second
#
# Iteration 537:
# Time: 418.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553324 mol
# Total moles H2CO3: 906.318852 mol
# Cumulative moles removed: 378955.839828 mol
# cumulative_mass_removed: 16674.056952 kg
# C_flow_values: 2246600.480561 m3/s
# CO2 flow rate required: 2246600.389809 cubic meters per second
#
# Iteration 538:
# Time: 419.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 379862.158643 mol
# cumulative_mass_removed: 16713.934980 kg
# C_flow_values: 2246600.389809 m3/s
# CO2 flow rate required: 2246600.295467 cubic meters per second
#
# Iteration 539:
# Time: 420.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553399 mol
# Total moles H2CO3: 906.318777 mol
# Cumulative moles removed: 380768.477420 mol
# cumulative_mass_removed: 16753.813006 kg
# C_flow_values: 2246600.295467 m3/s
# CO2 flow rate required: 2246600.389796 cubic meters per second
#
# Iteration 540:
# Time: 421.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 381674.796235 mol
# cumulative_mass_removed: 16793.691034 kg
# C_flow_values: 2246600.389796 m3/s
# CO2 flow rate required: 2246600.486223 cubic meters per second
#
# Iteration 541:
# Time: 422.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553322 mol
# Total moles H2CO3: 906.318854 mol
# Cumulative moles removed: 382581.115089 mol
# cumulative_mass_removed: 16833.569064 kg
# C_flow_values: 2246600.486223 m3/s
# CO2 flow rate required: 2246600.389809 cubic meters per second
#
# Iteration 542:
# Time: 423.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 383487.433904 mol
# cumulative_mass_removed: 16873.447092 kg
# C_flow_values: 2246600.389809 m3/s
# CO2 flow rate required: 2246600.292138 cubic meters per second
#
# Iteration 543:
# Time: 424.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553400 mol
# Total moles H2CO3: 906.318776 mol
# Cumulative moles removed: 384393.752680 mol
# cumulative_mass_removed: 16913.325118 kg
# C_flow_values: 2246600.292138 m3/s
# CO2 flow rate required: 2246600.389796 cubic meters per second
#
# Iteration 544:
# Time: 425.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 385300.071495 mol
# cumulative_mass_removed: 16953.203146 kg
# C_flow_values: 2246600.389796 m3/s
# CO2 flow rate required: 2246600.488213 cubic meters per second
#
# Iteration 545:
# Time: 426.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553321 mol
# Total moles H2CO3: 906.318855 mol
# Cumulative moles removed: 386206.390350 mol
# cumulative_mass_removed: 16993.081175 kg
# C_flow_values: 2246600.488213 m3/s
# CO2 flow rate required: 2246600.389809 cubic meters per second
#
# Iteration 546:
# Time: 427.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 387112.709165 mol
# cumulative_mass_removed: 17032.959203 kg
# C_flow_values: 2246600.389809 m3/s
# CO2 flow rate required: 2246600.290930 cubic meters per second
#
# Iteration 547:
# Time: 428.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553401 mol
# Total moles H2CO3: 906.318775 mol
# Cumulative moles removed: 388019.027941 mol
# cumulative_mass_removed: 17072.837229 kg
# C_flow_values: 2246600.290930 m3/s
# CO2 flow rate required: 2246600.389796 cubic meters per second
#
# Iteration 548:
# Time: 429.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 388925.346756 mol
# cumulative_mass_removed: 17112.715257 kg
# C_flow_values: 2246600.389796 m3/s
# CO2 flow rate required: 2246600.090413 cubic meters per second
#
# Iteration 549:
# Time: 430.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553482 mol
# Total moles H2CO3: 906.318694 mol
# Cumulative moles removed: 389831.665450 mol
# cumulative_mass_removed: 17152.593280 kg
# C_flow_values: 2246600.090413 m3/s
# CO2 flow rate required: 2246600.389787 cubic meters per second
#
# Iteration 550:
# Time: 431.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 390737.984266 mol
# cumulative_mass_removed: 17192.471308 kg
# C_flow_values: 2246600.389787 m3/s
# CO2 flow rate required: 2246600.635954 cubic meters per second
#
# Iteration 551:
# Time: 432.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553262 mol
# Total moles H2CO3: 906.318915 mol
# Cumulative moles removed: 391644.303180 mol
# cumulative_mass_removed: 17232.349340 kg
# C_flow_values: 2246600.635954 m3/s
# CO2 flow rate required: 2246600.389816 cubic meters per second
#
# Iteration 552:
# Time: 433.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 392550.621995 mol
# cumulative_mass_removed: 17272.227368 kg
# C_flow_values: 2246600.389816 m3/s
# CO2 flow rate required: 2246601.010035 cubic meters per second
#
# Iteration 553:
# Time: 434.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061114 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205448 mol/m³
# Removal rate: 3.205448 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553111 mol
# Total moles H2CO3: 906.319065 mol
# Cumulative moles removed: 393456.941061 mol
# cumulative_mass_removed: 17312.105407 kg
# C_flow_values: 2246601.010035 m3/s
# CO2 flow rate required: 2246600.389978 cubic meters per second
#
# Iteration 554:
# Time: 435.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 394363.259876 mol
# cumulative_mass_removed: 17351.983435 kg
# C_flow_values: 2246600.389978 m3/s
# CO2 flow rate required: 2246600.389803 cubic meters per second
#
# Iteration 555:
# Time: 436.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 395269.578691 mol
# cumulative_mass_removed: 17391.861462 kg
# C_flow_values: 2246600.389803 m3/s
# CO2 flow rate required: 2246600.390964 cubic meters per second
#
# Iteration 556:
# Time: 437.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553360 mol
# Total moles H2CO3: 906.318816 mol
# Cumulative moles removed: 396175.897507 mol
# cumulative_mass_removed: 17431.739490 kg
# C_flow_values: 2246600.390964 m3/s
# CO2 flow rate required: 2246600.389804 cubic meters per second
#
# Iteration 557:
# Time: 438.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 397082.216322 mol
# cumulative_mass_removed: 17471.617518 kg
# C_flow_values: 2246600.389804 m3/s
# CO2 flow rate required: 2246600.373750 cubic meters per second
#
# Iteration 558:
# Time: 439.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553367 mol
# Total moles H2CO3: 906.318809 mol
# Cumulative moles removed: 397988.535131 mol
# cumulative_mass_removed: 17511.495546 kg
# C_flow_values: 2246600.373750 m3/s
# CO2 flow rate required: 2246600.389799 cubic meters per second
#
# Iteration 559:
# Time: 440.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 398894.853946 mol
# cumulative_mass_removed: 17551.373574 kg
# C_flow_values: 2246600.389799 m3/s
# CO2 flow rate required: 2246600.442740 cubic meters per second
#
# Iteration 560:
# Time: 441.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553339 mol
# Total moles H2CO3: 906.318837 mol
# Cumulative moles removed: 399801.172782 mol
# cumulative_mass_removed: 17591.251602 kg
# C_flow_values: 2246600.442740 m3/s
# CO2 flow rate required: 2246600.389808 cubic meters per second
#
# Iteration 561:
# Time: 442.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 400707.491598 mol
# cumulative_mass_removed: 17631.129630 kg
# C_flow_values: 2246600.389808 m3/s
# CO2 flow rate required: 2246600.632604 cubic meters per second
#
# Iteration 562:
# Time: 443.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553263 mol
# Total moles H2CO3: 906.318913 mol
# Cumulative moles removed: 401613.810511 mol
# cumulative_mass_removed: 17671.007662 kg
# C_flow_values: 2246600.632604 m3/s
# CO2 flow rate required: 2246600.389816 cubic meters per second
#
# Iteration 563:
# Time: 444.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 402520.129326 mol
# cumulative_mass_removed: 17710.885690 kg
# C_flow_values: 2246600.389816 m3/s
# CO2 flow rate required: 2246601.003066 cubic meters per second
#
# Iteration 564:
# Time: 445.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061114 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205448 mol/m³
# Removal rate: 3.205448 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553113 mol
# Total moles H2CO3: 906.319063 mol
# Cumulative moles removed: 403426.448389 mol
# cumulative_mass_removed: 17750.763729 kg
# C_flow_values: 2246601.003066 m3/s
# CO2 flow rate required: 2246600.389839 cubic meters per second
#
# Iteration 565:
# Time: 446.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 404332.767204 mol
# cumulative_mass_removed: 17790.641757 kg
# C_flow_values: 2246600.389839 m3/s
# CO2 flow rate required: 2246599.834369 cubic meters per second
#
# Iteration 566:
# Time: 447.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061116 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205446 mol/m³
# Removal rate: 3.205446 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553585 mol
# Total moles H2CO3: 906.318591 mol
# Cumulative moles removed: 405239.085795 mol
# cumulative_mass_removed: 17830.519775 kg
# C_flow_values: 2246599.834369 m3/s
# CO2 flow rate required: 2246600.389768 cubic meters per second
#
# Iteration 567:
# Time: 448.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 406145.404610 mol
# cumulative_mass_removed: 17870.397803 kg
# C_flow_values: 2246600.389768 m3/s
# CO2 flow rate required: 2246600.915892 cubic meters per second
#
# Iteration 568:
# Time: 449.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061114 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205448 mol/m³
# Removal rate: 3.205448 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553149 mol
# Total moles H2CO3: 906.319027 mol
# Cumulative moles removed: 407051.723638 mol
# cumulative_mass_removed: 17910.275840 kg
# C_flow_values: 2246600.915892 m3/s
# CO2 flow rate required: 2246600.389832 cubic meters per second
#
# Iteration 569:
# Time: 450.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 407958.042453 mol
# cumulative_mass_removed: 17950.153868 kg
# C_flow_values: 2246600.389832 m3/s
# CO2 flow rate required: 2246599.946765 cubic meters per second
#
# Iteration 570:
# Time: 451.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061116 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205446 mol/m³
# Removal rate: 3.205446 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553540 mol
# Total moles H2CO3: 906.318636 mol
# Cumulative moles removed: 408864.361089 mol
# cumulative_mass_removed: 17990.031888 kg
# C_flow_values: 2246599.946765 m3/s
# CO2 flow rate required: 2246600.389778 cubic meters per second
#
# Iteration 571:
# Time: 452.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 409770.679904 mol
# cumulative_mass_removed: 18029.909916 kg
# C_flow_values: 2246600.389778 m3/s
# CO2 flow rate required: 2246600.773412 cubic meters per second
#
# Iteration 572:
# Time: 453.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061114 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205448 mol/m³
# Removal rate: 3.205448 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553206 mol
# Total moles H2CO3: 906.318970 mol
# Cumulative moles removed: 410676.998874 mol
# cumulative_mass_removed: 18069.787950 kg
# C_flow_values: 2246600.773412 m3/s
# CO2 flow rate required: 2246600.389825 cubic meters per second
#
# Iteration 573:
# Time: 454.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 411583.317690 mol
# cumulative_mass_removed: 18109.665978 kg
# C_flow_values: 2246600.389825 m3/s
# CO2 flow rate required: 2246600.044755 cubic meters per second
#
# Iteration 574:
# Time: 455.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553500 mol
# Total moles H2CO3: 906.318676 mol
# Cumulative moles removed: 412489.636366 mol
# cumulative_mass_removed: 18149.544000 kg
# C_flow_values: 2246600.044755 m3/s
# CO2 flow rate required: 2246600.389784 cubic meters per second
#
# Iteration 575:
# Time: 456.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 413395.955181 mol
# cumulative_mass_removed: 18189.422028 kg
# C_flow_values: 2246600.389784 m3/s
# CO2 flow rate required: 2246600.671518 cubic meters per second
#
# Iteration 576:
# Time: 457.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205448 mol/m³
# Removal rate: 3.205448 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553247 mol
# Total moles H2CO3: 906.318929 mol
# Cumulative moles removed: 414302.274110 mol
# cumulative_mass_removed: 18229.300061 kg
# C_flow_values: 2246600.671518 m3/s
# CO2 flow rate required: 2246600.389818 cubic meters per second
#
# Iteration 577:
# Time: 458.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 415208.592925 mol
# cumulative_mass_removed: 18269.178089 kg
# C_flow_values: 2246600.389818 m3/s
# CO2 flow rate required: 2246600.157340 cubic meters per second
#
# Iteration 578:
# Time: 459.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553455 mol
# Total moles H2CO3: 906.318721 mol
# Cumulative moles removed: 416114.911646 mol
# cumulative_mass_removed: 18309.056112 kg
# C_flow_values: 2246600.157340 m3/s
# CO2 flow rate required: 2246600.389790 cubic meters per second
#
# Iteration 579:
# Time: 460.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 417021.230461 mol
# cumulative_mass_removed: 18348.934140 kg
# C_flow_values: 2246600.389790 m3/s
# CO2 flow rate required: 2246600.584018 cubic meters per second
#
# Iteration 580:
# Time: 461.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553282 mol
# Total moles H2CO3: 906.318894 mol
# Cumulative moles removed: 417927.549355 mol
# cumulative_mass_removed: 18388.812172 kg
# C_flow_values: 2246600.584018 m3/s
# CO2 flow rate required: 2246600.389814 cubic meters per second
#
# Iteration 581:
# Time: 462.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 418833.868170 mol
# cumulative_mass_removed: 18428.690199 kg
# C_flow_values: 2246600.389814 m3/s
# CO2 flow rate required: 2246600.224339 cubic meters per second
#
# Iteration 582:
# Time: 463.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553428 mol
# Total moles H2CO3: 906.318748 mol
# Cumulative moles removed: 419740.186919 mol
# cumulative_mass_removed: 18468.568224 kg
# C_flow_values: 2246600.224339 m3/s
# CO2 flow rate required: 2246600.389793 cubic meters per second
#
# Iteration 583:
# Time: 464.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 420646.505734 mol
# cumulative_mass_removed: 18508.446252 kg
# C_flow_values: 2246600.389793 m3/s
# CO2 flow rate required: 2246600.534321 cubic meters per second
#
# Iteration 584:
# Time: 465.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553303 mol
# Total moles H2CO3: 906.318873 mol
# Cumulative moles removed: 421552.824607 mol
# cumulative_mass_removed: 18548.324283 kg
# C_flow_values: 2246600.534321 m3/s
# CO2 flow rate required: 2246600.389811 cubic meters per second
#
# Iteration 585:
# Time: 466.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 422459.143423 mol
# cumulative_mass_removed: 18588.202311 kg
# C_flow_values: 2246600.389811 m3/s
# CO2 flow rate required: 2246600.260051 cubic meters per second
#
# Iteration 586:
# Time: 467.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553413 mol
# Total moles H2CO3: 906.318763 mol
# Cumulative moles removed: 423365.462185 mol
# cumulative_mass_removed: 18628.080336 kg
# C_flow_values: 2246600.260051 m3/s
# CO2 flow rate required: 2246600.389795 cubic meters per second
#
# Iteration 587:
# Time: 468.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 424271.781001 mol
# cumulative_mass_removed: 18667.958364 kg
# C_flow_values: 2246600.389795 m3/s
# CO2 flow rate required: 2246600.026011 cubic meters per second
#
# Iteration 588:
# Time: 469.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553508 mol
# Total moles H2CO3: 906.318668 mol
# Cumulative moles removed: 425178.099669 mol
# cumulative_mass_removed: 18707.836385 kg
# C_flow_values: 2246600.026011 m3/s
# CO2 flow rate required: 2246600.389783 cubic meters per second
#
# Iteration 589:
# Time: 470.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 426084.418484 mol
# cumulative_mass_removed: 18747.714413 kg
# C_flow_values: 2246600.389783 m3/s
# CO2 flow rate required: 2246600.686196 cubic meters per second
#
# Iteration 590:
# Time: 471.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205448 mol/m³
# Removal rate: 3.205448 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553241 mol
# Total moles H2CO3: 906.318935 mol
# Cumulative moles removed: 426990.737419 mol
# cumulative_mass_removed: 18787.592446 kg
# C_flow_values: 2246600.686196 m3/s
# CO2 flow rate required: 2246600.389819 cubic meters per second
#
# Iteration 591:
# Time: 472.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 427897.056234 mol
# cumulative_mass_removed: 18827.470474 kg
# C_flow_values: 2246600.389819 m3/s
# CO2 flow rate required: 2246601.131570 cubic meters per second
#
# Iteration 592:
# Time: 473.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061114 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205448 mol/m³
# Removal rate: 3.205448 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553062 mol
# Total moles H2CO3: 906.319114 mol
# Cumulative moles removed: 428803.375349 mol
# cumulative_mass_removed: 18867.348515 kg
# C_flow_values: 2246601.131570 m3/s
# CO2 flow rate required: 2246600.419018 cubic meters per second
#
# Iteration 593:
# Time: 474.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553349 mol
# Total moles H2CO3: 906.318827 mol
# Cumulative moles removed: 429709.694176 mol
# cumulative_mass_removed: 18907.226544 kg
# C_flow_values: 2246600.419018 m3/s
# CO2 flow rate required: 2246600.392053 cubic meters per second
#
# Iteration 594:
# Time: 475.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553360 mol
# Total moles H2CO3: 906.318816 mol
# Cumulative moles removed: 430616.012992 mol
# cumulative_mass_removed: 18947.104572 kg
# C_flow_values: 2246600.392053 m3/s
# CO2 flow rate required: 2246600.389804 cubic meters per second
#
# Iteration 595:
# Time: 476.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 431522.331807 mol
# cumulative_mass_removed: 18986.982600 kg
# C_flow_values: 2246600.389804 m3/s
# CO2 flow rate required: 2246600.454064 cubic meters per second
#
# Iteration 596:
# Time: 477.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553335 mol
# Total moles H2CO3: 906.318841 mol
# Cumulative moles removed: 432428.650648 mol
# cumulative_mass_removed: 19026.860629 kg
# C_flow_values: 2246600.454064 m3/s
# CO2 flow rate required: 2246600.389808 cubic meters per second
#
# Iteration 597:
# Time: 478.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 433334.969463 mol
# cumulative_mass_removed: 19066.738656 kg
# C_flow_values: 2246600.389808 m3/s
# CO2 flow rate required: 2246600.639585 cubic meters per second
#
# Iteration 598:
# Time: 479.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553260 mol
# Total moles H2CO3: 906.318916 mol
# Cumulative moles removed: 434241.288379 mol
# cumulative_mass_removed: 19106.616689 kg
# C_flow_values: 2246600.639585 m3/s
# CO2 flow rate required: 2246600.389816 cubic meters per second
#
# Iteration 599:
# Time: 480.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 435147.607194 mol
# cumulative_mass_removed: 19146.494717 kg
# C_flow_values: 2246600.389816 m3/s
# CO2 flow rate required: 2246601.024764 cubic meters per second
#
# Iteration 600:
# Time: 481.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061114 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205448 mol/m³
# Removal rate: 3.205448 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553105 mol
# Total moles H2CO3: 906.319071 mol
# Cumulative moles removed: 436053.926266 mol
# cumulative_mass_removed: 19186.372756 kg
# C_flow_values: 2246601.024764 m3/s
# CO2 flow rate required: 2246600.389970 cubic meters per second
#
# Iteration 601:
# Time: 482.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 436960.245081 mol
# cumulative_mass_removed: 19226.250784 kg
# C_flow_values: 2246600.389970 m3/s
# CO2 flow rate required: 2246600.389803 cubic meters per second
#
# Iteration 602:
# Time: 483.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 437866.563896 mol
# cumulative_mass_removed: 19266.128811 kg
# C_flow_values: 2246600.389803 m3/s
# CO2 flow rate required: 2246600.389709 cubic meters per second
#
# Iteration 603:
# Time: 484.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 438772.882711 mol
# cumulative_mass_removed: 19306.006839 kg
# C_flow_values: 2246600.389709 m3/s
# CO2 flow rate required: 2246601.824401 cubic meters per second
#
# Iteration 604:
# Time: 485.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061113 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205449 mol/m³
# Removal rate: 3.205449 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.552782 mol
# Total moles H2CO3: 906.319394 mol
# Cumulative moles removed: 439679.202105 mol
# cumulative_mass_removed: 19345.884893 kg
# C_flow_values: 2246601.824401 m3/s
# CO2 flow rate required: 2246600.389872 cubic meters per second
#
# Iteration 605:
# Time: 486.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 440585.520921 mol
# cumulative_mass_removed: 19385.762921 kg
# C_flow_values: 2246600.389872 m3/s
# CO2 flow rate required: 2246599.327719 cubic meters per second
#
# Iteration 606:
# Time: 487.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061116 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205446 mol/m³
# Removal rate: 3.205446 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553789 mol
# Total moles H2CO3: 906.318387 mol
# Cumulative moles removed: 441491.839307 mol
# cumulative_mass_removed: 19425.640930 kg
# C_flow_values: 2246599.327719 m3/s
# CO2 flow rate required: 2246600.390186 cubic meters per second
#
# Iteration 607:
# Time: 488.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 442398.158123 mol
# cumulative_mass_removed: 19465.518957 kg
# C_flow_values: 2246600.390186 m3/s
# CO2 flow rate required: 2246600.389803 cubic meters per second
#
# Iteration 608:
# Time: 489.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# ...
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553413 mol
# Total moles H2CO3: 906.318763 mol
# Cumulative moles removed: 620942.967188 mol
# cumulative_mass_removed: 27321.490556 kg
# C_flow_values: 2246600.260697 m3/s
# CO2 flow rate required: 2246600.389795 cubic meters per second
#
# Iteration 805:
# Time: 686.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 621849.286003 mol
# cumulative_mass_removed: 27361.368584 kg
# C_flow_values: 2246600.389795 m3/s
# CO2 flow rate required: 2246600.508744 cubic meters per second
#
# Iteration 806:
# Time: 687.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553313 mol
# Total moles H2CO3: 906.318863 mol
# Cumulative moles removed: 622755.604866 mol
# cumulative_mass_removed: 27401.246614 kg
# C_flow_values: 2246600.508744 m3/s
# CO2 flow rate required: 2246600.389810 cubic meters per second
#
# Iteration 807:
# Time: 688.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 623661.923681 mol
# cumulative_mass_removed: 27441.124642 kg
# C_flow_values: 2246600.389810 m3/s
# CO2 flow rate required: 2246600.732276 cubic meters per second
#
# Iteration 808:
# Time: 689.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061114 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205448 mol/m³
# Removal rate: 3.205448 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553223 mol
# Total moles H2CO3: 906.318953 mol
# Cumulative moles removed: 624568.242635 mol
# cumulative_mass_removed: 27481.002676 kg
# C_flow_values: 2246600.732276 m3/s
# CO2 flow rate required: 2246600.389821 cubic meters per second
#
# Iteration 809:
# Time: 690.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 625474.561450 mol
# cumulative_mass_removed: 27520.880704 kg
# C_flow_values: 2246600.389821 m3/s
# CO2 flow rate required: 2246600.110084 cubic meters per second
#
# Iteration 810:
# Time: 691.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553474 mol
# Total moles H2CO3: 906.318702 mol
# Cumulative moles removed: 626380.880152 mol
# cumulative_mass_removed: 27560.758727 kg
# C_flow_values: 2246600.110084 m3/s
# CO2 flow rate required: 2246600.389788 cubic meters per second
#
# Iteration 811:
# Time: 692.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 627287.198967 mol
# cumulative_mass_removed: 27600.636755 kg
# C_flow_values: 2246600.389788 m3/s
# CO2 flow rate required: 2246600.620719 cubic meters per second
#
# Iteration 812:
# Time: 693.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553268 mol
# Total moles H2CO3: 906.318908 mol
# Cumulative moles removed: 628193.517876 mol
# cumulative_mass_removed: 27640.514787 kg
# C_flow_values: 2246600.620719 m3/s
# CO2 flow rate required: 2246600.389815 cubic meters per second
#
# Iteration 813:
# Time: 694.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 629099.836691 mol
# cumulative_mass_removed: 27680.392814 kg
# C_flow_values: 2246600.389815 m3/s
# CO2 flow rate required: 2246600.196772 cubic meters per second
#
# Iteration 814:
# Time: 695.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553439 mol
# Total moles H2CO3: 906.318737 mol
# Cumulative moles removed: 630006.155428 mol
# cumulative_mass_removed: 27720.270839 kg
# C_flow_values: 2246600.196772 m3/s
# CO2 flow rate required: 2246600.389792 cubic meters per second
#
# Iteration 815:
# Time: 696.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 630912.474243 mol
# cumulative_mass_removed: 27760.148867 kg
# C_flow_values: 2246600.389792 m3/s
# CO2 flow rate required: 2246600.554390 cubic meters per second
#
# Iteration 816:
# Time: 697.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553294 mol
# Total moles H2CO3: 906.318882 mol
# Cumulative moles removed: 631818.793125 mol
# cumulative_mass_removed: 27800.026898 kg
# C_flow_values: 2246600.554390 m3/s
# CO2 flow rate required: 2246600.389812 cubic meters per second
#
# Iteration 817:
# Time: 698.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 632725.111940 mol
# cumulative_mass_removed: 27839.904925 kg
# C_flow_values: 2246600.389812 m3/s
# CO2 flow rate required: 2246600.245895 cubic meters per second
#
# Iteration 818:
# Time: 699.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553419 mol
# Total moles H2CO3: 906.318757 mol
# Cumulative moles removed: 633631.430697 mol
# cumulative_mass_removed: 27879.782951 kg
# C_flow_values: 2246600.245895 m3/s
# CO2 flow rate required: 2246600.389794 cubic meters per second
#
# Iteration 819:
# Time: 700.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 634537.749513 mol
# cumulative_mass_removed: 27919.660979 kg
# C_flow_values: 2246600.389794 m3/s
# CO2 flow rate required: 2246600.519128 cubic meters per second
#
# Iteration 820:
# Time: 701.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553309 mol
# Total moles H2CO3: 906.318867 mol
# Cumulative moles removed: 635444.068380 mol
# cumulative_mass_removed: 27959.539009 kg
# C_flow_values: 2246600.519128 m3/s
# CO2 flow rate required: 2246600.389811 cubic meters per second
#
# Iteration 821:
# Time: 702.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 636350.387195 mol
# cumulative_mass_removed: 27999.417037 kg
# C_flow_values: 2246600.389811 m3/s
# CO2 flow rate required: 2246600.270713 cubic meters per second
#
# Iteration 822:
# Time: 703.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553409 mol
# Total moles H2CO3: 906.318767 mol
# Cumulative moles removed: 637256.705962 mol
# cumulative_mass_removed: 28039.295062 kg
# C_flow_values: 2246600.270713 m3/s
# CO2 flow rate required: 2246600.389795 cubic meters per second
#
# Iteration 823:
# Time: 704.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 638163.024778 mol
# cumulative_mass_removed: 28079.173090 kg
# C_flow_values: 2246600.389795 m3/s
# CO2 flow rate required: 2246600.501920 cubic meters per second
#
# Iteration 824:
# Time: 705.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553316 mol
# Total moles H2CO3: 906.318860 mol
# Cumulative moles removed: 639069.343638 mol
# cumulative_mass_removed: 28119.051120 kg
# C_flow_values: 2246600.501920 m3/s
# CO2 flow rate required: 2246600.389810 cubic meters per second
#
# Iteration 825:
# Time: 706.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 639975.662453 mol
# cumulative_mass_removed: 28158.929148 kg
# C_flow_values: 2246600.389810 m3/s
# CO2 flow rate required: 2246600.282276 cubic meters per second
#
# Iteration 826:
# Time: 707.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553404 mol
# Total moles H2CO3: 906.318772 mol
# Cumulative moles removed: 640881.981225 mol
# cumulative_mass_removed: 28198.807174 kg
# C_flow_values: 2246600.282276 m3/s
# CO2 flow rate required: 2246600.389796 cubic meters per second
#
# Iteration 827:
# Time: 708.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553361 mol
# Total moles H2CO3: 906.318815 mol
# Cumulative moles removed: 641788.300040 mol
# cumulative_mass_removed: 28238.685202 kg
# C_flow_values: 2246600.389796 m3/s
# CO2 flow rate required: 2246600.494350 cubic meters per second
#
# Iteration 828:
# Time: 709.179245018369 seconds
# Time step: 1.000000 seconds
# Mass transfer rate: 0.000000 mol/s
# CO2 concentration in gas phase: 40.876319 mol/m³
# CO2 concentration in liquid phase: 34.061115 mol/m³
# Equilibrium concentration in liquid phase: 34.013605 mol/m³
# Carbonic acid concentration: 3.205447 mol/m³
# Removal rate: 3.205447 mol/s
# Total moles CO2 (gas): 36598.771791 mol
# Total moles CO2 (liquid): 9630.553319 mol
# Total moles H2CO3: 906.318857 mol
# Cumulative moles removed: 642694.618898 mol
# cumulative_mass_removed: 28278.563231 kg
# C_flow_values: 2246600.494350 m3/s

# %%
# Print final concentrations and mass transfer rate at the end of the simulation
H2CO3_values.append(H2CO3_new)
final_mass_transfer_rate = k * available_surface_area * (C_g_values[-1] - C_l_values[-1])



# Final total moles of carbon in the system
final_moles_CO2_gas = C_g_values[-1] * gas_volume
final_moles_CO2_liquid = C_l_values[-1] * liquid_volume
final_moles_H2CO3 = H2CO3_values[-1] * liquid_volume
final_total_moles_carbon = final_moles_CO2_gas + final_moles_CO2_liquid + final_moles_H2CO3 + cumulative_removal_values[-1]

# Print initial and final total moles of carbon
#print(f"Initial total moles of carbon: {initial_total_moles_carbon:.6f} mol")
#print(f"Final total moles of carbon: {final_total_moles_carbon:.6f} mol")

print(f"Final concentration of CO2 in the gas phase: {C_g_values[-1]:.6f} mol/m³")
print(f"Final concentration of CO2 in the liquid phase: {C_l_values[-1]:.6f} mol/m³")
#print(f"Final mass transfer rate: {final_mass_transfer_rate:.6f} mol/s")
print(f"Final concentration of HCO3- in the liquid phase: {H2CO3_values[-1]:.6f} mol/m³")


# Print cumulative total moles of carbon removed
#print(f"Cumulative total moles of carbon removed: {cumulative_removal_values[-1]:.6f} mol")
print(f"Cumulative total mass of carbon removed: {cumulative_mass_removed [-1]:.6f} kg")

print(f"Time to reach CO2 removal target: {time_points [-1]:.6f} sec")

print(f"Time to reach CO2 removal target: {(1/60)*time_points [-1]:.6f} minutes")

print(f"Time to reach CO2 removal target: {(1/3600)*time_points [-1]:.6f} hours")
print(f"Maximum CO2 flow rate: {C_flow_values[-1]:.6f} m3/s")



time_points.append(time_points[-1] + time_step)  # Increment time by the time step
C_g_values.append(C_g_new)
C_l_values.append(C_l_new)
C_sol_values.append(C_sol_new)
cumulative_removal_values.append(cumulative_removal_values[-1])
total_moles_carbon_values.append(total_moles_carbon)
C_flow_values.append(C_flow_values)
C_flow_values.append(C_flow_values)


# Plot the results
#plt.figure(figsize=(10, 6))
#plt.plot(time_points, C_g_values, label='CO2 concentration in gas phase')
#plt.plot(time_points, C_l_values, label='CO2 concentration in liquid phase')
#plt.plot(time_points, C_sol_values, label='CO2 solubility in liquid phase')
#plt.xlabel('Time (seconds)')
#plt.ylabel('CO2 concentration (mol/m³)')
#plt.title('CO2 Concentration in Gas and Liquid Phases Over Time')
#plt.legend()
#plt.grid(True)
#plt.show()

# Plot results
plt.figure(figsize=(10, 6))
plt.plot(time_points, C_g_values, label="CO2 (gas)")
plt.plot(time_points, C_l_values, label="CO2 (liquid)")
plt.plot(time_points,H2CO3_values, label="H2CO3 (liquid)")
plt.xlabel("Time (s)")
plt.ylabel("Concentration (mol/m³)")
plt.legend()
plt.title("Concentration vs Time")
plt.grid(True)
plt.show()

# Plot results
#plt.figure(figsize=(10, 6))
#plt.plot(time_points, [val * gas_volume for val in C_g_values], label="CO2 (gas)")
#plt.plot(time_points, [val * liquid_volume for val in C_l_values], label="CO2 (liquid)")
#plt.plot(time_points, [val * liquid_volume for val in H2CO3_values], label="H2CO3 (liquid)")
#plt.plot(time_points, cumulative_removal_values, label="Cumulative Removal")
#plt.plot(time_points, total_moles_carbon_values, label="Total Moles of Carbon")
#plt.xlabel("Time (s)")
#plt.ylabel("Total Moles of Carbon")
#plt.legend()
#plt.title("Total Moles of Carbon vs Time")
#plt.grid(True)
#plt.show()


# Plot results
plt.figure(figsize=(10, 6))
plt.plot(time_points, [val * gas_volume for val in C_g_values], label="CO2 (gas)")
plt.plot(time_points, [val * liquid_volume for val in C_l_values], label="CO2 (liquid)")
plt.plot(time_points, [val * liquid_volume for val in H2CO3_values], label="H2CO3 (liquid)")
#plt.plot(time_points, cumulative_removal_values, label="Cumulative Removal")
plt.plot(time_points, total_moles_carbon_values, label="Total Mass of Carbon")
plt.xlabel("Time (s)")
plt.ylabel("Total Mass of Carbon")
plt.legend()
plt.title("Carbonation of substrate")
plt.grid(True)
plt.show()
# Out:
# Final concentration of CO2 in the gas phase: 40.876319 mol/m³
# Final concentration of CO2 in the liquid phase: 34.061115 mol/m³
# Final concentration of HCO3- in the liquid phase: 3.205447 mol/m³
# Cumulative total mass of carbon removed: 28278.563231 kg
# Time to reach CO2 removal target: 709.179245 sec
# Time to reach CO2 removal target: 11.819654 minutes
# Time to reach CO2 removal target: 0.196994 hours
# Maximum CO2 flow rate: 2246600.494350 m3/s
