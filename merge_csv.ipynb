# %%
import pandas as pd
import os

def merge_csv_files(file_paths, output_file_path):
    # List to hold DataFrames
    dataframes = []
    
    # Loop through each file path
    for file_path in file_paths:
        # Read the CSV file
        df = pd.read_csv(file_path)
        
        # Extract the file name from the path
        filename = os.path.basename(file_path)
        
        # Add filename to the first row
        filename_row = pd.DataFrame({col: [filename] for col in df.columns})
        
        # Append the filename row and the DataFrame
        combined_df = pd.concat([filename_row, df], ignore_index=True)
        dataframes.append(combined_df)
    
    # Merge DataFrames column-wise
    merged_df = pd.concat(dataframes, axis=1)
    
    # Ensure the directory exists
    os.makedirs(os.path.dirname(output_file_path), exist_ok=True)
    
    # Save the merged DataFrame to a CSV file
    merged_df.to_csv(output_file_path, index=False)

# List of file paths
file_paths = [
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\test4_13\output_data_size_5_trip_5.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\test4_13\output_data_size_5_trip_6.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\test4_13\output_data_size_5_trip_7.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\test4_13\output_data_size_5_trip_8.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\test4_13\output_data_size_5_trip_9.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\test4_13\output_data_size_5_trip_10.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\test4_13\output_data_size_5_trip_11.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\test4_13\output_data_size_5_trip_12.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\test4_13\output_data_size_5_trip_13.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\test4_13\output_data_size_5_trip_4.csv"
]

# Output file path
output_file_path = r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\test4_13\merged_output.csv"

# Merge the CSV files
merge_csv_files(file_paths, output_file_path)

# %%
import pandas as pd
import os

def merge_csv_files(file_paths, output_file_path):
    # List to hold DataFrames
    dataframes = []
    
    # Loop through each file path
    for file_path in file_paths:
        # Read the CSV file
        df = pd.read_csv(file_path)
        
        # Extract the file name from the path
        filename = os.path.basename(file_path)
        
        # Add filename to the first column
        df.insert(0, 'SourceFile', filename)
        
        # Append the DataFrame to the list
        dataframes.append(df)
    
    # Merge DataFrames row-wise
    merged_df = pd.concat(dataframes, ignore_index=True)
    
    # Ensure the directory exists
    os.makedirs(os.path.dirname(output_file_path), exist_ok=True)
    
    # Save the merged DataFrame to a CSV file
    merged_df.to_csv(output_file_path, index=False)

# List of file paths
file_paths = [
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\4_13b\output_data_size_5_trip_4.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\4_13b\output_data_size_5_trip_5.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\4_13b\output_data_size_5_trip_6.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\4_13b\output_data_size_5_trip_7.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\4_13b\output_data_size_5_trip_8.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\4_13b\output_data_size_5_trip_9.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\4_13b\output_data_size_5_trip_10.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\4_13b\output_data_size_5_trip_11.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\4_13b\output_data_size_5_trip_12.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\4_13b\output_data_size_5_trip_13.csv"
]

# Output file path
output_file_path = r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\4_13b\merged_output.csv"

# Merge the CSV files
merge_csv_files(file_paths, output_file_path)

# %%
import pandas as pd
import os

def merge_csv_files(file_paths, output_file_path):
    # List to hold DataFrames
    dataframes = []
    
    # Loop through each file path
    for file_path in file_paths:
        # Read the CSV file
        df = pd.read_csv(file_path)
        
        # Extract the file name from the path
        filename = os.path.basename(file_path)
        
        # Add filename to the first column
        df.insert(0, 'SourceFile', filename)
        
        # Append the DataFrame to the list
        dataframes.append(df)
    
    # Merge DataFrames row-wise
    merged_df = pd.concat(dataframes, ignore_index=True)
    
    # Ensure the directory exists
    os.makedirs(os.path.dirname(output_file_path), exist_ok=True)
    
    # Save the merged DataFrame to a CSV file
    merged_df.to_csv(output_file_path, index=False)

# List of file paths
file_paths = [
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\4_13C\output_data_size_5_trip_4.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\4_13C\output_data_size_5_trip_5.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\4_13C\output_data_size_5_trip_6.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\4_13C\output_data_size_5_trip_7.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\4_13C\output_data_size_5_trip_8.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\4_13C\output_data_size_5_trip_9.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\4_13C\output_data_size_5_trip_10.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\4_13C\output_data_size_5_trip_11.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\4_13C\output_data_size_5_trip_12.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\4_13C\output_data_size_5_trip_13.csv"
]

# Output file path
output_file_path = r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\4_13C\merged_output.csv"

# Merge the CSV files
merge_csv_files(file_paths, output_file_path)
# Out:
# C:\Users\Henry\AppData\Local\Temp\ipykernel_3984\149653418.py:23: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   merged_df = pd.concat(dataframes, ignore_index=True)

# %%
import pandas as pd
import os

def merge_csv_files(file_paths, output_file_path):
    # List to hold DataFrames
    dataframes = []
    
    # Loop through each file path
    for file_path in file_paths:
        # Read the CSV file
        df = pd.read_csv(file_path)
        
        # Extract the file name from the path
        filename = os.path.basename(file_path)
        
        # Add filename to the first column
        df.insert(0, 'SourceFile', filename)
        
        # Append the DataFrame to the list
        dataframes.append(df)
    
    # Merge DataFrames row-wise
    merged_df = pd.concat(dataframes, ignore_index=True)
    
    # Ensure the directory exists
    os.makedirs(os.path.dirname(output_file_path), exist_ok=True)
    
    # Save the merged DataFrame to a CSV file
    merged_df.to_csv(output_file_path, index=False)

# List of file paths
file_paths = [
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\test4_13\output_data_size_5_trip_4.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\test4_13\output_data_size_5_trip_5.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\test4_13\output_data_size_5_trip_6.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\test4_13\output_data_size_5_trip_7.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\test4_13\output_data_size_5_trip_8.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\test4_13\output_data_size_5_trip_9.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\test4_13\output_data_size_5_trip_10.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\test4_13\output_data_size_5_trip_11.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\test4_13\output_data_size_5_trip_12.csv",
    r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\test4_13\output_data_size_5_trip_13.csv"
]

# Output file path
output_file_path = r"C:\Users\Henry\Downloads\Timelapse\DCIM\100MEDIA\test4_13\merged_output.csv"

# Merge the CSV files
merge_csv_files(file_paths, output_file_path)
